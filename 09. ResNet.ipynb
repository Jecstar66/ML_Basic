# %% [markdown]
# # **EE214 Project 2: CNN (ResNet)**
#
# This is the second project for EE214 Machine Learning Basics and Practices.
#
# &nbsp;
#
# In this project, we will **implement ResNet18 and ResNet50** and perform **a classification task on the Fashion-MNIST dataset** using these models. Additionally, we will **achieve the highest possible accuracy score using any model and by only utilizing the resources available in Colab**. This project consists of the following components:
#
# * **Part 1 (10 pts). Dataset visualization**
# * **Part 2 (30 pts). Implement Building Blocks for ResNet**
# * **Part 3 (30 pts). Implement ResNet18 and ResNet50**
# * **Part 4 (10 pts). Train and visualize the results**
# * **Part 5 (20 pts). Achieve the highest possible accuracy score.**
#
#
# &nbsp;
#
#
# ## **Important**
#
# * You have to write some description about your code and results for points in each part. For required sections, we will make the **markdown** box to write in and inform you what to write. Check **ALL** steps which have points.
# * Your **submission** must be on the KLMS and includes two formats:
#     * **[STUDENT_ID]_project2.ipynb**, e.g., 20XXXXX1.ipynb
#     * **[STUDENT_ID]_project2.pdf**

# %%
# Importing the Required Library
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Subset
from torchsummary import summary

import time

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# To train a model much faster, we'll use GPU source. Therefore, the runtime type must be changed to T4 GPU (Colab), and the below code should be compiled for using cuda. <br>
# Furthermore, in Part 4, train() function is modified due to the change of PyTorch device. Modifications are specified inside the code.

# %%
# Set PyTorch device (use GPU or CPU)
# For faster training, we'll use GPU(cuda). Change runtime type as T4 GPU in Colab.
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(device)

# If GPU is available, check CUDA version
if torch.cuda.is_available():
    # !nvcc --version
# Out:
# cuda
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %% [markdown]
# # **Part 1 (Total 10 pts)**. Download and examine the Fashion-MNIST dataset
# - In this project, we'll use the Fashion-MNIST dataset, which consists of 28x28 grayscale images of clothing.
# - As you progress through **Part 1**, you'll download the dataset and examine its structure.

# %%
# Define the transformation to be applied to the data
transformations = transforms.Compose([transforms.ToTensor(),])

# Download the FashionMNIST dataset
train_dataset = datasets.FashionMNIST(root='./data', train=True, download=True, transform=transformations)
test_dataset = datasets.FashionMNIST('./data', download=True, train=False, transform=transformations)

# Create DataLoader with subset of the dataset
def get_train_loader():
  indices = list(range(len(train_dataset)))
  sub_dataset_size = len(train_dataset) // 3
  random_indices = torch.randperm(len(indices)).tolist()
  subset_indices = random_indices[:sub_dataset_size]

  train_subset = Subset(train_dataset, subset_indices)
  train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)

  return train_loader

train_loader = get_train_loader()
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=True)

print("Number of training data: %d" % len(train_dataset))
print("Number of test data: %d" % len(test_dataset))
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:02<00:00, 10727028.91it/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 173297.24it/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:01<00:00, 3258683.89it/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<00:00, 6714016.48it/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# Number of training data: 60000
# Number of test data: 10000

# %% [markdown]
# ### **$\color{red}{\text{ToDo}}$**: Visualize the dataset as shown in the illustration below. You don't need to replicate the exact results, but make sure to satisfy the following three conditions:
#
# 1. Ensure that at least one image for each label is included.
# 2. Plot a total of 30 or more samples.
# 3. Provide information about which label each sample belongs to alongside the plot.
#
# ![](https://drive.google.com/uc?export=view&id=1cotGY0lWW78uaObXs1xtIKMK58OuYhAd)

# %%
FASHION_LABELS = {0: 'T-shirt/top', 1: 'Trouser', 2: 'Pullover', 3: 'Dress', 4: 'Coat', 5: 'Sandal', 6: 'Shirt', 7: 'Sneaker', 8: 'Bag', 9: 'Ankle boot'}

def display_sample(sample_images, sample_labels):

    ########## implement here ##########
    # Plot 8 x 8 = 64 images
    num_rows = 8
    num_cols = 8
    num_samples = num_rows * num_cols

    plt.figure(figsize=(10, 12))
    for i in range(num_samples):
        # 8 x 8 display (show all images in mini-batch)
        plt.subplot(num_rows, num_cols, i + 1)
        # show 28 x 28 2D image (not 3D like 1 x 28 x 28 )
        plt.imshow(sample_images[i,0,:,:], cmap = 'binary')
        ## Label visualization as title
        plt.title(FASHION_LABELS[sample_labels[i]])
        plt.axis('off')
        # Note that the current output shows all 10 labels at least once
        # However, re-compiling this code can omit some labels unfortunately.
    ####################################

    plt.show()
    plt.close()

# display a sample
data_iter = iter(train_loader)
images, labels = next(data_iter)
print(f'images.shape = {images.shape}, labels.shape={labels.shape}')
display_sample(images.cpu().numpy(), labels.cpu().numpy())
# Out:
# images.shape = torch.Size([64, 1, 28, 28]), labels.shape=torch.Size([64])

# %% [markdown]
# # **Part 2 (Total 30 pts)**. Implement Building Blocks for ResNet
#
#
# - In ResNet, residual networks are implemented using the following two methods. The first is the Identity method, which uses a simple structure, as shown in the figure below. The second is the Projection method, which scales the dimensions through 1x1 convolution operations to reduce the number of parameters.
#
#   <img src="https://drive.google.com/uc?export=view&id=16QzhXGKVS2XVxDf-5Nz-PZjQRL0dyntO" width="600" height="300" />
#
# - In **Part 2**, we will implement the two types of blocks used in ResNet, the basic block and the bottleneck block.

# %% [markdown]
# ## **Step 1 (Total 15 pts)**. Implement BasicBlock class
#
# This class implements a basic building block for the Residual Network (ResNet) architecture. ResNet's design incorporates "shortcut" or "skip connections" to allow the gradient to be directly backpropagated through the network, addressing the vanishing/exploding gradient problem found in deeper networks. Each `BasicBlock` represents a residual block with two convolutional layers and a skip connection.
#
# &nbsp;
#
# ### **$\color{red}{\text{ToDo}}$**: Fill in the blanks in the skeleton code below to complete the BasicBlock class. As can be seen in the following diagram, the BasicBlock consists of following elements:
#
# ```
# (A 3x3 convolution that returns a vector of dimensions out_channels)
#  ➡ (batch normalization)
#  ➡ (relu)
#  ➡ (A 3x3 convolution that returns a vector of dimensions out_channels)
#  ➡ (batch normalization)
#  ➡ residual with input vector
#  ➡ relu
# ```
#
# &nbsp;
#
# The detailed guide for each element is as follows:
#
#
# **1. First Convolution:**
#    - When input data is given, this data first passes through a 3x3 convolutional layer.
#    - During this process, depending on the 'stride' value, the size of the feature map may reduce.
#    - After this operation, the number of channels changes to the value defined by the 'out_channels' parameter.
#
# **2. Batch Normalization:**
#    - The result after the convolution operation undergoes batch normalization.
#    - This step normalizes each channel so that the mean is 0 and the variance is 1, increasing the stability of the network.
#
# **3. Application of ReLU Activation Function:**
#    - The result of batch normalization passes through the ReLU activation function, introducing non-linearity.
#    - This aids the model in learning more complex patterns and features.
#
# **4. Second Convolution:**
#    - Next, the activated feature map passes through a second 3x3 convolutional layer.
#    - The number of channels remains 'out_channels' here as well, and 'stride' is set to 1, meaning the size of the feature map remains unchanged.
#
# **5. Second Batch Normalization:**
#    - The result after the second convolution operation also undergoes batch normalization.
#
# **6. Addition of the Shortcut:**
#    - The original input (also known as the Residual or Shortcut) is added to the transformed feature map at this point.
#    - If the dimensions of the input and output differ, the input is adjusted through a 1x1 convolution + batch normalization for dimension matching.
#    - If the dimensions are the same, the original input is added directly without any alteration.
#    - This step is crucial as it allows the network to retain fundamental information from the input data while still detecting changes.
#
# **7. Application of the Final ReLU Activation Function:**
#    - The result, combined from the shortcut and the convolution path, passes through the ReLU activation function once more.
#    - This output is either passed on to the next layer or used as the final output, depending on the network's structure.

# %%
########## implement this class ##########

class BasicBlock(nn.Module):
    """
    Implements a BasicBlock architecture.

    Attributes:
    -----------
    expansion : int
        Class attribute representing the expansion factor for the block's output channels. For
        `BasicBlock`, this is always 1 as there is no expansion within the block itself.

    conv1 : nn.Conv2d
        The first convolutional layer in the block, applying filters to the input data with a
        kernel size of 3x3. The stride can be adjusted, affecting the output's height and width
        and serving as a mechanism for spatial down-sampling. This layer does not use bias.

    bn1 : nn.BatchNorm2d
        Batch Normalization for stabilizing the inputs to the second layer by adjusting and
        scaling the activations. Applied to the outputs of `conv1`.

    relu1 : nn.ReLU
        ReLU activation function applied after first batch normalization, introducing
        non-linearity and enhancing the network's learning capabilities.

    conv2 : nn.Conv2d
        The second convolutional layer with the same kernel size as `conv1` but with a fixed
        stride of 1, preserving the spatial dimensions of the data. This layer also does not use bias.

    bn2 : nn.BatchNorm2d
        Similar to `bn1`, this Batch Normalization layer normalizes the output from `conv2`,
        ensuring that the network remains stable during training.

    shortcut : nn.Sequential
        The skip connection providing a pathway for the original input to bypass the convolutional
        layers, facilitating the gradient flow during backpropagation. If the input and output dimensions
        are consistent, this remains an empty sequential block. If they differ (often due to a change
        in stride), this pathway adjusts the input's dimensions to match the output using a 1x1 convolution.

    relu2 : nn.ReLU
        The result, combined from the shortcut and the convolution path, passes through the ReLU activation function once more.
        This output is either passed on to the next layer or used as the final output, depending on the network's structure.

    Methods:
    --------
    __init__(self, input_channels: int, output_channels: int, stride: int = 1) -> None:
        Constructs all the necessary attributes for the BasicBlock object, including the convolutional
        layers, batch normalization, and the shortcut connection.

    forward(self, x: Tensor) -> Tensor:
        Defines the computation performed at every call, applying both convolutional layers to the input,
        then combining the output with the original input (the "shortcut") before returning the
        final activated result. This method is crucial for the 'torch.nn.Module' interface, as it handles
        the block's operations on input data.
    """

    expansion = 1

    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()

        # TODO: Define the first convolutional layer and batch normalization.
        # Remember to consider the number of input and output channels and the stride.
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size = 3, stride = stride, padding = 1)
        self.bn1 = nn.BatchNorm2d(out_channels)

        # TODO: Define a 1st activation function ReLU.
        self.relu1 = nn.ReLU()

        # TODO: Define the second convolutional layer and batch normalization.
        # The number of output channels remains the same as the first layer.
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size = 3, stride = 1, padding = 1)
        self.bn2 = nn.BatchNorm2d(out_channels)

        # TODO: Define a shortcut layer that appropriately transforms the input to be added to the transformed feature map up to this point.
        # If input and output are the same dimensions, use an empty sequential model.
        # If the dimensions are different, adjust the layers accordingly using 1x1 convolution + batch normalization.
        if stride == 1 and in_channels == out_channels * self.expansion:  # Default is identity (no-operation)
          self.shortcut = nn.Sequential()

        else: # TODO: Add a layer to adjust dimensions in the shortcut path, if necessary, using 1x1 convolution + batch normalization.
          self.shortcut = nn.Sequential(nn.Conv2d(in_channels, out_channels * self.expansion, kernel_size=1, stride=stride),
                                        nn.BatchNorm2d(out_channels * self.expansion))

        # TODO: Define a 2nd activation function ReLU.
        self.relu2 = nn.ReLU()

    def forward(self, x):
        # TODO: Implement the forward function that applies the layers you have defined in the __init__.
        # Don't forget to add the input x to the output of the convolutional layers (skip connection).
        # conv1 : A 3x3 convolution that returns a vector of dimensions out_channels
        # ➡ bn1 : batch normalization
        # ➡ relu1 : relu
        # ➡ conv2 : A 3x3 convolution that returns a vector of dimensions out_channels
        # ➡ bn2 : batch normalization
        # ➡ shortcut : residual with input vector
        # ➡ relu1 : relu

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu1(out)

        out = self.conv2(out)
        out = self.bn2(out)

        shortcut = self.shortcut(x)
        out += shortcut

        out = self.relu2(out)

        return out

# %% [markdown]
# ## **Step 2 (Total 15 pts)**. Implement Bottleneck block
#
# This class implements the "Bottleneck" building block used in deeper Residual Network (ResNet) architectures. These blocks are designed with efficiency in mind, providing a more efficient way of increasing the depth of the network without a significant increase in computational complexity. The main feature of a Bottleneck block is the use of 1x1 convolutions to reduce and subsequently restore dimensions, ensuring that the 3x3 convolution has a minimal computational load.
#
# &nbsp;
#
# ### **$\color{red}{\text{ToDo}}$**: Fill in the blanks in the skeleton code below to complete the Bottleneck class. As can be seen in the following diagram, the Bottleneck class consists of following elements:
#
# ```
# (A 1x1 convolution that returns a vector of dimensions out_channels)
#  ➡ (batch normalization)
#  ➡ (relu)
#  ➡ (A 3x3 convolution that returns a vector of dimensions out_channels)
#  ➡ (batch normalization)
#  ➡ (relu)
#  ➡ (A 1x1 convolution that returns a vector of dimensions out_channels*4)
#  ➡ (batch normalization)
#  ➡ residual with input vector
#  ➡ relu
# ```
#
# **1. First Convolution (1x1 kernels):**
#    - The data first passes through a 1x1 convolutional layer. Despite its simplicity, this layer is instrumental in reducing the dimensionality, as it affects the depth of the feature maps (i.e., the number of channels).
#    - This layer performs initial feature transformation, preparing the data for the next step of processing.
#
# **2. First Batch Normalization and ReLU Activation:**
#    - Subsequent to convolution, the model normalizes the batch using Batch Normalization. This step is crucial for maintaining consistent mean and variance, improving the stability and speed of the training process.
#    - After normalization, the feature map goes through a ReLU activation function, providing the non-linearity necessary for the model to learn complex patterns.
#
# **3. Second Convolution (3x3 kernels):**
#    - The second layer is a 3x3 convolution, the central part of the bottleneck. It's where the spatial features are primarily learned, without any change in the depth of the feature maps.
#    - This convolution is more computational efficient due to the reduced dimensionality from the previous 1x1 convolution.
#
# **4. Second Batch Normalization and ReLU Activation:**
#    - The model normalizes the results of the second convolution before applying another ReLU activation.
#    - This step is necessary for ensuring the model does not produce outputs with high variance or learn inefficient representations.
#
# **5. Third Convolution (1x1 kernels):**
#    - The third layer involves another 1x1 convolution. This stage is crucial as it restores the depth of the feature maps, often expanding it to be ready for addition with the shortcut.
#    - It allows the network to learn more abstract features by reintroducing depth to the feature maps.
#
# **6. Third Batch Normalization:**
#    - Similar to previous layers, batch normalization is applied to standardize the feature maps, preparing them for the shortcut connection.
#
# **7. Shortcut Connection and Final ReLU Activation:**
#    - The shortcut (or residual connection) is then added back to the main pathway. If the input needs to be resized to match the output dimensions, a 1x1 convolution is applied to the shortcut connection.
#    - After adding the shortcut, the block applies a ReLU activation function to introduce non-linearity, making the output the final result of this block.

# %%
########## implement this class ##########

class Bottleneck(nn.Module):

    """
    Implements a Bottleneck architecture.

    Attributes:
    -----------
    expansion : int
        Class attribute representing the expansion factor for the output channels at the end of
        the block. This attribute multiplies the number of channels in the block, typically
        increasing the depth by 4 times in a standard Bottleneck block.

    conv1 : nn.Conv2d
        The first layer in the bottleneck, a 1x1 convolution. This layer reduces the number of
        channels, preparing the input for the next 3x3 convolution. It is designed without a bias term.

    bn1 : nn.BatchNorm2d
        Batch Normalization for the first convolution, stabilizing the activations and improving
        the training process.

    relu1 : nn.ReLU
        ReLU activation function applied after first batch normalization, introducing
        non-linearity and enhancing the network's learning capabilities.

    conv2 : nn.Conv2d
        The central layer of the bottleneck, a 3x3 convolution. This layer maintains the number
        of channels but can alter the spatial dimensions based on the stride. It is also designed
        without a bias term.

    bn2 : nn.BatchNorm2d
        Batch Normalization for the central convolutional layer, providing the same benefits as `bn1`.

    relu2 : nn.ReLU
        ReLU activation function applied after central batch normalization.

    conv3 : nn.Conv2d
        The final layer in the bottleneck, a 1x1 convolution. This layer expands the number of
        channels by the factor defined in `expansion`, increasing the depth of the feature map.
        This convolution is also without a bias term.

    bn3 : nn.BatchNorm2d
        Batch Normalization for the final convolution, ensuring the network's stability as the depth increases.

    shortcut : nn.Sequential
        A sequential container for the 'shortcut' or 'skip connection'. When the input and output
        dimensions differ, due to either a stride not equal to 1 or a difference in the number of channels,
        this pathway contains a 1x1 convolution that adjusts the input's dimensions to match the output.

    relu3 : nn.ReLU
        After adding the shortcut, the block applies a ReLU activation function to introduce non-linearity,
        making the output the final result of this block.

    Methods:
    --------
    __init__(self, in_channels: int, out_channels: int, stride: int = 1) -> None:
        Initializes the Bottleneck block with its convolutional layers, batch normalization,
        and prepares the shortcut connection.

    forward(self, x: Tensor) -> Tensor:
        Defines the computation performed at every call. The input passes through each layer of the
        bottleneck, with a skip connection adding the input of the block to its output. This method
        applies the ReLU activation function after each addition and finally returns the resulting tensor.
    """

    # This value is used to adjust the number of output channels in the layer, e.g., out_channels * expansion.
    expansion = 4

    def __init__(self, in_channels, out_channels, stride=1):
        super(Bottleneck, self).__init__()

        # TODO: Define the first 1x1 convolution layer.
        # It should take in_channels and return out_channels.
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=1)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu1 = nn.ReLU()

        # TODO: Define the second 3x3 convolution layer.
        # It should take out_channels and return out_channels, possibly performing downsampling using stride and padding.
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=stride, padding=1)
        self.bn2 = nn.BatchNorm2d(out_channels)
        self.relu2 = nn.ReLU()

        # TODO: Define the third 1x1 convolution layer.
        # It should take out_channels and return out_channels * expansion.
        self.conv3 = nn.Conv2d(out_channels, out_channels * self.expansion, kernel_size=1)
        self.bn3 = nn.BatchNorm2d(out_channels * self.expansion)

        # TODO: Shortcut definition for skip connection & Final ReLU
        self.shortcut = nn.Sequential()  # Default is identity (no-operation)
        if stride != 1 or in_channels != out_channels * self.expansion:
            # TODO: Add a layer to adjust dimensions in the shortcut path, if necessary, using 1x1 convolution + batch normalization.
            self.shortcut = nn.Sequential(nn.Conv2d(in_channels, out_channels * self.expansion, kernel_size=1, stride=stride),
                nn.BatchNorm2d(out_channels * self.expansion))

        self.relu3 = nn.ReLU()

    def forward(self, x):
        # TODO: Implement the forward function that applies the layers you have defined in the __init__.
        # Don't forget to add the input x to the output of the convolutional layers (skip connection).

        # Step 1. 1x1 convolution layer
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu1(out)

        # Step 2. 3x3 convolution layer
        out = self.conv2(out)
        out = self.bn2(out)
        out = self.relu2(out)

        # Step 3. 1x1 convolution layer
        out = self.conv3(out)
        out = self.bn3(out)

        # Step 4. Shortcut layer connection and final ReLU
        shortcut = self.shortcut(x)
        out += shortcut
        out = self.relu3(out)

        return out  # Return the final output

# %% [markdown]
# # **Part 3 (Total 30 pts)**. Implement ResNet18 and ResNet50
# - In **Part 3**, we will implement ResNet18 and ResNet50 using the Basic block and Bottleneck block that we implemented in Part 2.
# - The architectural configuration of ResNet18 and ResNet50 is as shown in the figure below, and one [*] represents a basic/bottleneck block.
#
#   <img src="https://drive.google.com/uc?export=view&id=1lY6jHixjUNKYpiw0Nho0XyLzlHuvhmGh" width="700" height="330" />
# - First, we will implement a common ResNet class that can be used to build both ResNet18 and ResNet50, and through this, we will create each model.

# %% [markdown]
# ## **Step 1 (Total 25 pts)**. Implement ResNet Class
#
# ### **$\color{red}{\text{ToDo}}$**: Using the detailed description provided, complete the ResNet class by filling in the blanks in the following skeleton code.
#
# **1. Initial Setup:**
#    - ResNet class initializes with parameters specifying the type of block to use, the number of blocks, and the number of classes for classification.
#    - The initial number of channels, specifically, `in_channels`, is set to 64.
#
# **2. Initial Convolutional Layer and Max Pooling:**
#
#    - Initial Convolutional Layer: This layer (`self.conv1`) employs 64 filters of size 7x7 with a stride of 2 and padding of 3.
#
#    - Batch Normalization: Following the convolution, the model applies batch normalization via `self.bn1` to standardize the activations of the previous layer. This process helps stabilize and accelerate the learning process.
#
#    - ReLU Activation: After the convolution, the model applies a ReLU activation function (`self.relu`).
#
#    - Max Pooling: Subsequent to the initial convolutional layers, the ResNet model incorporates a max-pooling layer (`self.maxpool`). This layer, with a kernel size of 3x3, stride of 2, and padding of 1, reduces the spatial dimensions by taking the maximum value of features, helping the model eliminate redundant information and retain only crucial features.
#
# **3. Constructing Residual Layers:**
#    - Four main layers (each a sequence of blocks) follow the initial convolution. Each layer uses the `_make_layer` function to create a series of residual blocks.
#    - `self.layer1` is composed of `num_blocks[0]` blocks, each outputting 64 channels and using a stride of 1 for maintaining the spatial dimensions of the feature maps.
#    - `self.layer2` consists of `num_blocks[1]` blocks, increasing the number of channels to 128. With the appropriate stride, it effectively halves the dimensions of the feature maps while increasing their depth for a more complex feature representation.
#    - `self.layer3` is structured with `num_blocks[2]` blocks, further enhancing the capacity by increasing the channels to 256. It continues the trend of reducing spatial dimensions by half and doubling the depth, allowing the network to learn even more complex patterns in the input data.
#    - `self.layer4` forms the deepest segment of the architecture, comprising `num_blocks[3]` blocks, each contributing to a total of 512 channels. This layer continues to compact the spatial dimensions and enhance the representational depth, making the network capable of understanding highly abstract features present in the data.
#
#
# **4. Residual Block Creation (`_make_layer` method):**
#    - This method creates a sequence of residual blocks. The first block in each sequence might use a stride not equal to 1 for dimensionality reduction.
#    - For each block, it adjusts the number of input channels (`self.in_channels`) and the number of output channels, ensuring that the subsequent block receives the correct number of input channels.
#    - It stacks these blocks sequentially to form a complete layer.
#
# **5. Forward Pass:**
#    - The `forward` method defines the data flow through the network:
#      - The input data `x` goes through the initial convolution, batch normalization, and ReLU activation.
#      - It then sequentially passes through each of the four layers of residual blocks (`self.layer1`, `self.layer2`, `self.layer3`, `self.layer4`).
#      - Following the residual layers, a global average pooling is performed reducing the spatial dimensions to 1x1.
#      - The pooled output is then flattened and finally, a linear layer (`self.linear`) classifies the features into `num_classes` categories.

# %%
########## implement this class ##########
"""
      Implements a Residual Network (ResNet) architecture.

      The ResNet architecture is designed with deep residual learning to ease the training of
      networks that are substantially deeper than those used previously. This class creates a
      customizable ResNet model by stacking layers of residual blocks, performing initial
      convolution, and final classification using a fully connected layer.

      Attributes:
      -----------
      in_channels : int
          The number of channels in the input data. Initialized to 64 for the first layer.
      conv1 : nn.Conv2d
          The first convolutional layer which applies 64 filters with a 7x7 kernel, stride of 2,
          and padding of 3.
      bn1 : nn.BatchNorm2d
          Batch Normalization for the first convolutional layer.
      relu : nn.ReLU
          ReLU activation function used after batch normalization.
      maxpool : nn.MaxPool2d
          Max pooling with a 3x3 kernel, stride of 2, and padding of 1.
      layer1-4 : nn.Sequential
          Layers of residual blocks, with the number of blocks and output channels varying
          per layer. Each individual layer is created by the _make_layer private method.
      linear : nn.Linear
          The final fully connected layer that outputs the classification results.

      Methods:
      --------
      __init__(self, block, num_blocks, num_classes=10):
          Initializes the ResNet with the given block type, list of integers representing the
          number of blocks in each layer, and the number of classification classes.

      _make_layer(self, block, output_channels, num_blocks, stride):
          Helper function to create a layer of residual blocks with the specified number of blocks,
          output channels, and the initial stride.

      forward(self, x):
          Defines the forward pass of the input through the ResNet architecture. The input data 'x'
          passes sequentially through the initial convolution (with batch normalization and ReLU),
          max pooling, four residual layers, and finally, the fully connected layer for classification.
          The output of this method is the classification result of the input.
          """
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_channels = 64  # Starting number of channels

        # TODO: Define the initial convolutional layer and batch normalization.
        self.conv1 = nn.Conv2d(in_channels = 1, out_channels = 64, kernel_size = 7, stride = 2, padding = 3) # 64 filters of size 7x7 with a stride of 2 and padding of 3
        self.bn1 = nn.BatchNorm2d(64) # standardize the activations of the previous layer
        self.relu = nn.ReLU() # Add a non-linearity to model
        self.maxpool = nn.MaxPool2d(kernel_size=3, stride=2, padding=1) #  reduces the spatial dimensions by taking the maximum value of features

        # Define layers consisting of BasicBlocks. Each layer may contain multiple blocks.
        # The number of blocks for each layer is specified in num_blocks.
        # TODO: Define the four layers of the ResNet (self.layer1 to self.layer4) using the '_make_layer' function.
        # Note that for self.layer2, 3, 4, halves the dimensions of the feature maps while increasing their depth for a more complex feature representation
        # while self.layer1 maintaining the spatial dimensions of the feature maps.

        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride = 1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride = 2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride = 2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride = 2)

        # Reducing dimension with selecting appropriate pooling layer
        self.avgpool = nn.AdaptiveAvgPool2d(output_size=(1, 1))

        # TODO: Define the final fully connected layer that maps the output of the convolutional layers to the classes.
        self.linear = nn.Linear(in_features = 512 * block.expansion, out_features = 10)

    def _make_layer(self, block, out_channels, num_blocks, stride):
        # This function creates a sequential layer for each set of blocks.
        # TODO: Implement the function that creates each layer. You will need to consider the stride for the first block
        # and make sure subsequent blocks maintain the output dimension.
        # Update self.in_channels as needed.
        layers = []
        stride_list = [stride] + [1] * (num_blocks - 1)

        for s in stride_list:
          # Note that for each layer, only initial block has a stride that specified in parameter, for dimensionality reduction.
          # Other blocks have a stride with 1.
          layers.append(block(self.in_channels, out_channels, stride = s ))
          self.in_channels = out_channels * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        # TODO: Implement the forward function. Apply the layers defined in the __init__ to the input x.
        # The initial convolutional layer and batch normalization. Dimension reduction occurs by maxpool.
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        out = self.maxpool(out)

        # Passing the data through four layers (each layers have multiple Basicblock or Bottleneck)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)

        # Finally, apply average pooling and a fully connected layer for the classification.
        out = self.avgpool(out)
        out = out.view(out.size(0), -1)
        out = self.linear(out)

        return out

# %% [markdown]
# ## **Step 2 (Total 5 pts)**. Construct and check your ResNet18 and ResNet50

# %% [markdown]
# Note that when the model runs on GPU, then the device should be changes by implementation.

# %%
# To use GPU for training, attach to(device) method at the end of each model.
# Define the ResNet18 model using the previously defined BasicBlock and ResNet class.
resnet18_model = ResNet(block=BasicBlock,
                   num_blocks=[2, 2, 2, 2],
                   num_classes=10)
summary(resnet18_model.to(device), (1, 28, 28))

# Define the ResNet50 model using the previously defined Bottleneck block and ResNet class.
resnet50_model = model = ResNet(block=Bottleneck,
                   num_blocks=[3, 4, 6, 3],
                   num_classes=10)
summary(resnet50_model.to(device), (1, 28, 28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 14, 14]           3,200
#        BatchNorm2d-2           [-1, 64, 14, 14]             128
#               ReLU-3           [-1, 64, 14, 14]               0
#          MaxPool2d-4             [-1, 64, 7, 7]               0
#             Conv2d-5             [-1, 64, 7, 7]          36,928
#        BatchNorm2d-6             [-1, 64, 7, 7]             128
#               ReLU-7             [-1, 64, 7, 7]               0
#             Conv2d-8             [-1, 64, 7, 7]          36,928
#        BatchNorm2d-9             [-1, 64, 7, 7]             128
#              ReLU-10             [-1, 64, 7, 7]               0
#        BasicBlock-11             [-1, 64, 7, 7]               0
#            Conv2d-12             [-1, 64, 7, 7]          36,928
#       BatchNorm2d-13             [-1, 64, 7, 7]             128
#              ReLU-14             [-1, 64, 7, 7]               0
#            Conv2d-15             [-1, 64, 7, 7]          36,928
#       BatchNorm2d-16             [-1, 64, 7, 7]             128
#              ReLU-17             [-1, 64, 7, 7]               0
#        BasicBlock-18             [-1, 64, 7, 7]               0
#            Conv2d-19            [-1, 128, 4, 4]          73,856
#       BatchNorm2d-20            [-1, 128, 4, 4]             256
#              ReLU-21            [-1, 128, 4, 4]               0
#            Conv2d-22            [-1, 128, 4, 4]         147,584
#       BatchNorm2d-23            [-1, 128, 4, 4]             256
#            Conv2d-24            [-1, 128, 4, 4]           8,320
#       BatchNorm2d-25            [-1, 128, 4, 4]             256
#              ReLU-26            [-1, 128, 4, 4]               0
#        BasicBlock-27            [-1, 128, 4, 4]               0
#            Conv2d-28            [-1, 128, 4, 4]         147,584
#       BatchNorm2d-29            [-1, 128, 4, 4]             256
#              ReLU-30            [-1, 128, 4, 4]               0
#            Conv2d-31            [-1, 128, 4, 4]         147,584
#       BatchNorm2d-32            [-1, 128, 4, 4]             256
#              ReLU-33            [-1, 128, 4, 4]               0
#        BasicBlock-34            [-1, 128, 4, 4]               0
#            Conv2d-35            [-1, 256, 2, 2]         295,168
#       BatchNorm2d-36            [-1, 256, 2, 2]             512
#              ReLU-37            [-1, 256, 2, 2]               0
#            Conv2d-38            [-1, 256, 2, 2]         590,080
#       BatchNorm2d-39            [-1, 256, 2, 2]             512
#            Conv2d-40            [-1, 256, 2, 2]          33,024
#       BatchNorm2d-41            [-1, 256, 2, 2]             512
#              ReLU-42            [-1, 256, 2, 2]               0
#        BasicBlock-43            [-1, 256, 2, 2]               0
#            Conv2d-44            [-1, 256, 2, 2]         590,080
#       BatchNorm2d-45            [-1, 256, 2, 2]             512
#              ReLU-46            [-1, 256, 2, 2]               0
#            Conv2d-47            [-1, 256, 2, 2]         590,080
#       BatchNorm2d-48            [-1, 256, 2, 2]             512
#              ReLU-49            [-1, 256, 2, 2]               0
#        BasicBlock-50            [-1, 256, 2, 2]               0
#            Conv2d-51            [-1, 512, 1, 1]       1,180,160
#       BatchNorm2d-52            [-1, 512, 1, 1]           1,024
#              ReLU-53            [-1, 512, 1, 1]               0
#            Conv2d-54            [-1, 512, 1, 1]       2,359,808
#       BatchNorm2d-55            [-1, 512, 1, 1]           1,024
#            Conv2d-56            [-1, 512, 1, 1]         131,584
#       BatchNorm2d-57            [-1, 512, 1, 1]           1,024
#              ReLU-58            [-1, 512, 1, 1]               0
#        BasicBlock-59            [-1, 512, 1, 1]               0
#            Conv2d-60            [-1, 512, 1, 1]       2,359,808
#       BatchNorm2d-61            [-1, 512, 1, 1]           1,024
#              ReLU-62            [-1, 512, 1, 1]               0
#            Conv2d-63            [-1, 512, 1, 1]       2,359,808
#       BatchNorm2d-64            [-1, 512, 1, 1]           1,024
#              ReLU-65            [-1, 512, 1, 1]               0
#        BasicBlock-66            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                   [-1, 10]           5,130
# ================================================================
# Total params: 11,180,170
# Trainable params: 11,180,170
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 1.09
# Params size (MB): 42.65
# Estimated Total Size (MB): 43.74
# ----------------------------------------------------------------
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 14, 14]           3,200
#        BatchNorm2d-2           [-1, 64, 14, 14]             128
#               ReLU-3           [-1, 64, 14, 14]               0
#          MaxPool2d-4             [-1, 64, 7, 7]               0
#             Conv2d-5             [-1, 64, 7, 7]           4,160
#        BatchNorm2d-6             [-1, 64, 7, 7]             128
#               ReLU-7             [-1, 64, 7, 7]               0
#             Conv2d-8             [-1, 64, 7, 7]          36,928
#        BatchNorm2d-9             [-1, 64, 7, 7]             128
#              ReLU-10             [-1, 64, 7, 7]               0
#            Conv2d-11            [-1, 256, 7, 7]          16,640
#       BatchNorm2d-12            [-1, 256, 7, 7]             512
#            Conv2d-13            [-1, 256, 7, 7]          16,640
#       BatchNorm2d-14            [-1, 256, 7, 7]             512
#              ReLU-15            [-1, 256, 7, 7]               0
#        Bottleneck-16            [-1, 256, 7, 7]               0
#            Conv2d-17             [-1, 64, 7, 7]          16,448
#       BatchNorm2d-18             [-1, 64, 7, 7]             128
#              ReLU-19             [-1, 64, 7, 7]               0
#            Conv2d-20             [-1, 64, 7, 7]          36,928
#       BatchNorm2d-21             [-1, 64, 7, 7]             128
#              ReLU-22             [-1, 64, 7, 7]               0
#            Conv2d-23            [-1, 256, 7, 7]          16,640
#       BatchNorm2d-24            [-1, 256, 7, 7]             512
#              ReLU-25            [-1, 256, 7, 7]               0
#        Bottleneck-26            [-1, 256, 7, 7]               0
#            Conv2d-27             [-1, 64, 7, 7]          16,448
#       BatchNorm2d-28             [-1, 64, 7, 7]             128
#              ReLU-29             [-1, 64, 7, 7]               0
#            Conv2d-30             [-1, 64, 7, 7]          36,928
#       BatchNorm2d-31             [-1, 64, 7, 7]             128
#              ReLU-32             [-1, 64, 7, 7]               0
#            Conv2d-33            [-1, 256, 7, 7]          16,640
#       BatchNorm2d-34            [-1, 256, 7, 7]             512
#              ReLU-35            [-1, 256, 7, 7]               0
#        Bottleneck-36            [-1, 256, 7, 7]               0
#            Conv2d-37            [-1, 128, 7, 7]          32,896
#       BatchNorm2d-38            [-1, 128, 7, 7]             256
#              ReLU-39            [-1, 128, 7, 7]               0
#            Conv2d-40            [-1, 128, 4, 4]         147,584
#       BatchNorm2d-41            [-1, 128, 4, 4]             256
#              ReLU-42            [-1, 128, 4, 4]               0
#            Conv2d-43            [-1, 512, 4, 4]          66,048
#       BatchNorm2d-44            [-1, 512, 4, 4]           1,024
#            Conv2d-45            [-1, 512, 4, 4]         131,584
#       BatchNorm2d-46            [-1, 512, 4, 4]           1,024
#              ReLU-47            [-1, 512, 4, 4]               0
#        Bottleneck-48            [-1, 512, 4, 4]               0
#            Conv2d-49            [-1, 128, 4, 4]          65,664
#       BatchNorm2d-50            [-1, 128, 4, 4]             256
#              ReLU-51            [-1, 128, 4, 4]               0
#            Conv2d-52            [-1, 128, 4, 4]         147,584
#       BatchNorm2d-53            [-1, 128, 4, 4]             256
#              ReLU-54            [-1, 128, 4, 4]               0
#            Conv2d-55            [-1, 512, 4, 4]          66,048
#       BatchNorm2d-56            [-1, 512, 4, 4]           1,024
#              ReLU-57            [-1, 512, 4, 4]               0
#        Bottleneck-58            [-1, 512, 4, 4]               0
#            Conv2d-59            [-1, 128, 4, 4]          65,664
#       BatchNorm2d-60            [-1, 128, 4, 4]             256
#              ReLU-61            [-1, 128, 4, 4]               0
#            Conv2d-62            [-1, 128, 4, 4]         147,584
#       BatchNorm2d-63            [-1, 128, 4, 4]             256
#              ReLU-64            [-1, 128, 4, 4]               0
#            Conv2d-65            [-1, 512, 4, 4]          66,048
#       BatchNorm2d-66            [-1, 512, 4, 4]           1,024
#              ReLU-67            [-1, 512, 4, 4]               0
#        Bottleneck-68            [-1, 512, 4, 4]               0
#            Conv2d-69            [-1, 128, 4, 4]          65,664
#       BatchNorm2d-70            [-1, 128, 4, 4]             256
#              ReLU-71            [-1, 128, 4, 4]               0
#            Conv2d-72            [-1, 128, 4, 4]         147,584
#       BatchNorm2d-73            [-1, 128, 4, 4]             256
#              ReLU-74            [-1, 128, 4, 4]               0
#            Conv2d-75            [-1, 512, 4, 4]          66,048
#       BatchNorm2d-76            [-1, 512, 4, 4]           1,024
#              ReLU-77            [-1, 512, 4, 4]               0
#        Bottleneck-78            [-1, 512, 4, 4]               0
#            Conv2d-79            [-1, 256, 4, 4]         131,328
#       BatchNorm2d-80            [-1, 256, 4, 4]             512
#              ReLU-81            [-1, 256, 4, 4]               0
#            Conv2d-82            [-1, 256, 2, 2]         590,080
#       BatchNorm2d-83            [-1, 256, 2, 2]             512
#              ReLU-84            [-1, 256, 2, 2]               0
#            Conv2d-85           [-1, 1024, 2, 2]         263,168
#       BatchNorm2d-86           [-1, 1024, 2, 2]           2,048
#            Conv2d-87           [-1, 1024, 2, 2]         525,312
#       BatchNorm2d-88           [-1, 1024, 2, 2]           2,048
#              ReLU-89           [-1, 1024, 2, 2]               0
#        Bottleneck-90           [-1, 1024, 2, 2]               0
#            Conv2d-91            [-1, 256, 2, 2]         262,400
#       BatchNorm2d-92            [-1, 256, 2, 2]             512
#              ReLU-93            [-1, 256, 2, 2]               0
#            Conv2d-94            [-1, 256, 2, 2]         590,080
#       BatchNorm2d-95            [-1, 256, 2, 2]             512
#              ReLU-96            [-1, 256, 2, 2]               0
#            Conv2d-97           [-1, 1024, 2, 2]         263,168
#       BatchNorm2d-98           [-1, 1024, 2, 2]           2,048
#              ReLU-99           [-1, 1024, 2, 2]               0
#       Bottleneck-100           [-1, 1024, 2, 2]               0
#           Conv2d-101            [-1, 256, 2, 2]         262,400
#      BatchNorm2d-102            [-1, 256, 2, 2]             512
#             ReLU-103            [-1, 256, 2, 2]               0
#           Conv2d-104            [-1, 256, 2, 2]         590,080
#      BatchNorm2d-105            [-1, 256, 2, 2]             512
#             ReLU-106            [-1, 256, 2, 2]               0
#           Conv2d-107           [-1, 1024, 2, 2]         263,168
#      BatchNorm2d-108           [-1, 1024, 2, 2]           2,048
#             ReLU-109           [-1, 1024, 2, 2]               0
#       Bottleneck-110           [-1, 1024, 2, 2]               0
#           Conv2d-111            [-1, 256, 2, 2]         262,400
#      BatchNorm2d-112            [-1, 256, 2, 2]             512
#             ReLU-113            [-1, 256, 2, 2]               0
#           Conv2d-114            [-1, 256, 2, 2]         590,080
#      BatchNorm2d-115            [-1, 256, 2, 2]             512
#             ReLU-116            [-1, 256, 2, 2]               0
#           Conv2d-117           [-1, 1024, 2, 2]         263,168
#      BatchNorm2d-118           [-1, 1024, 2, 2]           2,048
#             ReLU-119           [-1, 1024, 2, 2]               0
#       Bottleneck-120           [-1, 1024, 2, 2]               0
#           Conv2d-121            [-1, 256, 2, 2]         262,400
#      BatchNorm2d-122            [-1, 256, 2, 2]             512
#             ReLU-123            [-1, 256, 2, 2]               0
#           Conv2d-124            [-1, 256, 2, 2]         590,080
#      BatchNorm2d-125            [-1, 256, 2, 2]             512
#             ReLU-126            [-1, 256, 2, 2]               0
#           Conv2d-127           [-1, 1024, 2, 2]         263,168
#      BatchNorm2d-128           [-1, 1024, 2, 2]           2,048
#             ReLU-129           [-1, 1024, 2, 2]               0
#       Bottleneck-130           [-1, 1024, 2, 2]               0
#           Conv2d-131            [-1, 256, 2, 2]         262,400
#      BatchNorm2d-132            [-1, 256, 2, 2]             512
#             ReLU-133            [-1, 256, 2, 2]               0
#           Conv2d-134            [-1, 256, 2, 2]         590,080
#      BatchNorm2d-135            [-1, 256, 2, 2]             512
#             ReLU-136            [-1, 256, 2, 2]               0
#           Conv2d-137           [-1, 1024, 2, 2]         263,168
#      BatchNorm2d-138           [-1, 1024, 2, 2]           2,048
#             ReLU-139           [-1, 1024, 2, 2]               0
#       Bottleneck-140           [-1, 1024, 2, 2]               0
#           Conv2d-141            [-1, 512, 2, 2]         524,800
#      BatchNorm2d-142            [-1, 512, 2, 2]           1,024
#             ReLU-143            [-1, 512, 2, 2]               0
#           Conv2d-144            [-1, 512, 1, 1]       2,359,808
#      BatchNorm2d-145            [-1, 512, 1, 1]           1,024
#             ReLU-146            [-1, 512, 1, 1]               0
#           Conv2d-147           [-1, 2048, 1, 1]       1,050,624
#      BatchNorm2d-148           [-1, 2048, 1, 1]           4,096
#           Conv2d-149           [-1, 2048, 1, 1]       2,099,200
#      BatchNorm2d-150           [-1, 2048, 1, 1]           4,096
#             ReLU-151           [-1, 2048, 1, 1]               0
#       Bottleneck-152           [-1, 2048, 1, 1]               0
#           Conv2d-153            [-1, 512, 1, 1]       1,049,088
#      BatchNorm2d-154            [-1, 512, 1, 1]           1,024
#             ReLU-155            [-1, 512, 1, 1]               0
#           Conv2d-156            [-1, 512, 1, 1]       2,359,808
#      BatchNorm2d-157            [-1, 512, 1, 1]           1,024
#             ReLU-158            [-1, 512, 1, 1]               0
#           Conv2d-159           [-1, 2048, 1, 1]       1,050,624
#      BatchNorm2d-160           [-1, 2048, 1, 1]           4,096
#             ReLU-161           [-1, 2048, 1, 1]               0
#       Bottleneck-162           [-1, 2048, 1, 1]               0
#           Conv2d-163            [-1, 512, 1, 1]       1,049,088
#      BatchNorm2d-164            [-1, 512, 1, 1]           1,024
#             ReLU-165            [-1, 512, 1, 1]               0
#           Conv2d-166            [-1, 512, 1, 1]       2,359,808
#      BatchNorm2d-167            [-1, 512, 1, 1]           1,024
#             ReLU-168            [-1, 512, 1, 1]               0
#           Conv2d-169           [-1, 2048, 1, 1]       1,050,624
#      BatchNorm2d-170           [-1, 2048, 1, 1]           4,096
#             ReLU-171           [-1, 2048, 1, 1]               0
#       Bottleneck-172           [-1, 2048, 1, 1]               0
# AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0
#           Linear-174                   [-1, 10]          20,490
# ================================================================
# Total params: 23,548,810
# Trainable params: 23,548,810
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 5.18
# Params size (MB): 89.83
# Estimated Total Size (MB): 95.02
# ----------------------------------------------------------------

# %% [markdown]
# # **Part 4 (Total 10 pts)**. Train and visualize the results

# %%
# Hyperparameters
random_seed = 7
learning_rate = 0.001
batch_size = 128
num_epochs = 5

# Architecture
NUM_FEATURES = 28*28
NUM_CLASSES = 10

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

def calculate_metric(metric_fn, true_y, pred_y):
    try:
      return metric_fn(true_y, pred_y, average="macro")
    except:
      return metric_fn(true_y, pred_y)

def print_scores(p, r, f1, a, batch_size):
    for name, scores in zip(("precision", "recall", "F1", "accuracy"), (p, r, f1, a)):
        print(f"\t{name.rjust(14, ' ')}: {sum(scores)/batch_size:.4f}")

# %% [markdown]
# To use GPU, features and targets data also should be sended to GPU as the model.<br>
# Plot the training loss and validation loss for each epoch.

# %%
def compute_accuracy(model, data_loader):
    correct_pred, num_examples = 0, 0
    for i, (features, targets) in enumerate(data_loader):

        logits, probas = model(features)
        _, predicted_labels = torch.max(probas, 1)
        num_examples += targets.size(0)
        correct_pred += (predicted_labels == targets).sum()
    return correct_pred.float()/num_examples * 100


def train(model, optimizer):
    # List that stacking the train loss / validation loss for each epoch
    train_losses = []
    validation_losses = []

    val_batches = len(test_loader)

    start_time = time.time()
    for epoch in range(num_epochs):
        total_loss = 0

        # ----------------- TRAINING  --------------------
        # set model to training

        train_loader = get_train_loader()
        batches = len(train_loader)

        model.train()
        for batch_idx, (features, targets) in enumerate(train_loader):
            # To use GPU, sending a dataset to GPU.
            features, targets = features.to(device), targets.to(device)
            logits = model(features)
            loss = F.cross_entropy(logits, targets)
            optimizer.zero_grad()

            loss.backward()
            optimizer.step()

            current_loss = loss.item()
            total_loss += current_loss

            if not batch_idx % 10:
                print ('Epoch: %d/%d | Batch %d/%d | loss: %.4f' %(epoch+1, num_epochs, batch_idx, len(train_loader), current_loss))

        # ----------------- VALIDATION  -----------------
        val_losses = 0
        precision, recall, f1, accuracy = [], [], [], []

        # set model to evaluating (testing)

        model.eval()
        with torch.no_grad():
            for batch_idx, (features, targets) in enumerate(test_loader):
                # To use GPU, sending a dataset to GPU.
                features, targets = features.to(device), targets.to(device)
                logits = model(features) # this get's the prediction from the network

                # IMPORTANT! To avoid an error, Use item method for moving data to cpu
                val_losses += F.cross_entropy(logits, targets).item()

                predicted_classes = torch.max(logits, 1)[1] # get class from network's prediction

                # calculate P/R/F1/A metrics for batch
                for acc, metric in zip((precision, recall, f1, accuracy),
                                    (precision_score, recall_score, f1_score, accuracy_score)):
                    acc.append(
                        calculate_metric(metric, targets.cpu(), predicted_classes.cpu())
                    )

        print(f"Epoch {epoch+1}/{num_epochs}, training loss: {total_loss/batches}, validation loss: {val_losses/val_batches}")
        print_scores(precision, recall, f1, accuracy, val_batches)
        train_losses.append(total_loss/batches) # for plotting training loss curve
        validation_losses.append(val_losses/val_batches) # for plotting validation loss curve

    print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))

    # Plot training loss for each epoch
    epoch_list = [i+1 for i in range(num_epochs)]

    plt.plot(epoch_list, train_losses, label='Training loss')
    plt.plot(epoch_list, validation_losses, label='Validation loss')
    plt.xlabel('Epochs')
    plt.ylabel("Average Loss")

    plt.xticks(epoch_list)
    plt.grid(visible=True)
    plt.legend()

    return train_losses

# %% [markdown]
# ## **Step 1 (Total 5 pts)**. Train the ResNet18 and display the training and testing losses for ResNet18 as a graph.
# ### **$\color{red}{\text{ToDo}}$**: Train your ResNet18 using below code and plot the training loss and validation loss against the epochs. (You can modify the training code as needed.)

# %%
num_epochs = 5
optimizer = torch.optim.Adam(resnet18_model.parameters(), lr=learning_rate)

losses = train(resnet18_model, optimizer)
# Out:
# Epoch: 1/5 | Batch 0/938 | loss: 2.6291
# Epoch: 1/5 | Batch 10/938 | loss: 1.1720
# Epoch: 1/5 | Batch 20/938 | loss: 0.7852
# Epoch: 1/5 | Batch 30/938 | loss: 0.9591
# Epoch: 1/5 | Batch 40/938 | loss: 0.7013
# Epoch: 1/5 | Batch 50/938 | loss: 0.6535
# Epoch: 1/5 | Batch 60/938 | loss: 0.5958
# Epoch: 1/5 | Batch 70/938 | loss: 0.6053
# Epoch: 1/5 | Batch 80/938 | loss: 0.7855
# Epoch: 1/5 | Batch 90/938 | loss: 0.6017
# Epoch: 1/5 | Batch 100/938 | loss: 0.7556
# Epoch: 1/5 | Batch 110/938 | loss: 0.8089
# Epoch: 1/5 | Batch 120/938 | loss: 0.7158
# Epoch: 1/5 | Batch 130/938 | loss: 0.7979
# Epoch: 1/5 | Batch 140/938 | loss: 0.5972
# Epoch: 1/5 | Batch 150/938 | loss: 0.4121
# Epoch: 1/5 | Batch 160/938 | loss: 0.3905
# Epoch: 1/5 | Batch 170/938 | loss: 0.5765
# Epoch: 1/5 | Batch 180/938 | loss: 0.4911
# Epoch: 1/5 | Batch 190/938 | loss: 0.6323
# Epoch: 1/5 | Batch 200/938 | loss: 0.5085
# Epoch: 1/5 | Batch 210/938 | loss: 0.5880
# Epoch: 1/5 | Batch 220/938 | loss: 0.5585
# Epoch: 1/5 | Batch 230/938 | loss: 0.4149
# Epoch: 1/5 | Batch 240/938 | loss: 0.5538
# Epoch: 1/5 | Batch 250/938 | loss: 0.3359
# Epoch: 1/5 | Batch 260/938 | loss: 0.5292
# Epoch: 1/5 | Batch 270/938 | loss: 0.2763
# Epoch: 1/5 | Batch 280/938 | loss: 0.4447
# Epoch: 1/5 | Batch 290/938 | loss: 0.2392
# Epoch: 1/5 | Batch 300/938 | loss: 0.3889
# Epoch: 1/5 | Batch 310/938 | loss: 0.5149
# Epoch: 1/5 | Batch 320/938 | loss: 0.4232
# Epoch: 1/5 | Batch 330/938 | loss: 0.4948
# Epoch: 1/5 | Batch 340/938 | loss: 0.3110
# Epoch: 1/5 | Batch 350/938 | loss: 0.3522
# Epoch: 1/5 | Batch 360/938 | loss: 0.4481
# Epoch: 1/5 | Batch 370/938 | loss: 0.5343
# Epoch: 1/5 | Batch 380/938 | loss: 0.4444
# Epoch: 1/5 | Batch 390/938 | loss: 0.3229
# Epoch: 1/5 | Batch 400/938 | loss: 0.5239
# Epoch: 1/5 | Batch 410/938 | loss: 0.3714
# Epoch: 1/5 | Batch 420/938 | loss: 0.6973
# Epoch: 1/5 | Batch 430/938 | loss: 0.2870
# Epoch: 1/5 | Batch 440/938 | loss: 0.5140
# Epoch: 1/5 | Batch 450/938 | loss: 0.2366
# Epoch: 1/5 | Batch 460/938 | loss: 0.6665
# Epoch: 1/5 | Batch 470/938 | loss: 0.3128
# Epoch: 1/5 | Batch 480/938 | loss: 0.3587
# Epoch: 1/5 | Batch 490/938 | loss: 0.4730
# Epoch: 1/5 | Batch 500/938 | loss: 0.3371
# Epoch: 1/5 | Batch 510/938 | loss: 0.5030
# Epoch: 1/5 | Batch 520/938 | loss: 0.6867
# Epoch: 1/5 | Batch 530/938 | loss: 0.3404
# Epoch: 1/5 | Batch 540/938 | loss: 0.2805
# Epoch: 1/5 | Batch 550/938 | loss: 0.5055
# Epoch: 1/5 | Batch 560/938 | loss: 0.4165
# Epoch: 1/5 | Batch 570/938 | loss: 0.3518
# Epoch: 1/5 | Batch 580/938 | loss: 0.4300
# Epoch: 1/5 | Batch 590/938 | loss: 0.4630
# Epoch: 1/5 | Batch 600/938 | loss: 0.3314
# Epoch: 1/5 | Batch 610/938 | loss: 0.2537
# Epoch: 1/5 | Batch 620/938 | loss: 0.4705
# Epoch: 1/5 | Batch 630/938 | loss: 0.3494
# Epoch: 1/5 | Batch 640/938 | loss: 0.5899
# Epoch: 1/5 | Batch 650/938 | loss: 0.4291
# Epoch: 1/5 | Batch 660/938 | loss: 0.4369
# Epoch: 1/5 | Batch 670/938 | loss: 0.4010
# Epoch: 1/5 | Batch 680/938 | loss: 0.5773
# Epoch: 1/5 | Batch 690/938 | loss: 0.5205
# Epoch: 1/5 | Batch 700/938 | loss: 0.3671
# Epoch: 1/5 | Batch 710/938 | loss: 0.4252
# Epoch: 1/5 | Batch 720/938 | loss: 0.3469
# Epoch: 1/5 | Batch 730/938 | loss: 0.6399
# Epoch: 1/5 | Batch 740/938 | loss: 0.2638
# Epoch: 1/5 | Batch 750/938 | loss: 0.2911
# Epoch: 1/5 | Batch 760/938 | loss: 0.4716
# Epoch: 1/5 | Batch 770/938 | loss: 0.2702
# Epoch: 1/5 | Batch 780/938 | loss: 0.5044
# Epoch: 1/5 | Batch 790/938 | loss: 0.4277
# Epoch: 1/5 | Batch 800/938 | loss: 0.4887
# Epoch: 1/5 | Batch 810/938 | loss: 0.4095
# Epoch: 1/5 | Batch 820/938 | loss: 0.3322
# Epoch: 1/5 | Batch 830/938 | loss: 0.3091
# Epoch: 1/5 | Batch 840/938 | loss: 0.4159
# Epoch: 1/5 | Batch 850/938 | loss: 0.3095
# Epoch: 1/5 | Batch 860/938 | loss: 0.4316
# Epoch: 1/5 | Batch 870/938 | loss: 0.4596
# Epoch: 1/5 | Batch 880/938 | loss: 0.2615
# Epoch: 1/5 | Batch 890/938 | loss: 0.2542
# Epoch: 1/5 | Batch 900/938 | loss: 0.4202
# Epoch: 1/5 | Batch 910/938 | loss: 0.2947
# Epoch: 1/5 | Batch 920/938 | loss: 0.3251
# Epoch: 1/5 | Batch 930/938 | loss: 0.2857
# Epoch 1/5, training loss: 0.4639391449532275, validation loss: 0.3624504666989017
# 	     precision: 0.8698
# 	        recall: 0.8643
# 	            F1: 0.8543
# 	      accuracy: 0.8622
# Epoch: 2/5 | Batch 0/938 | loss: 0.3713
# Epoch: 2/5 | Batch 10/938 | loss: 0.2502
# Epoch: 2/5 | Batch 20/938 | loss: 0.2750
# Epoch: 2/5 | Batch 30/938 | loss: 0.4864
# Epoch: 2/5 | Batch 40/938 | loss: 0.2743
# Epoch: 2/5 | Batch 50/938 | loss: 0.3040
# Epoch: 2/5 | Batch 60/938 | loss: 0.2110
# Epoch: 2/5 | Batch 70/938 | loss: 0.3728
# Epoch: 2/5 | Batch 80/938 | loss: 0.3821
# Epoch: 2/5 | Batch 90/938 | loss: 0.1877
# Epoch: 2/5 | Batch 100/938 | loss: 0.2973
# Epoch: 2/5 | Batch 110/938 | loss: 0.2618
# Epoch: 2/5 | Batch 120/938 | loss: 0.2799
# Epoch: 2/5 | Batch 130/938 | loss: 0.3113
# Epoch: 2/5 | Batch 140/938 | loss: 0.3735
# Epoch: 2/5 | Batch 150/938 | loss: 0.3927
# Epoch: 2/5 | Batch 160/938 | loss: 0.3236
# Epoch: 2/5 | Batch 170/938 | loss: 0.3622
# Epoch: 2/5 | Batch 180/938 | loss: 0.2576
# Epoch: 2/5 | Batch 190/938 | loss: 0.3755
# Epoch: 2/5 | Batch 200/938 | loss: 0.3529
# Epoch: 2/5 | Batch 210/938 | loss: 0.4241
# Epoch: 2/5 | Batch 220/938 | loss: 0.2921
# Epoch: 2/5 | Batch 230/938 | loss: 0.1658
# Epoch: 2/5 | Batch 240/938 | loss: 0.2887
# Epoch: 2/5 | Batch 250/938 | loss: 0.3563
# Epoch: 2/5 | Batch 260/938 | loss: 0.3431
# Epoch: 2/5 | Batch 270/938 | loss: 0.3058
# Epoch: 2/5 | Batch 280/938 | loss: 0.4341
# Epoch: 2/5 | Batch 290/938 | loss: 0.1186
# Epoch: 2/5 | Batch 300/938 | loss: 0.4737
# Epoch: 2/5 | Batch 310/938 | loss: 0.4353
# Epoch: 2/5 | Batch 320/938 | loss: 0.3613
# Epoch: 2/5 | Batch 330/938 | loss: 0.2988
# Epoch: 2/5 | Batch 340/938 | loss: 0.2717
# Epoch: 2/5 | Batch 350/938 | loss: 0.1350
# Epoch: 2/5 | Batch 360/938 | loss: 0.3723
# Epoch: 2/5 | Batch 370/938 | loss: 0.2930
# Epoch: 2/5 | Batch 380/938 | loss: 0.3477
# Epoch: 2/5 | Batch 390/938 | loss: 0.4579
# Epoch: 2/5 | Batch 400/938 | loss: 0.2577
# Epoch: 2/5 | Batch 410/938 | loss: 0.3308
# Epoch: 2/5 | Batch 420/938 | loss: 0.2336
# Epoch: 2/5 | Batch 430/938 | loss: 0.3070
# Epoch: 2/5 | Batch 440/938 | loss: 0.3766
# Epoch: 2/5 | Batch 450/938 | loss: 0.3690
# Epoch: 2/5 | Batch 460/938 | loss: 0.2023
# Epoch: 2/5 | Batch 470/938 | loss: 0.3173
# Epoch: 2/5 | Batch 480/938 | loss: 0.2549
# Epoch: 2/5 | Batch 490/938 | loss: 0.4067
# Epoch: 2/5 | Batch 500/938 | loss: 0.3737
# Epoch: 2/5 | Batch 510/938 | loss: 0.4428
# Epoch: 2/5 | Batch 520/938 | loss: 0.3770
# Epoch: 2/5 | Batch 530/938 | loss: 0.3955
# Epoch: 2/5 | Batch 540/938 | loss: 0.2342
# Epoch: 2/5 | Batch 550/938 | loss: 0.3524
# Epoch: 2/5 | Batch 560/938 | loss: 0.2844
# Epoch: 2/5 | Batch 570/938 | loss: 0.2358
# Epoch: 2/5 | Batch 580/938 | loss: 0.4929
# Epoch: 2/5 | Batch 590/938 | loss: 0.2670
# Epoch: 2/5 | Batch 600/938 | loss: 0.4060
# Epoch: 2/5 | Batch 610/938 | loss: 0.4867
# Epoch: 2/5 | Batch 620/938 | loss: 0.2296
# Epoch: 2/5 | Batch 630/938 | loss: 0.3064
# Epoch: 2/5 | Batch 640/938 | loss: 0.2728
# Epoch: 2/5 | Batch 650/938 | loss: 0.3273
# Epoch: 2/5 | Batch 660/938 | loss: 0.3449
# Epoch: 2/5 | Batch 670/938 | loss: 0.1865
# Epoch: 2/5 | Batch 680/938 | loss: 0.3946
# Epoch: 2/5 | Batch 690/938 | loss: 0.2978
# Epoch: 2/5 | Batch 700/938 | loss: 0.4657
# Epoch: 2/5 | Batch 710/938 | loss: 0.2396
# Epoch: 2/5 | Batch 720/938 | loss: 0.5488
# Epoch: 2/5 | Batch 730/938 | loss: 0.5158
# Epoch: 2/5 | Batch 740/938 | loss: 0.1737
# Epoch: 2/5 | Batch 750/938 | loss: 0.1819
# Epoch: 2/5 | Batch 760/938 | loss: 0.1759
# Epoch: 2/5 | Batch 770/938 | loss: 0.2941
# Epoch: 2/5 | Batch 780/938 | loss: 0.4492
# Epoch: 2/5 | Batch 790/938 | loss: 0.5100
# Epoch: 2/5 | Batch 800/938 | loss: 0.3045
# Epoch: 2/5 | Batch 810/938 | loss: 0.3971
# Epoch: 2/5 | Batch 820/938 | loss: 0.3376
# Epoch: 2/5 | Batch 830/938 | loss: 0.2462
# Epoch: 2/5 | Batch 840/938 | loss: 0.2646
# Epoch: 2/5 | Batch 850/938 | loss: 0.2619
# Epoch: 2/5 | Batch 860/938 | loss: 0.3264
# Epoch: 2/5 | Batch 870/938 | loss: 0.4537
# Epoch: 2/5 | Batch 880/938 | loss: 0.3976
# Epoch: 2/5 | Batch 890/938 | loss: 0.1691
# Epoch: 2/5 | Batch 900/938 | loss: 0.2475
# Epoch: 2/5 | Batch 910/938 | loss: 0.2600
# Epoch: 2/5 | Batch 920/938 | loss: 0.2452
# Epoch: 2/5 | Batch 930/938 | loss: 0.6959
# Epoch 2/5, training loss: 0.328448968949412, validation loss: 0.32793365988382106
# 	     precision: 0.8823
# 	        recall: 0.8842
# 	            F1: 0.8711
# 	      accuracy: 0.8817
# Epoch: 3/5 | Batch 0/938 | loss: 0.3711
# Epoch: 3/5 | Batch 10/938 | loss: 0.3670
# Epoch: 3/5 | Batch 20/938 | loss: 0.3000
# Epoch: 3/5 | Batch 30/938 | loss: 0.3909
# Epoch: 3/5 | Batch 40/938 | loss: 0.3751
# Epoch: 3/5 | Batch 50/938 | loss: 0.2360
# Epoch: 3/5 | Batch 60/938 | loss: 0.2020
# Epoch: 3/5 | Batch 70/938 | loss: 0.2201
# Epoch: 3/5 | Batch 80/938 | loss: 0.3613
# Epoch: 3/5 | Batch 90/938 | loss: 0.1711
# Epoch: 3/5 | Batch 100/938 | loss: 0.2203
# Epoch: 3/5 | Batch 110/938 | loss: 0.2550
# Epoch: 3/5 | Batch 120/938 | loss: 0.1709
# Epoch: 3/5 | Batch 130/938 | loss: 0.4451
# Epoch: 3/5 | Batch 140/938 | loss: 0.3439
# Epoch: 3/5 | Batch 150/938 | loss: 0.2714
# Epoch: 3/5 | Batch 160/938 | loss: 0.1977
# Epoch: 3/5 | Batch 170/938 | loss: 0.3471
# Epoch: 3/5 | Batch 180/938 | loss: 0.2860
# Epoch: 3/5 | Batch 190/938 | loss: 0.3206
# Epoch: 3/5 | Batch 200/938 | loss: 0.3000
# Epoch: 3/5 | Batch 210/938 | loss: 0.3445
# Epoch: 3/5 | Batch 220/938 | loss: 0.3094
# Epoch: 3/5 | Batch 230/938 | loss: 0.2439
# Epoch: 3/5 | Batch 240/938 | loss: 0.2006
# Epoch: 3/5 | Batch 250/938 | loss: 0.4152
# Epoch: 3/5 | Batch 260/938 | loss: 0.2921
# Epoch: 3/5 | Batch 270/938 | loss: 0.3602
# Epoch: 3/5 | Batch 280/938 | loss: 0.3950
# Epoch: 3/5 | Batch 290/938 | loss: 0.3548
# Epoch: 3/5 | Batch 300/938 | loss: 0.2325
# Epoch: 3/5 | Batch 310/938 | loss: 0.3717
# Epoch: 3/5 | Batch 320/938 | loss: 0.2103
# Epoch: 3/5 | Batch 330/938 | loss: 0.2559
# Epoch: 3/5 | Batch 340/938 | loss: 0.2552
# Epoch: 3/5 | Batch 350/938 | loss: 0.2835
# Epoch: 3/5 | Batch 360/938 | loss: 0.2052
# Epoch: 3/5 | Batch 370/938 | loss: 0.2916
# Epoch: 3/5 | Batch 380/938 | loss: 0.2348
# Epoch: 3/5 | Batch 390/938 | loss: 0.3227
# Epoch: 3/5 | Batch 400/938 | loss: 0.3219
# Epoch: 3/5 | Batch 410/938 | loss: 0.3936
# Epoch: 3/5 | Batch 420/938 | loss: 0.3568
# Epoch: 3/5 | Batch 430/938 | loss: 0.2284
# Epoch: 3/5 | Batch 440/938 | loss: 0.3312
# Epoch: 3/5 | Batch 450/938 | loss: 0.5235
# Epoch: 3/5 | Batch 460/938 | loss: 0.3554
# Epoch: 3/5 | Batch 470/938 | loss: 0.2368
# Epoch: 3/5 | Batch 480/938 | loss: 0.3300
# Epoch: 3/5 | Batch 490/938 | loss: 0.1673
# Epoch: 3/5 | Batch 500/938 | loss: 0.3990
# Epoch: 3/5 | Batch 510/938 | loss: 0.2825
# Epoch: 3/5 | Batch 520/938 | loss: 0.3676
# Epoch: 3/5 | Batch 530/938 | loss: 0.3661
# Epoch: 3/5 | Batch 540/938 | loss: 0.2293
# Epoch: 3/5 | Batch 550/938 | loss: 0.2438
# Epoch: 3/5 | Batch 560/938 | loss: 0.1787
# Epoch: 3/5 | Batch 570/938 | loss: 0.3439
# Epoch: 3/5 | Batch 580/938 | loss: 0.2451
# Epoch: 3/5 | Batch 590/938 | loss: 0.2622
# Epoch: 3/5 | Batch 600/938 | loss: 0.2832
# Epoch: 3/5 | Batch 610/938 | loss: 0.3456
# Epoch: 3/5 | Batch 620/938 | loss: 0.1348
# Epoch: 3/5 | Batch 630/938 | loss: 0.3082
# Epoch: 3/5 | Batch 640/938 | loss: 0.1575
# Epoch: 3/5 | Batch 650/938 | loss: 0.0943
# Epoch: 3/5 | Batch 660/938 | loss: 0.1194
# Epoch: 3/5 | Batch 670/938 | loss: 0.2746
# Epoch: 3/5 | Batch 680/938 | loss: 0.3260
# Epoch: 3/5 | Batch 690/938 | loss: 0.3956
# Epoch: 3/5 | Batch 700/938 | loss: 0.3566
# Epoch: 3/5 | Batch 710/938 | loss: 0.2359
# Epoch: 3/5 | Batch 720/938 | loss: 0.1915
# Epoch: 3/5 | Batch 730/938 | loss: 0.2615
# Epoch: 3/5 | Batch 740/938 | loss: 0.2956
# Epoch: 3/5 | Batch 750/938 | loss: 0.2892
# Epoch: 3/5 | Batch 760/938 | loss: 0.2441
# Epoch: 3/5 | Batch 770/938 | loss: 0.1760
# Epoch: 3/5 | Batch 780/938 | loss: 0.2870
# Epoch: 3/5 | Batch 790/938 | loss: 0.3236
# Epoch: 3/5 | Batch 800/938 | loss: 0.1581
# Epoch: 3/5 | Batch 810/938 | loss: 0.2513
# Epoch: 3/5 | Batch 820/938 | loss: 0.3080
# Epoch: 3/5 | Batch 830/938 | loss: 0.1632
# Epoch: 3/5 | Batch 840/938 | loss: 0.2848
# Epoch: 3/5 | Batch 850/938 | loss: 0.3154
# Epoch: 3/5 | Batch 860/938 | loss: 0.2575
# Epoch: 3/5 | Batch 870/938 | loss: 0.4388
# Epoch: 3/5 | Batch 880/938 | loss: 0.3476
# Epoch: 3/5 | Batch 890/938 | loss: 0.3348
# Epoch: 3/5 | Batch 900/938 | loss: 0.3788
# Epoch: 3/5 | Batch 910/938 | loss: 0.2460
# Epoch: 3/5 | Batch 920/938 | loss: 0.2523
# Epoch: 3/5 | Batch 930/938 | loss: 0.2511
# Epoch 3/5, training loss: 0.28792739862095573, validation loss: 0.34448639982065576
# 	     precision: 0.8813
# 	        recall: 0.8708
# 	            F1: 0.8598
# 	      accuracy: 0.8719
# Epoch: 4/5 | Batch 0/938 | loss: 0.4477
# Epoch: 4/5 | Batch 10/938 | loss: 0.2081
# Epoch: 4/5 | Batch 20/938 | loss: 0.3358
# Epoch: 4/5 | Batch 30/938 | loss: 0.1520
# Epoch: 4/5 | Batch 40/938 | loss: 0.2061
# Epoch: 4/5 | Batch 50/938 | loss: 0.3192
# Epoch: 4/5 | Batch 60/938 | loss: 0.3104
# Epoch: 4/5 | Batch 70/938 | loss: 0.1344
# Epoch: 4/5 | Batch 80/938 | loss: 0.2825
# Epoch: 4/5 | Batch 90/938 | loss: 0.2832
# Epoch: 4/5 | Batch 100/938 | loss: 0.1699
# Epoch: 4/5 | Batch 110/938 | loss: 0.2455
# Epoch: 4/5 | Batch 120/938 | loss: 0.3391
# Epoch: 4/5 | Batch 130/938 | loss: 0.1154
# Epoch: 4/5 | Batch 140/938 | loss: 0.1362
# Epoch: 4/5 | Batch 150/938 | loss: 0.1661
# Epoch: 4/5 | Batch 160/938 | loss: 0.2305
# Epoch: 4/5 | Batch 170/938 | loss: 0.2780
# Epoch: 4/5 | Batch 180/938 | loss: 0.4137
# Epoch: 4/5 | Batch 190/938 | loss: 0.2926
# Epoch: 4/5 | Batch 200/938 | loss: 0.2068
# Epoch: 4/5 | Batch 210/938 | loss: 0.1980
# Epoch: 4/5 | Batch 220/938 | loss: 0.2450
# Epoch: 4/5 | Batch 230/938 | loss: 0.2934
# Epoch: 4/5 | Batch 240/938 | loss: 0.1318
# Epoch: 4/5 | Batch 250/938 | loss: 0.3904
# Epoch: 4/5 | Batch 260/938 | loss: 0.1823
# Epoch: 4/5 | Batch 270/938 | loss: 0.2423
# Epoch: 4/5 | Batch 280/938 | loss: 0.2828
# Epoch: 4/5 | Batch 290/938 | loss: 0.2607
# Epoch: 4/5 | Batch 300/938 | loss: 0.1836
# Epoch: 4/5 | Batch 310/938 | loss: 0.2780
# Epoch: 4/5 | Batch 320/938 | loss: 0.3087
# Epoch: 4/5 | Batch 330/938 | loss: 0.5648
# Epoch: 4/5 | Batch 340/938 | loss: 0.5182
# Epoch: 4/5 | Batch 350/938 | loss: 0.2588
# Epoch: 4/5 | Batch 360/938 | loss: 0.1398
# Epoch: 4/5 | Batch 370/938 | loss: 0.2116
# Epoch: 4/5 | Batch 380/938 | loss: 0.2823
# Epoch: 4/5 | Batch 390/938 | loss: 0.3068
# Epoch: 4/5 | Batch 400/938 | loss: 0.4250
# Epoch: 4/5 | Batch 410/938 | loss: 0.2641
# Epoch: 4/5 | Batch 420/938 | loss: 0.2271
# Epoch: 4/5 | Batch 430/938 | loss: 0.1991
# Epoch: 4/5 | Batch 440/938 | loss: 0.3127
# Epoch: 4/5 | Batch 450/938 | loss: 0.2820
# Epoch: 4/5 | Batch 460/938 | loss: 0.2245
# Epoch: 4/5 | Batch 470/938 | loss: 0.1344
# Epoch: 4/5 | Batch 480/938 | loss: 0.1312
# Epoch: 4/5 | Batch 490/938 | loss: 0.2422
# Epoch: 4/5 | Batch 500/938 | loss: 0.2797
# Epoch: 4/5 | Batch 510/938 | loss: 0.4206
# Epoch: 4/5 | Batch 520/938 | loss: 0.1828
# Epoch: 4/5 | Batch 530/938 | loss: 0.4582
# Epoch: 4/5 | Batch 540/938 | loss: 0.1847
# Epoch: 4/5 | Batch 550/938 | loss: 0.3075
# Epoch: 4/5 | Batch 560/938 | loss: 0.4537
# Epoch: 4/5 | Batch 570/938 | loss: 0.2517
# Epoch: 4/5 | Batch 580/938 | loss: 0.2539
# Epoch: 4/5 | Batch 590/938 | loss: 0.2835
# Epoch: 4/5 | Batch 600/938 | loss: 0.3266
# Epoch: 4/5 | Batch 610/938 | loss: 0.1293
# Epoch: 4/5 | Batch 620/938 | loss: 0.1732
# Epoch: 4/5 | Batch 630/938 | loss: 0.3167
# Epoch: 4/5 | Batch 640/938 | loss: 0.2106
# Epoch: 4/5 | Batch 650/938 | loss: 0.1973
# Epoch: 4/5 | Batch 660/938 | loss: 0.3096
# Epoch: 4/5 | Batch 670/938 | loss: 0.3148
# Epoch: 4/5 | Batch 680/938 | loss: 0.2974
# Epoch: 4/5 | Batch 690/938 | loss: 0.2653
# Epoch: 4/5 | Batch 700/938 | loss: 0.2992
# Epoch: 4/5 | Batch 710/938 | loss: 0.2383
# Epoch: 4/5 | Batch 720/938 | loss: 0.3514
# Epoch: 4/5 | Batch 730/938 | loss: 0.4496
# Epoch: 4/5 | Batch 740/938 | loss: 0.1600
# Epoch: 4/5 | Batch 750/938 | loss: 0.2728
# Epoch: 4/5 | Batch 760/938 | loss: 0.2921
# Epoch: 4/5 | Batch 770/938 | loss: 0.2476
# Epoch: 4/5 | Batch 780/938 | loss: 0.1899
# Epoch: 4/5 | Batch 790/938 | loss: 0.2899
# Epoch: 4/5 | Batch 800/938 | loss: 0.1491
# Epoch: 4/5 | Batch 810/938 | loss: 0.2860
# Epoch: 4/5 | Batch 820/938 | loss: 0.2402
# Epoch: 4/5 | Batch 830/938 | loss: 0.2382
# Epoch: 4/5 | Batch 840/938 | loss: 0.2871
# Epoch: 4/5 | Batch 850/938 | loss: 0.1360
# Epoch: 4/5 | Batch 860/938 | loss: 0.2666
# Epoch: 4/5 | Batch 870/938 | loss: 0.3580
# Epoch: 4/5 | Batch 880/938 | loss: 0.2059
# Epoch: 4/5 | Batch 890/938 | loss: 0.2588
# Epoch: 4/5 | Batch 900/938 | loss: 0.2335
# Epoch: 4/5 | Batch 910/938 | loss: 0.2851
# Epoch: 4/5 | Batch 920/938 | loss: 0.3705
# Epoch: 4/5 | Batch 930/938 | loss: 0.2030
# Epoch 4/5, training loss: 0.2622431893306755, validation loss: 0.27665130703882046
# 	     precision: 0.8939
# 	        recall: 0.8958
# 	            F1: 0.8858
# 	      accuracy: 0.8959
# Epoch: 5/5 | Batch 0/938 | loss: 0.4104
# Epoch: 5/5 | Batch 10/938 | loss: 0.2814
# Epoch: 5/5 | Batch 20/938 | loss: 0.2477
# Epoch: 5/5 | Batch 30/938 | loss: 0.2292
# Epoch: 5/5 | Batch 40/938 | loss: 0.1235
# Epoch: 5/5 | Batch 50/938 | loss: 0.1117
# Epoch: 5/5 | Batch 60/938 | loss: 0.2490
# Epoch: 5/5 | Batch 70/938 | loss: 0.2369
# Epoch: 5/5 | Batch 80/938 | loss: 0.1910
# Epoch: 5/5 | Batch 90/938 | loss: 0.2368
# Epoch: 5/5 | Batch 100/938 | loss: 0.1170
# Epoch: 5/5 | Batch 110/938 | loss: 0.3027
# Epoch: 5/5 | Batch 120/938 | loss: 0.2403
# Epoch: 5/5 | Batch 130/938 | loss: 0.2210
# Epoch: 5/5 | Batch 140/938 | loss: 0.1246
# Epoch: 5/5 | Batch 150/938 | loss: 0.1807
# Epoch: 5/5 | Batch 160/938 | loss: 0.1303
# Epoch: 5/5 | Batch 170/938 | loss: 0.2199
# Epoch: 5/5 | Batch 180/938 | loss: 0.4489
# Epoch: 5/5 | Batch 190/938 | loss: 0.4034
# Epoch: 5/5 | Batch 200/938 | loss: 0.3223
# Epoch: 5/5 | Batch 210/938 | loss: 0.3176
# Epoch: 5/5 | Batch 220/938 | loss: 0.1245
# Epoch: 5/5 | Batch 230/938 | loss: 0.1120
# Epoch: 5/5 | Batch 240/938 | loss: 0.2537
# Epoch: 5/5 | Batch 250/938 | loss: 0.4479
# Epoch: 5/5 | Batch 260/938 | loss: 0.1995
# Epoch: 5/5 | Batch 270/938 | loss: 0.1810
# Epoch: 5/5 | Batch 280/938 | loss: 0.2363
# Epoch: 5/5 | Batch 290/938 | loss: 0.1310
# Epoch: 5/5 | Batch 300/938 | loss: 0.2736
# Epoch: 5/5 | Batch 310/938 | loss: 0.1861
# Epoch: 5/5 | Batch 320/938 | loss: 0.2613
# Epoch: 5/5 | Batch 330/938 | loss: 0.2591
# Epoch: 5/5 | Batch 340/938 | loss: 0.1319
# Epoch: 5/5 | Batch 350/938 | loss: 0.1752
# Epoch: 5/5 | Batch 360/938 | loss: 0.1594
# Epoch: 5/5 | Batch 370/938 | loss: 0.2265
# Epoch: 5/5 | Batch 380/938 | loss: 0.3702
# Epoch: 5/5 | Batch 390/938 | loss: 0.1840
# Epoch: 5/5 | Batch 400/938 | loss: 0.4285
# Epoch: 5/5 | Batch 410/938 | loss: 0.2347
# Epoch: 5/5 | Batch 420/938 | loss: 0.3623
# Epoch: 5/5 | Batch 430/938 | loss: 0.3215
# Epoch: 5/5 | Batch 440/938 | loss: 0.5420
# Epoch: 5/5 | Batch 450/938 | loss: 0.2234
# Epoch: 5/5 | Batch 460/938 | loss: 0.2886
# Epoch: 5/5 | Batch 470/938 | loss: 0.3780
# Epoch: 5/5 | Batch 480/938 | loss: 0.2784
# Epoch: 5/5 | Batch 490/938 | loss: 0.2651
# Epoch: 5/5 | Batch 500/938 | loss: 0.2654
# Epoch: 5/5 | Batch 510/938 | loss: 0.4414
# Epoch: 5/5 | Batch 520/938 | loss: 0.1359
# Epoch: 5/5 | Batch 530/938 | loss: 0.1808
# Epoch: 5/5 | Batch 540/938 | loss: 0.1981
# Epoch: 5/5 | Batch 550/938 | loss: 0.2637
# Epoch: 5/5 | Batch 560/938 | loss: 0.2490
# Epoch: 5/5 | Batch 570/938 | loss: 0.1516
# Epoch: 5/5 | Batch 580/938 | loss: 0.2831
# Epoch: 5/5 | Batch 590/938 | loss: 0.1853
# Epoch: 5/5 | Batch 600/938 | loss: 0.2688
# Epoch: 5/5 | Batch 610/938 | loss: 0.2959
# Epoch: 5/5 | Batch 620/938 | loss: 0.1508
# Epoch: 5/5 | Batch 630/938 | loss: 0.2772
# Epoch: 5/5 | Batch 640/938 | loss: 0.2282
# Epoch: 5/5 | Batch 650/938 | loss: 0.4270
# Epoch: 5/5 | Batch 660/938 | loss: 0.2036
# Epoch: 5/5 | Batch 670/938 | loss: 0.2086
# Epoch: 5/5 | Batch 680/938 | loss: 0.3127
# Epoch: 5/5 | Batch 690/938 | loss: 0.3519
# Epoch: 5/5 | Batch 700/938 | loss: 0.2954
# Epoch: 5/5 | Batch 710/938 | loss: 0.3161
# Epoch: 5/5 | Batch 720/938 | loss: 0.3560
# Epoch: 5/5 | Batch 730/938 | loss: 0.2342
# Epoch: 5/5 | Batch 740/938 | loss: 0.1388
# Epoch: 5/5 | Batch 750/938 | loss: 0.2357
# Epoch: 5/5 | Batch 760/938 | loss: 0.2143
# Epoch: 5/5 | Batch 770/938 | loss: 0.3101
# Epoch: 5/5 | Batch 780/938 | loss: 0.2260
# Epoch: 5/5 | Batch 790/938 | loss: 0.2883
# Epoch: 5/5 | Batch 800/938 | loss: 0.2158
# Epoch: 5/5 | Batch 810/938 | loss: 0.3256
# Epoch: 5/5 | Batch 820/938 | loss: 0.3449
# Epoch: 5/5 | Batch 830/938 | loss: 0.3196
# Epoch: 5/5 | Batch 840/938 | loss: 0.2381
# Epoch: 5/5 | Batch 850/938 | loss: 0.1838
# Epoch: 5/5 | Batch 860/938 | loss: 0.2906
# Epoch: 5/5 | Batch 870/938 | loss: 0.1240
# Epoch: 5/5 | Batch 880/938 | loss: 0.2201
# Epoch: 5/5 | Batch 890/938 | loss: 0.2435
# Epoch: 5/5 | Batch 900/938 | loss: 0.2396
# Epoch: 5/5 | Batch 910/938 | loss: 0.3743
# Epoch: 5/5 | Batch 920/938 | loss: 0.2173
# Epoch: 5/5 | Batch 930/938 | loss: 0.1954
# Epoch 5/5, training loss: 0.24415511697498973, validation loss: 0.2965404267903346
# 	     precision: 0.8932
# 	        recall: 0.8904
# 	            F1: 0.8823
# 	      accuracy: 0.8917
# Total Training Time: 3.66 min

# %% [markdown]
# ## **Step 2 (Total 5 pts)**. Train the ResNet50 and display the training and testing losses for ResNet50 as a graph.
# ### **$\color{red}{\text{ToDo}}$**: Train your ResNet50 using below code and plot the training loss and validation loss against the epochs. (You can modify the training code as needed.)

# %%
num_epochs = 5
optimizer = torch.optim.Adam(resnet50_model.parameters(), lr=learning_rate)

losses = train(resnet50_model, optimizer)
# Out:
# Epoch: 1/5 | Batch 0/938 | loss: 2.8762
# Epoch: 1/5 | Batch 10/938 | loss: 1.8106
# Epoch: 1/5 | Batch 20/938 | loss: 1.2379
# Epoch: 1/5 | Batch 30/938 | loss: 0.9419
# Epoch: 1/5 | Batch 40/938 | loss: 0.9554
# Epoch: 1/5 | Batch 50/938 | loss: 0.8376
# Epoch: 1/5 | Batch 60/938 | loss: 1.0012
# Epoch: 1/5 | Batch 70/938 | loss: 1.0465
# Epoch: 1/5 | Batch 80/938 | loss: 1.7959
# Epoch: 1/5 | Batch 90/938 | loss: 0.8518
# Epoch: 1/5 | Batch 100/938 | loss: 0.5956
# Epoch: 1/5 | Batch 110/938 | loss: 0.8406
# Epoch: 1/5 | Batch 120/938 | loss: 0.6253
# Epoch: 1/5 | Batch 130/938 | loss: 0.7042
# Epoch: 1/5 | Batch 140/938 | loss: 0.6271
# Epoch: 1/5 | Batch 150/938 | loss: 0.7240
# Epoch: 1/5 | Batch 160/938 | loss: 0.9108
# Epoch: 1/5 | Batch 170/938 | loss: 0.6423
# Epoch: 1/5 | Batch 180/938 | loss: 0.7685
# Epoch: 1/5 | Batch 190/938 | loss: 1.1372
# Epoch: 1/5 | Batch 200/938 | loss: 0.6618
# Epoch: 1/5 | Batch 210/938 | loss: 0.6494
# Epoch: 1/5 | Batch 220/938 | loss: 0.3746
# Epoch: 1/5 | Batch 230/938 | loss: 0.3858
# Epoch: 1/5 | Batch 240/938 | loss: 0.6378
# Epoch: 1/5 | Batch 250/938 | loss: 0.9088
# Epoch: 1/5 | Batch 260/938 | loss: 0.4086
# Epoch: 1/5 | Batch 270/938 | loss: 1.7181
# Epoch: 1/5 | Batch 280/938 | loss: 1.1473
# Epoch: 1/5 | Batch 290/938 | loss: 0.3357
# Epoch: 1/5 | Batch 300/938 | loss: 0.7511
# Epoch: 1/5 | Batch 310/938 | loss: 0.6093
# Epoch: 1/5 | Batch 320/938 | loss: 0.8294
# Epoch: 1/5 | Batch 330/938 | loss: 1.5939
# Epoch: 1/5 | Batch 340/938 | loss: 1.5084
# Epoch: 1/5 | Batch 350/938 | loss: 0.9087
# Epoch: 1/5 | Batch 360/938 | loss: 1.2227
# Epoch: 1/5 | Batch 370/938 | loss: 0.8769
# Epoch: 1/5 | Batch 380/938 | loss: 0.6917
# Epoch: 1/5 | Batch 390/938 | loss: 0.6436
# Epoch: 1/5 | Batch 400/938 | loss: 1.3453
# Epoch: 1/5 | Batch 410/938 | loss: 0.7383
# Epoch: 1/5 | Batch 420/938 | loss: 0.4907
# Epoch: 1/5 | Batch 430/938 | loss: 0.7885
# Epoch: 1/5 | Batch 440/938 | loss: 1.0090
# Epoch: 1/5 | Batch 450/938 | loss: 0.5337
# Epoch: 1/5 | Batch 460/938 | loss: 0.6911
# Epoch: 1/5 | Batch 470/938 | loss: 0.7910
# Epoch: 1/5 | Batch 480/938 | loss: 0.6849
# Epoch: 1/5 | Batch 490/938 | loss: 0.5619
# Epoch: 1/5 | Batch 500/938 | loss: 0.5248
# Epoch: 1/5 | Batch 510/938 | loss: 0.4585
# Epoch: 1/5 | Batch 520/938 | loss: 0.9374
# Epoch: 1/5 | Batch 530/938 | loss: 0.4414
# Epoch: 1/5 | Batch 540/938 | loss: 0.5587
# Epoch: 1/5 | Batch 550/938 | loss: 0.4659
# Epoch: 1/5 | Batch 560/938 | loss: 0.5566
# Epoch: 1/5 | Batch 570/938 | loss: 0.8589
# Epoch: 1/5 | Batch 580/938 | loss: 0.5400
# Epoch: 1/5 | Batch 590/938 | loss: 0.3861
# Epoch: 1/5 | Batch 600/938 | loss: 0.6324
# Epoch: 1/5 | Batch 610/938 | loss: 0.4482
# Epoch: 1/5 | Batch 620/938 | loss: 0.7237
# Epoch: 1/5 | Batch 630/938 | loss: 0.5133
# Epoch: 1/5 | Batch 640/938 | loss: 0.5858
# Epoch: 1/5 | Batch 650/938 | loss: 0.7818
# Epoch: 1/5 | Batch 660/938 | loss: 0.5353
# Epoch: 1/5 | Batch 670/938 | loss: 1.3311
# Epoch: 1/5 | Batch 680/938 | loss: 0.5646
# Epoch: 1/5 | Batch 690/938 | loss: 0.4659
# Epoch: 1/5 | Batch 700/938 | loss: 0.3423
# Epoch: 1/5 | Batch 710/938 | loss: 0.4405
# Epoch: 1/5 | Batch 720/938 | loss: 0.5437
# Epoch: 1/5 | Batch 730/938 | loss: 0.3376
# Epoch: 1/5 | Batch 740/938 | loss: 0.5341
# Epoch: 1/5 | Batch 750/938 | loss: 0.5286
# Epoch: 1/5 | Batch 760/938 | loss: 0.4175
# Epoch: 1/5 | Batch 770/938 | loss: 0.3642
# Epoch: 1/5 | Batch 780/938 | loss: 0.7410
# Epoch: 1/5 | Batch 790/938 | loss: 0.3217
# Epoch: 1/5 | Batch 800/938 | loss: 0.2999
# Epoch: 1/5 | Batch 810/938 | loss: 0.4826
# Epoch: 1/5 | Batch 820/938 | loss: 0.4668
# Epoch: 1/5 | Batch 830/938 | loss: 1.1490
# Epoch: 1/5 | Batch 840/938 | loss: 0.5887
# Epoch: 1/5 | Batch 850/938 | loss: 0.4345
# Epoch: 1/5 | Batch 860/938 | loss: 0.4217
# Epoch: 1/5 | Batch 870/938 | loss: 0.4724
# Epoch: 1/5 | Batch 880/938 | loss: 0.6270
# Epoch: 1/5 | Batch 890/938 | loss: 0.6936
# Epoch: 1/5 | Batch 900/938 | loss: 0.5843
# Epoch: 1/5 | Batch 910/938 | loss: 0.4238
# Epoch: 1/5 | Batch 920/938 | loss: 0.6136
# Epoch: 1/5 | Batch 930/938 | loss: 0.4497
# Epoch 1/5, training loss: 0.7076255360773123, validation loss: 0.5752630432130424
# 	     precision: 0.8214
# 	        recall: 0.8212
# 	            F1: 0.8002
# 	      accuracy: 0.8225
# Epoch: 2/5 | Batch 0/938 | loss: 0.4960
# Epoch: 2/5 | Batch 10/938 | loss: 0.4015
# Epoch: 2/5 | Batch 20/938 | loss: 0.6180
# Epoch: 2/5 | Batch 30/938 | loss: 0.4373
# Epoch: 2/5 | Batch 40/938 | loss: 0.6149
# Epoch: 2/5 | Batch 50/938 | loss: 0.4371
# Epoch: 2/5 | Batch 60/938 | loss: 0.4153
# Epoch: 2/5 | Batch 70/938 | loss: 0.5104
# Epoch: 2/5 | Batch 80/938 | loss: 0.6311
# Epoch: 2/5 | Batch 90/938 | loss: 0.5288
# Epoch: 2/5 | Batch 100/938 | loss: 0.5005
# Epoch: 2/5 | Batch 110/938 | loss: 0.5156
# Epoch: 2/5 | Batch 120/938 | loss: 0.7059
# Epoch: 2/5 | Batch 130/938 | loss: 0.5437
# Epoch: 2/5 | Batch 140/938 | loss: 0.6449
# Epoch: 2/5 | Batch 150/938 | loss: 0.3728
# Epoch: 2/5 | Batch 160/938 | loss: 0.3683
# Epoch: 2/5 | Batch 170/938 | loss: 0.3860
# Epoch: 2/5 | Batch 180/938 | loss: 0.4113
# Epoch: 2/5 | Batch 190/938 | loss: 0.5198
# Epoch: 2/5 | Batch 200/938 | loss: 0.4822
# Epoch: 2/5 | Batch 210/938 | loss: 0.4542
# Epoch: 2/5 | Batch 220/938 | loss: 0.3903
# Epoch: 2/5 | Batch 230/938 | loss: 1.0899
# Epoch: 2/5 | Batch 240/938 | loss: 0.3302
# Epoch: 2/5 | Batch 250/938 | loss: 0.3680
# Epoch: 2/5 | Batch 260/938 | loss: 0.4727
# Epoch: 2/5 | Batch 270/938 | loss: 0.7092
# Epoch: 2/5 | Batch 280/938 | loss: 0.3854
# Epoch: 2/5 | Batch 290/938 | loss: 0.3178
# Epoch: 2/5 | Batch 300/938 | loss: 0.8142
# Epoch: 2/5 | Batch 310/938 | loss: 0.4001
# Epoch: 2/5 | Batch 320/938 | loss: 0.4275
# Epoch: 2/5 | Batch 330/938 | loss: 0.6062
# Epoch: 2/5 | Batch 340/938 | loss: 0.5477
# Epoch: 2/5 | Batch 350/938 | loss: 0.4649
# Epoch: 2/5 | Batch 360/938 | loss: 0.4591
# Epoch: 2/5 | Batch 370/938 | loss: 0.4535
# Epoch: 2/5 | Batch 380/938 | loss: 0.7153
# Epoch: 2/5 | Batch 390/938 | loss: 1.3237
# Epoch: 2/5 | Batch 400/938 | loss: 0.4151
# Epoch: 2/5 | Batch 410/938 | loss: 0.6016
# Epoch: 2/5 | Batch 420/938 | loss: 0.3560
# Epoch: 2/5 | Batch 430/938 | loss: 0.4942
# Epoch: 2/5 | Batch 440/938 | loss: 0.3004
# Epoch: 2/5 | Batch 450/938 | loss: 0.4573
# Epoch: 2/5 | Batch 460/938 | loss: 0.4122
# Epoch: 2/5 | Batch 470/938 | loss: 0.3957
# Epoch: 2/5 | Batch 480/938 | loss: 0.3026
# Epoch: 2/5 | Batch 490/938 | loss: 0.2698
# Epoch: 2/5 | Batch 500/938 | loss: 0.5053
# Epoch: 2/5 | Batch 510/938 | loss: 0.3456
# Epoch: 2/5 | Batch 520/938 | loss: 0.3847
# Epoch: 2/5 | Batch 530/938 | loss: 0.3713
# Epoch: 2/5 | Batch 540/938 | loss: 0.4901
# Epoch: 2/5 | Batch 550/938 | loss: 0.6998
# Epoch: 2/5 | Batch 560/938 | loss: 0.6233
# Epoch: 2/5 | Batch 570/938 | loss: 0.5430
# Epoch: 2/5 | Batch 580/938 | loss: 0.6529
# Epoch: 2/5 | Batch 590/938 | loss: 0.5991
# Epoch: 2/5 | Batch 600/938 | loss: 0.4955
# Epoch: 2/5 | Batch 610/938 | loss: 0.5871
# Epoch: 2/5 | Batch 620/938 | loss: 0.3608
# Epoch: 2/5 | Batch 630/938 | loss: 0.3467
# Epoch: 2/5 | Batch 640/938 | loss: 0.3480
# Epoch: 2/5 | Batch 650/938 | loss: 0.2210
# Epoch: 2/5 | Batch 660/938 | loss: 0.3018
# Epoch: 2/5 | Batch 670/938 | loss: 0.2839
# Epoch: 2/5 | Batch 680/938 | loss: 0.3745
# Epoch: 2/5 | Batch 690/938 | loss: 0.4532
# Epoch: 2/5 | Batch 700/938 | loss: 0.4717
# Epoch: 2/5 | Batch 710/938 | loss: 0.5806
# Epoch: 2/5 | Batch 720/938 | loss: 0.4219
# Epoch: 2/5 | Batch 730/938 | loss: 0.5661
# Epoch: 2/5 | Batch 740/938 | loss: 0.5616
# Epoch: 2/5 | Batch 750/938 | loss: 0.5925
# Epoch: 2/5 | Batch 760/938 | loss: 0.5628
# Epoch: 2/5 | Batch 770/938 | loss: 0.3942
# Epoch: 2/5 | Batch 780/938 | loss: 0.4273
# Epoch: 2/5 | Batch 790/938 | loss: 0.5351
# Epoch: 2/5 | Batch 800/938 | loss: 0.3973
# Epoch: 2/5 | Batch 810/938 | loss: 0.5043
# Epoch: 2/5 | Batch 820/938 | loss: 0.4586
# Epoch: 2/5 | Batch 830/938 | loss: 0.4556
# Epoch: 2/5 | Batch 840/938 | loss: 0.4314
# Epoch: 2/5 | Batch 850/938 | loss: 0.4098
# Epoch: 2/5 | Batch 860/938 | loss: 0.4417
# Epoch: 2/5 | Batch 870/938 | loss: 0.5050
# Epoch: 2/5 | Batch 880/938 | loss: 0.3842
# Epoch: 2/5 | Batch 890/938 | loss: 0.4057
# Epoch: 2/5 | Batch 900/938 | loss: 0.5358
# Epoch: 2/5 | Batch 910/938 | loss: 0.4795
# Epoch: 2/5 | Batch 920/938 | loss: 0.4647
# Epoch: 2/5 | Batch 930/938 | loss: 0.3359
# Epoch 2/5, training loss: 0.4801718778669961, validation loss: 0.37769935441434765
# 	     precision: 0.8596
# 	        recall: 0.8544
# 	            F1: 0.8444
# 	      accuracy: 0.8553
# Epoch: 3/5 | Batch 0/938 | loss: 0.2973
# Epoch: 3/5 | Batch 10/938 | loss: 0.3526
# Epoch: 3/5 | Batch 20/938 | loss: 0.3732
# Epoch: 3/5 | Batch 30/938 | loss: 1.4270
# Epoch: 3/5 | Batch 40/938 | loss: 0.5404
# Epoch: 3/5 | Batch 50/938 | loss: 0.7875
# Epoch: 3/5 | Batch 60/938 | loss: 0.7785
# Epoch: 3/5 | Batch 70/938 | loss: 0.7448
# Epoch: 3/5 | Batch 80/938 | loss: 0.2966
# Epoch: 3/5 | Batch 90/938 | loss: 0.6895
# Epoch: 3/5 | Batch 100/938 | loss: 0.6089
# Epoch: 3/5 | Batch 110/938 | loss: 0.5120
# Epoch: 3/5 | Batch 120/938 | loss: 0.4707
# Epoch: 3/5 | Batch 130/938 | loss: 0.5118
# Epoch: 3/5 | Batch 140/938 | loss: 0.3378
# Epoch: 3/5 | Batch 150/938 | loss: 1.0534
# Epoch: 3/5 | Batch 160/938 | loss: 0.4580
# Epoch: 3/5 | Batch 170/938 | loss: 0.4050
# Epoch: 3/5 | Batch 180/938 | loss: 0.5164
# Epoch: 3/5 | Batch 190/938 | loss: 0.6083
# Epoch: 3/5 | Batch 200/938 | loss: 0.6702
# Epoch: 3/5 | Batch 210/938 | loss: 0.2320
# Epoch: 3/5 | Batch 220/938 | loss: 0.6467
# Epoch: 3/5 | Batch 230/938 | loss: 0.4741
# Epoch: 3/5 | Batch 240/938 | loss: 0.6597
# Epoch: 3/5 | Batch 250/938 | loss: 0.4692
# Epoch: 3/5 | Batch 260/938 | loss: 0.4797
# Epoch: 3/5 | Batch 270/938 | loss: 0.4347
# Epoch: 3/5 | Batch 280/938 | loss: 0.7226
# Epoch: 3/5 | Batch 290/938 | loss: 0.8125
# Epoch: 3/5 | Batch 300/938 | loss: 0.6485
# Epoch: 3/5 | Batch 310/938 | loss: 0.8886
# Epoch: 3/5 | Batch 320/938 | loss: 0.5898
# Epoch: 3/5 | Batch 330/938 | loss: 0.5379
# Epoch: 3/5 | Batch 340/938 | loss: 0.3690
# Epoch: 3/5 | Batch 350/938 | loss: 0.3574
# Epoch: 3/5 | Batch 360/938 | loss: 0.3703
# Epoch: 3/5 | Batch 370/938 | loss: 0.2900
# Epoch: 3/5 | Batch 380/938 | loss: 0.3247
# Epoch: 3/5 | Batch 390/938 | loss: 0.2861
# Epoch: 3/5 | Batch 400/938 | loss: 0.3658
# Epoch: 3/5 | Batch 410/938 | loss: 0.3886
# Epoch: 3/5 | Batch 420/938 | loss: 0.2471
# Epoch: 3/5 | Batch 430/938 | loss: 0.3203
# Epoch: 3/5 | Batch 440/938 | loss: 0.5037
# Epoch: 3/5 | Batch 450/938 | loss: 0.3735
# Epoch: 3/5 | Batch 460/938 | loss: 0.5190
# Epoch: 3/5 | Batch 470/938 | loss: 0.4946
# Epoch: 3/5 | Batch 480/938 | loss: 0.2650
# Epoch: 3/5 | Batch 490/938 | loss: 0.4595
# Epoch: 3/5 | Batch 500/938 | loss: 0.3244
# Epoch: 3/5 | Batch 510/938 | loss: 0.5091
# Epoch: 3/5 | Batch 520/938 | loss: 0.3653
# Epoch: 3/5 | Batch 530/938 | loss: 0.5304
# Epoch: 3/5 | Batch 540/938 | loss: 0.4418
# Epoch: 3/5 | Batch 550/938 | loss: 0.4412
# Epoch: 3/5 | Batch 560/938 | loss: 0.2899
# Epoch: 3/5 | Batch 570/938 | loss: 0.4306
# Epoch: 3/5 | Batch 580/938 | loss: 0.4227
# Epoch: 3/5 | Batch 590/938 | loss: 0.5411
# Epoch: 3/5 | Batch 600/938 | loss: 0.5979
# Epoch: 3/5 | Batch 610/938 | loss: 0.4657
# Epoch: 3/5 | Batch 620/938 | loss: 0.5523
# Epoch: 3/5 | Batch 630/938 | loss: 0.5125
# Epoch: 3/5 | Batch 640/938 | loss: 0.4952
# Epoch: 3/5 | Batch 650/938 | loss: 0.3962
# Epoch: 3/5 | Batch 660/938 | loss: 0.3695
# Epoch: 3/5 | Batch 670/938 | loss: 0.4288
# Epoch: 3/5 | Batch 680/938 | loss: 0.2672
# Epoch: 3/5 | Batch 690/938 | loss: 0.4338
# Epoch: 3/5 | Batch 700/938 | loss: 0.2502
# Epoch: 3/5 | Batch 710/938 | loss: 0.3185
# Epoch: 3/5 | Batch 720/938 | loss: 0.3252
# Epoch: 3/5 | Batch 730/938 | loss: 0.4450
# Epoch: 3/5 | Batch 740/938 | loss: 0.4847
# Epoch: 3/5 | Batch 750/938 | loss: 0.4397
# Epoch: 3/5 | Batch 760/938 | loss: 0.3226
# Epoch: 3/5 | Batch 770/938 | loss: 0.3577
# Epoch: 3/5 | Batch 780/938 | loss: 0.4124
# Epoch: 3/5 | Batch 790/938 | loss: 0.4111
# Epoch: 3/5 | Batch 800/938 | loss: 0.2763
# Epoch: 3/5 | Batch 810/938 | loss: 0.6528
# Epoch: 3/5 | Batch 820/938 | loss: 0.4133
# Epoch: 3/5 | Batch 830/938 | loss: 0.4230
# Epoch: 3/5 | Batch 840/938 | loss: 0.3458
# Epoch: 3/5 | Batch 850/938 | loss: 0.3159
# Epoch: 3/5 | Batch 860/938 | loss: 0.3552
# Epoch: 3/5 | Batch 870/938 | loss: 0.2233
# Epoch: 3/5 | Batch 880/938 | loss: 0.4593
# Epoch: 3/5 | Batch 890/938 | loss: 0.2341
# Epoch: 3/5 | Batch 900/938 | loss: 0.4248
# Epoch: 3/5 | Batch 910/938 | loss: 0.2070
# Epoch: 3/5 | Batch 920/938 | loss: 0.3246
# Epoch: 3/5 | Batch 930/938 | loss: 0.2798
# Epoch 3/5, training loss: 0.4661409454559212, validation loss: 0.345486457180825
# 	     precision: 0.8688
# 	        recall: 0.8689
# 	            F1: 0.8586
# 	      accuracy: 0.8705
# Epoch: 4/5 | Batch 0/938 | loss: 0.2229
# Epoch: 4/5 | Batch 10/938 | loss: 0.4160
# Epoch: 4/5 | Batch 20/938 | loss: 0.4454
# Epoch: 4/5 | Batch 30/938 | loss: 0.3180
# Epoch: 4/5 | Batch 40/938 | loss: 0.3986
# Epoch: 4/5 | Batch 50/938 | loss: 0.2272
# Epoch: 4/5 | Batch 60/938 | loss: 0.3228
# Epoch: 4/5 | Batch 70/938 | loss: 0.2699
# Epoch: 4/5 | Batch 80/938 | loss: 0.1821
# Epoch: 4/5 | Batch 90/938 | loss: 0.2788
# Epoch: 4/5 | Batch 100/938 | loss: 0.3708
# Epoch: 4/5 | Batch 110/938 | loss: 0.3064
# Epoch: 4/5 | Batch 120/938 | loss: 0.3599
# Epoch: 4/5 | Batch 130/938 | loss: 0.3413
# Epoch: 4/5 | Batch 140/938 | loss: 0.1812
# Epoch: 4/5 | Batch 150/938 | loss: 0.3390
# Epoch: 4/5 | Batch 160/938 | loss: 0.4274
# Epoch: 4/5 | Batch 170/938 | loss: 0.2576
# Epoch: 4/5 | Batch 180/938 | loss: 0.2305
# Epoch: 4/5 | Batch 190/938 | loss: 0.3337
# Epoch: 4/5 | Batch 200/938 | loss: 0.3810
# Epoch: 4/5 | Batch 210/938 | loss: 0.3522
# Epoch: 4/5 | Batch 220/938 | loss: 0.3741
# Epoch: 4/5 | Batch 230/938 | loss: 0.3165
# Epoch: 4/5 | Batch 240/938 | loss: 0.3486
# Epoch: 4/5 | Batch 250/938 | loss: 0.4294
# Epoch: 4/5 | Batch 260/938 | loss: 0.2157
# Epoch: 4/5 | Batch 270/938 | loss: 0.5557
# Epoch: 4/5 | Batch 280/938 | loss: 0.3749
# Epoch: 4/5 | Batch 290/938 | loss: 0.4498
# Epoch: 4/5 | Batch 300/938 | loss: 0.2543
# Epoch: 4/5 | Batch 310/938 | loss: 0.3521
# Epoch: 4/5 | Batch 320/938 | loss: 0.3075
# Epoch: 4/5 | Batch 330/938 | loss: 0.5717
# Epoch: 4/5 | Batch 340/938 | loss: 0.3363
# Epoch: 4/5 | Batch 350/938 | loss: 0.4773
# Epoch: 4/5 | Batch 360/938 | loss: 0.3081
# Epoch: 4/5 | Batch 370/938 | loss: 0.1429
# Epoch: 4/5 | Batch 380/938 | loss: 0.2513
# Epoch: 4/5 | Batch 390/938 | loss: 0.3368
# Epoch: 4/5 | Batch 400/938 | loss: 0.2698
# Epoch: 4/5 | Batch 410/938 | loss: 0.4128
# Epoch: 4/5 | Batch 420/938 | loss: 0.1792
# Epoch: 4/5 | Batch 430/938 | loss: 0.3708
# Epoch: 4/5 | Batch 440/938 | loss: 0.2560
# Epoch: 4/5 | Batch 450/938 | loss: 0.1388
# Epoch: 4/5 | Batch 460/938 | loss: 0.2604
# Epoch: 4/5 | Batch 470/938 | loss: 0.1659
# Epoch: 4/5 | Batch 480/938 | loss: 0.2793
# Epoch: 4/5 | Batch 490/938 | loss: 0.3640
# Epoch: 4/5 | Batch 500/938 | loss: 0.1624
# Epoch: 4/5 | Batch 510/938 | loss: 0.4477
# Epoch: 4/5 | Batch 520/938 | loss: 0.3809
# Epoch: 4/5 | Batch 530/938 | loss: 0.2928
# Epoch: 4/5 | Batch 540/938 | loss: 0.1962
# Epoch: 4/5 | Batch 550/938 | loss: 0.2398
# Epoch: 4/5 | Batch 560/938 | loss: 0.3287
# Epoch: 4/5 | Batch 570/938 | loss: 0.3006
# Epoch: 4/5 | Batch 580/938 | loss: 0.4301
# Epoch: 4/5 | Batch 590/938 | loss: 0.3463
# Epoch: 4/5 | Batch 600/938 | loss: 0.2806
# Epoch: 4/5 | Batch 610/938 | loss: 0.2052
# Epoch: 4/5 | Batch 620/938 | loss: 0.4118
# Epoch: 4/5 | Batch 630/938 | loss: 0.2938
# Epoch: 4/5 | Batch 640/938 | loss: 0.2233
# Epoch: 4/5 | Batch 650/938 | loss: 0.2462
# Epoch: 4/5 | Batch 660/938 | loss: 0.1757
# Epoch: 4/5 | Batch 670/938 | loss: 0.3323
# Epoch: 4/5 | Batch 680/938 | loss: 0.2586
# Epoch: 4/5 | Batch 690/938 | loss: 0.2830
# Epoch: 4/5 | Batch 700/938 | loss: 0.4132
# Epoch: 4/5 | Batch 710/938 | loss: 0.3220
# Epoch: 4/5 | Batch 720/938 | loss: 0.2382
# Epoch: 4/5 | Batch 730/938 | loss: 0.4436
# Epoch: 4/5 | Batch 740/938 | loss: 0.2493
# Epoch: 4/5 | Batch 750/938 | loss: 0.2805
# Epoch: 4/5 | Batch 760/938 | loss: 0.3086
# Epoch: 4/5 | Batch 770/938 | loss: 0.4666
# Epoch: 4/5 | Batch 780/938 | loss: 0.4940
# Epoch: 4/5 | Batch 790/938 | loss: 0.3372
# Epoch: 4/5 | Batch 800/938 | loss: 0.4987
# Epoch: 4/5 | Batch 810/938 | loss: 0.2542
# Epoch: 4/5 | Batch 820/938 | loss: 0.2346
# Epoch: 4/5 | Batch 830/938 | loss: 0.2738
# Epoch: 4/5 | Batch 840/938 | loss: 0.3735
# Epoch: 4/5 | Batch 850/938 | loss: 0.2623
# Epoch: 4/5 | Batch 860/938 | loss: 0.1783
# Epoch: 4/5 | Batch 870/938 | loss: 0.2661
# Epoch: 4/5 | Batch 880/938 | loss: 0.2773
# Epoch: 4/5 | Batch 890/938 | loss: 0.4124
# Epoch: 4/5 | Batch 900/938 | loss: 0.3710
# Epoch: 4/5 | Batch 910/938 | loss: 0.3785
# Epoch: 4/5 | Batch 920/938 | loss: 0.1190
# Epoch: 4/5 | Batch 930/938 | loss: 0.2626
# Epoch 4/5, training loss: 0.3308052190029418, validation loss: 0.3096814088665756
# 	     precision: 0.8860
# 	        recall: 0.8876
# 	            F1: 0.8766
# 	      accuracy: 0.8859
# Epoch: 5/5 | Batch 0/938 | loss: 0.2344
# Epoch: 5/5 | Batch 10/938 | loss: 0.2443
# Epoch: 5/5 | Batch 20/938 | loss: 0.1541
# Epoch: 5/5 | Batch 30/938 | loss: 0.4210
# Epoch: 5/5 | Batch 40/938 | loss: 0.3536
# Epoch: 5/5 | Batch 50/938 | loss: 0.4364
# Epoch: 5/5 | Batch 60/938 | loss: 0.4344
# Epoch: 5/5 | Batch 70/938 | loss: 0.6223
# Epoch: 5/5 | Batch 80/938 | loss: 0.3161
# Epoch: 5/5 | Batch 90/938 | loss: 0.2546
# Epoch: 5/5 | Batch 100/938 | loss: 0.2263
# Epoch: 5/5 | Batch 110/938 | loss: 0.3450
# Epoch: 5/5 | Batch 120/938 | loss: 0.3188
# Epoch: 5/5 | Batch 130/938 | loss: 0.2452
# Epoch: 5/5 | Batch 140/938 | loss: 0.4655
# Epoch: 5/5 | Batch 150/938 | loss: 0.2616
# Epoch: 5/5 | Batch 160/938 | loss: 0.3240
# Epoch: 5/5 | Batch 170/938 | loss: 0.1843
# Epoch: 5/5 | Batch 180/938 | loss: 0.3427
# Epoch: 5/5 | Batch 190/938 | loss: 0.3249
# Epoch: 5/5 | Batch 200/938 | loss: 0.2019
# Epoch: 5/5 | Batch 210/938 | loss: 0.2004
# Epoch: 5/5 | Batch 220/938 | loss: 0.3643
# Epoch: 5/5 | Batch 230/938 | loss: 0.3581
# Epoch: 5/5 | Batch 240/938 | loss: 0.3859
# Epoch: 5/5 | Batch 250/938 | loss: 0.2241
# Epoch: 5/5 | Batch 260/938 | loss: 0.3388
# Epoch: 5/5 | Batch 270/938 | loss: 0.1913
# Epoch: 5/5 | Batch 280/938 | loss: 0.2056
# Epoch: 5/5 | Batch 290/938 | loss: 0.3187
# Epoch: 5/5 | Batch 300/938 | loss: 0.2558
# Epoch: 5/5 | Batch 310/938 | loss: 0.5524
# Epoch: 5/5 | Batch 320/938 | loss: 0.3644
# Epoch: 5/5 | Batch 330/938 | loss: 0.2593
# Epoch: 5/5 | Batch 340/938 | loss: 0.3276
# Epoch: 5/5 | Batch 350/938 | loss: 0.2092
# Epoch: 5/5 | Batch 360/938 | loss: 0.2555
# Epoch: 5/5 | Batch 370/938 | loss: 0.1134
# Epoch: 5/5 | Batch 380/938 | loss: 0.4432
# Epoch: 5/5 | Batch 390/938 | loss: 0.2866
# Epoch: 5/5 | Batch 400/938 | loss: 0.2178
# Epoch: 5/5 | Batch 410/938 | loss: 0.3627
# Epoch: 5/5 | Batch 420/938 | loss: 0.1489
# Epoch: 5/5 | Batch 430/938 | loss: 0.3070
# Epoch: 5/5 | Batch 440/938 | loss: 0.4714
# Epoch: 5/5 | Batch 450/938 | loss: 0.2550
# Epoch: 5/5 | Batch 460/938 | loss: 0.4350
# Epoch: 5/5 | Batch 470/938 | loss: 0.3518
# Epoch: 5/5 | Batch 480/938 | loss: 0.3051
# Epoch: 5/5 | Batch 490/938 | loss: 0.2178
# Epoch: 5/5 | Batch 500/938 | loss: 0.4189
# Epoch: 5/5 | Batch 510/938 | loss: 0.5685
# Epoch: 5/5 | Batch 520/938 | loss: 0.2816
# Epoch: 5/5 | Batch 530/938 | loss: 0.3655
# Epoch: 5/5 | Batch 540/938 | loss: 0.2100
# Epoch: 5/5 | Batch 550/938 | loss: 0.3044
# Epoch: 5/5 | Batch 560/938 | loss: 0.2586
# Epoch: 5/5 | Batch 570/938 | loss: 0.2274
# Epoch: 5/5 | Batch 580/938 | loss: 0.2824
# Epoch: 5/5 | Batch 590/938 | loss: 0.3932
# Epoch: 5/5 | Batch 600/938 | loss: 0.5627
# Epoch: 5/5 | Batch 610/938 | loss: 0.3182
# Epoch: 5/5 | Batch 620/938 | loss: 0.4579
# Epoch: 5/5 | Batch 630/938 | loss: 0.2670
# Epoch: 5/5 | Batch 640/938 | loss: 0.4818
# Epoch: 5/5 | Batch 650/938 | loss: 0.2883
# Epoch: 5/5 | Batch 660/938 | loss: 0.4225
# Epoch: 5/5 | Batch 670/938 | loss: 0.4063
# Epoch: 5/5 | Batch 680/938 | loss: 0.1515
# Epoch: 5/5 | Batch 690/938 | loss: 0.4310
# Epoch: 5/5 | Batch 700/938 | loss: 0.2795
# Epoch: 5/5 | Batch 710/938 | loss: 0.3765
# Epoch: 5/5 | Batch 720/938 | loss: 0.3399
# Epoch: 5/5 | Batch 730/938 | loss: 0.2885
# Epoch: 5/5 | Batch 740/938 | loss: 0.4608
# Epoch: 5/5 | Batch 750/938 | loss: 0.3083
# Epoch: 5/5 | Batch 760/938 | loss: 0.4897
# Epoch: 5/5 | Batch 770/938 | loss: 0.3008
# Epoch: 5/5 | Batch 780/938 | loss: 0.2829
# Epoch: 5/5 | Batch 790/938 | loss: 0.3668
# Epoch: 5/5 | Batch 800/938 | loss: 0.2571
# Epoch: 5/5 | Batch 810/938 | loss: 0.2512
# Epoch: 5/5 | Batch 820/938 | loss: 0.3881
# Epoch: 5/5 | Batch 830/938 | loss: 0.3047
# Epoch: 5/5 | Batch 840/938 | loss: 0.3899
# Epoch: 5/5 | Batch 850/938 | loss: 0.3991
# Epoch: 5/5 | Batch 860/938 | loss: 0.1788
# Epoch: 5/5 | Batch 870/938 | loss: 0.5296
# Epoch: 5/5 | Batch 880/938 | loss: 0.4015
# Epoch: 5/5 | Batch 890/938 | loss: 0.2411
# Epoch: 5/5 | Batch 900/938 | loss: 0.5460
# Epoch: 5/5 | Batch 910/938 | loss: 0.2552
# Epoch: 5/5 | Batch 920/938 | loss: 0.1521
# Epoch: 5/5 | Batch 930/938 | loss: 0.1500
# Epoch 5/5, training loss: 0.3112740881963452, validation loss: 0.3247173282371205
# 	     precision: 0.8822
# 	        recall: 0.8723
# 	            F1: 0.8618
# 	      accuracy: 0.8710
# Total Training Time: 5.30 min

# %% [markdown]
#  # **Part 5 (Total 20 pts)**. Achieve the highest possible **accuracy score** on the test dataset for the Fashion-MNIST classification task using only the basic Colab resources.
#
# * **You can use any model**, including the ResNet you implemented, as long as **it can be trained within the Colab resources**.
# * To receive points for your score, **the model and the training process used to achieve that score must be accurately documented in your submitted file.**
# * You may modify `train_loader`, `train()` as necessary, but `test_loader` should not be modified.
#
# - Part5 score will be given based on the achieved accuracy score like the followings:
#   - 0.93 ~ : 20 pts
#   - 0.90 ~ 0.93 : 15 pts
#   - 0.88 ~ 0.90 : 10 pts
#   - 0.85 ~ 0.88 : 5 pts

# %% [markdown]
# To improve a model with higher accuracy (goal : 0.93), the model is modified with below specifications.
# - Resnet18 with different initial convolutional layer: Using simple model (e.g. a few convolutional layers) shows a lack of capacity and cause underfitting, while complex model(e.g. Resnet with many layers) shows an overfitting problem easily and train longer. Therefore, we'll use a model based on a structure of Resnet18. <br>
# For this model, **initial convolutional layer is modified by (kernel_size, stride, padding) = (3, 1, 1), instead of (7, 2, 3) combination.** This makes the kernel becomes small, but allows stronger locality. Also, it can be fit to the small data size, like 28 x 28 pixel image.
# - Data Augmentation : Apply a data augmentation on **training data** to increase the size of the training set and to get more different images. We'll only transform the training set images by changing the brightness using **transforms.ColorJitter method**, because the image has a small size, so spatial transformation can make a huge different between the original data.
#
#   **Important!!** Test dataset should not be modified, which means the data augmentation doesn't applied at the test dataset.
# - Regularization with dropout : Placing a dropout layer inside the BasicBlock forward process and also the Resnet's fully connected layer. This regularization can prevent the overfitting.
# - More training : increase the number of epochs from 5 to 30. This change will make model more accurate, but the model will fall into the overfitting and accuracy won't increase soon.
#
# First, we'll consider the data augmentation.

# %%
# Data Augmentation
# Define the transformation to be applied to the data
train_transformations = transforms.Compose([  transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0, hue=0), transforms.ToTensor()])

# Download the FashionMNIST dataset with Data Augmentation
train_dataset = datasets.FashionMNIST(root='./data', train=True, download=True, transform=train_transformations)

train_loader = get_train_loader()

print("Number of training data: %d" % len(train_dataset))
print("Number of test data: %d" % len(test_dataset))
# Out:
# Number of training data: 60000
# Number of test data: 10000

# %% [markdown]
# Then. we'll implement the modified BasicBlock and Resnet class, called **BasicBlock_rev** and **Resnet_rev**, respectively. <br>
# In BasicBlock_rev, dropout layer with rate 0.2 applied before the second convolutional layer.

# %%
########## implement this class ##########

class BasicBlock_rev(nn.Module):
    expansion = 1

    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock_rev, self).__init__()

        # TODO: Define the first convolutional layer and batch normalization.
        # Remember to consider the number of input and output channels and the stride.
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size = 3, stride = stride, padding = 1)
        self.bn1 = nn.BatchNorm2d(out_channels)

        # TODO: Define a 1st activation function ReLU.
        self.relu1 = nn.ReLU()

        # TODO: Define the second convolutional layer and batch normalization.
        # The number of output channels remains the same as the first layer.
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size = 3, stride = 1, padding = 1)
        self.bn2 = nn.BatchNorm2d(out_channels)

        # TODO: Define a shortcut layer that appropriately transforms the input to be added to the transformed feature map up to this point.
        # If input and output are the same dimensions, use an empty sequential model.
        # If the dimensions are different, adjust the layers accordingly using 1x1 convolution + batch normalization.
        if stride == 1 and in_channels == out_channels * self.expansion:  # Default is identity (no-operation)
          self.shortcut = nn.Sequential()

        else: # TODO: Add a layer to adjust dimensions in the shortcut path, if necessary, using 1x1 convolution + batch normalization.
          self.shortcut = nn.Sequential(nn.Conv2d(in_channels, out_channels * self.expansion, kernel_size=1, stride=stride),
                                        nn.BatchNorm2d(out_channels * self.expansion))

        # TODO: Define a 2nd activation function ReLU.
        self.relu2 = nn.ReLU()

        # Dropout Layer
        self.drop = nn.Dropout2d(0.2)

    def forward(self, x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu1(out)
        # Apply dropout layer after the first activation function
        out = self.drop(out)

        out = self.conv2(out)
        out = self.bn2(out)

        shortcut = self.shortcut(x)
        out += shortcut

        out = self.relu2(out)

        return out

# %% [markdown]
# In Resnet_rev, dropout layer with rate 0.5 applied before the linear layer. Also, at the initial convolutional layer conv1, (kernel_size, stride, padding) change from (7,2,3) to (3,1,1).

# %%
class ResNet_rev(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet_rev, self).__init__()
        self.in_channels = 64  # Starting number of channels

        # TODO: Define the initial convolutional layer and batch normalization.
        self.conv1 = nn.Conv2d(in_channels = 1, out_channels = 64, kernel_size = 3, stride = 1, padding = 1)
        self.bn1 = nn.BatchNorm2d(64)
        self.relu = nn.ReLU()
        self.maxpool = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)

        # Define layers consisting of BasicBlocks. Each layer may contain multiple blocks.
        # The number of blocks for each layer is specified in num_blocks.
        # TODO: Define the four layers of the ResNet (self.layer1 to self.layer4) using the '_make_layer' function.
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride = 1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride = 2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride = 2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride = 2)

        self.avgpool = nn.AdaptiveAvgPool2d(output_size=(1, 1))

        # TODO: Define the final fully connected layer that maps the output of the convolutional layers to the classes.
        self.linear = nn.Linear(in_features = 512 * block.expansion, out_features = 10)

        # Dropout Layer
        self.drop = nn.Dropout2d(0.5)

    def _make_layer(self, block, out_channels, num_blocks, stride):
        # This function creates a sequential layer for each set of blocks.
        # TODO: Implement the function that creates each layer. You will need to consider the stride for the first block
        # and make sure subsequent blocks maintain the output dimension.
        # Update self.in_channels as needed.
        layers = []
        stride_list = [stride] + [1] * (num_blocks - 1)

        for s in stride_list:
          layers.append(block(self.in_channels, out_channels, stride = s ))
          self.in_channels = out_channels * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        # TODO: Implement the forward function. Apply the layers defined in the __init__ to the input x.
        # Finally, apply average pooling and a fully connected layer for the classification.
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        out = self.maxpool(out)

        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)


        out = self.avgpool(out)
        out = out.view(out.size(0), -1)
        # Apply dropout layer(p=0.5) before the linear layer
        out = self.drop(out)
        out = self.linear(out)

        return out

# %% [markdown]
# Let's create a new Resnet18_rev model! <br>
# Note that still, the model runs on GPU. <br>
# If you see the summary below, dropout layers are successfully added between the layers.

# %%
Resnet18_rev_model = ResNet_rev(block=BasicBlock_rev,
                   num_blocks=[2, 2, 2, 2],
                   num_classes=10)
summary(Resnet18_rev_model.to(device), (1, 28, 28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 28, 28]             640
#        BatchNorm2d-2           [-1, 64, 28, 28]             128
#               ReLU-3           [-1, 64, 28, 28]               0
#          MaxPool2d-4           [-1, 64, 14, 14]               0
#             Conv2d-5           [-1, 64, 14, 14]          36,928
#        BatchNorm2d-6           [-1, 64, 14, 14]             128
#               ReLU-7           [-1, 64, 14, 14]               0
#          Dropout2d-8           [-1, 64, 14, 14]               0
#             Conv2d-9           [-1, 64, 14, 14]          36,928
#       BatchNorm2d-10           [-1, 64, 14, 14]             128
#              ReLU-11           [-1, 64, 14, 14]               0
#    BasicBlock_rev-12           [-1, 64, 14, 14]               0
#            Conv2d-13           [-1, 64, 14, 14]          36,928
#       BatchNorm2d-14           [-1, 64, 14, 14]             128
#              ReLU-15           [-1, 64, 14, 14]               0
#         Dropout2d-16           [-1, 64, 14, 14]               0
#            Conv2d-17           [-1, 64, 14, 14]          36,928
#       BatchNorm2d-18           [-1, 64, 14, 14]             128
#              ReLU-19           [-1, 64, 14, 14]               0
#    BasicBlock_rev-20           [-1, 64, 14, 14]               0
#            Conv2d-21            [-1, 128, 7, 7]          73,856
#       BatchNorm2d-22            [-1, 128, 7, 7]             256
#              ReLU-23            [-1, 128, 7, 7]               0
#         Dropout2d-24            [-1, 128, 7, 7]               0
#            Conv2d-25            [-1, 128, 7, 7]         147,584
#       BatchNorm2d-26            [-1, 128, 7, 7]             256
#            Conv2d-27            [-1, 128, 7, 7]           8,320
#       BatchNorm2d-28            [-1, 128, 7, 7]             256
#              ReLU-29            [-1, 128, 7, 7]               0
#    BasicBlock_rev-30            [-1, 128, 7, 7]               0
#            Conv2d-31            [-1, 128, 7, 7]         147,584
#       BatchNorm2d-32            [-1, 128, 7, 7]             256
#              ReLU-33            [-1, 128, 7, 7]               0
#         Dropout2d-34            [-1, 128, 7, 7]               0
#            Conv2d-35            [-1, 128, 7, 7]         147,584
#       BatchNorm2d-36            [-1, 128, 7, 7]             256
#              ReLU-37            [-1, 128, 7, 7]               0
#    BasicBlock_rev-38            [-1, 128, 7, 7]               0
#            Conv2d-39            [-1, 256, 4, 4]         295,168
#       BatchNorm2d-40            [-1, 256, 4, 4]             512
#              ReLU-41            [-1, 256, 4, 4]               0
#         Dropout2d-42            [-1, 256, 4, 4]               0
#            Conv2d-43            [-1, 256, 4, 4]         590,080
#       BatchNorm2d-44            [-1, 256, 4, 4]             512
#            Conv2d-45            [-1, 256, 4, 4]          33,024
#       BatchNorm2d-46            [-1, 256, 4, 4]             512
#              ReLU-47            [-1, 256, 4, 4]               0
#    BasicBlock_rev-48            [-1, 256, 4, 4]               0
#            Conv2d-49            [-1, 256, 4, 4]         590,080
#       BatchNorm2d-50            [-1, 256, 4, 4]             512
#              ReLU-51            [-1, 256, 4, 4]               0
#         Dropout2d-52            [-1, 256, 4, 4]               0
#            Conv2d-53            [-1, 256, 4, 4]         590,080
#       BatchNorm2d-54            [-1, 256, 4, 4]             512
#              ReLU-55            [-1, 256, 4, 4]               0
#    BasicBlock_rev-56            [-1, 256, 4, 4]               0
#            Conv2d-57            [-1, 512, 2, 2]       1,180,160
#       BatchNorm2d-58            [-1, 512, 2, 2]           1,024
#              ReLU-59            [-1, 512, 2, 2]               0
#         Dropout2d-60            [-1, 512, 2, 2]               0
#            Conv2d-61            [-1, 512, 2, 2]       2,359,808
#       BatchNorm2d-62            [-1, 512, 2, 2]           1,024
#            Conv2d-63            [-1, 512, 2, 2]         131,584
#       BatchNorm2d-64            [-1, 512, 2, 2]           1,024
#              ReLU-65            [-1, 512, 2, 2]               0
#    BasicBlock_rev-66            [-1, 512, 2, 2]               0
#            Conv2d-67            [-1, 512, 2, 2]       2,359,808
#       BatchNorm2d-68            [-1, 512, 2, 2]           1,024
#              ReLU-69            [-1, 512, 2, 2]               0
#         Dropout2d-70            [-1, 512, 2, 2]               0
#            Conv2d-71            [-1, 512, 2, 2]       2,359,808
#       BatchNorm2d-72            [-1, 512, 2, 2]           1,024
#              ReLU-73            [-1, 512, 2, 2]               0
#    BasicBlock_rev-74            [-1, 512, 2, 2]               0
# AdaptiveAvgPool2d-75            [-1, 512, 1, 1]               0
#         Dropout2d-76                  [-1, 512]               0
#            Linear-77                   [-1, 10]           5,130
# ================================================================
# Total params: 11,177,610
# Trainable params: 11,177,610
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 4.49
# Params size (MB): 42.64
# Estimated Total Size (MB): 47.13
# ----------------------------------------------------------------

# %% [markdown]
# Train the model with larger num_epochs.

# %%
num_epochs = 30
optimizer = torch.optim.Adam(Resnet18_rev_model.parameters(), lr=learning_rate)

losses = train(Resnet18_rev_model.to(device), optimizer)
# Out:
# Epoch: 1/30 | Batch 0/938 | loss: 2.5779
# Epoch: 1/30 | Batch 10/938 | loss: 1.0650
# Epoch: 1/30 | Batch 20/938 | loss: 1.0453
# Epoch: 1/30 | Batch 30/938 | loss: 0.8953
# Epoch: 1/30 | Batch 40/938 | loss: 1.0134
# Epoch: 1/30 | Batch 50/938 | loss: 0.7812
# Epoch: 1/30 | Batch 60/938 | loss: 0.7361
# Epoch: 1/30 | Batch 70/938 | loss: 0.6460
# Epoch: 1/30 | Batch 80/938 | loss: 0.5031
# Epoch: 1/30 | Batch 90/938 | loss: 0.6433
# Epoch: 1/30 | Batch 100/938 | loss: 0.4011
# Epoch: 1/30 | Batch 110/938 | loss: 0.7789
# Epoch: 1/30 | Batch 120/938 | loss: 0.3593
# Epoch: 1/30 | Batch 130/938 | loss: 0.7009
# Epoch: 1/30 | Batch 140/938 | loss: 0.6439
# Epoch: 1/30 | Batch 150/938 | loss: 0.7226
# Epoch: 1/30 | Batch 160/938 | loss: 0.4863
# Epoch: 1/30 | Batch 170/938 | loss: 0.5210
# Epoch: 1/30 | Batch 180/938 | loss: 0.3606
# Epoch: 1/30 | Batch 190/938 | loss: 0.4517
# Epoch: 1/30 | Batch 200/938 | loss: 0.4126
# Epoch: 1/30 | Batch 210/938 | loss: 0.4265
# Epoch: 1/30 | Batch 220/938 | loss: 0.4495
# Epoch: 1/30 | Batch 230/938 | loss: 0.6623
# Epoch: 1/30 | Batch 240/938 | loss: 0.4254
# Epoch: 1/30 | Batch 250/938 | loss: 0.5587
# Epoch: 1/30 | Batch 260/938 | loss: 0.4893
# Epoch: 1/30 | Batch 270/938 | loss: 0.3212
# Epoch: 1/30 | Batch 280/938 | loss: 0.5118
# Epoch: 1/30 | Batch 290/938 | loss: 0.5259
# Epoch: 1/30 | Batch 300/938 | loss: 0.1739
# Epoch: 1/30 | Batch 310/938 | loss: 0.3642
# Epoch: 1/30 | Batch 320/938 | loss: 0.2794
# Epoch: 1/30 | Batch 330/938 | loss: 0.4200
# Epoch: 1/30 | Batch 340/938 | loss: 0.3244
# Epoch: 1/30 | Batch 350/938 | loss: 0.3510
# Epoch: 1/30 | Batch 360/938 | loss: 0.5268
# Epoch: 1/30 | Batch 370/938 | loss: 0.3109
# Epoch: 1/30 | Batch 380/938 | loss: 0.3577
# Epoch: 1/30 | Batch 390/938 | loss: 0.4194
# Epoch: 1/30 | Batch 400/938 | loss: 0.3523
# Epoch: 1/30 | Batch 410/938 | loss: 0.4121
# Epoch: 1/30 | Batch 420/938 | loss: 0.3326
# Epoch: 1/30 | Batch 430/938 | loss: 0.4092
# Epoch: 1/30 | Batch 440/938 | loss: 0.5703
# Epoch: 1/30 | Batch 450/938 | loss: 0.3541
# Epoch: 1/30 | Batch 460/938 | loss: 0.5133
# Epoch: 1/30 | Batch 470/938 | loss: 0.5784
# Epoch: 1/30 | Batch 480/938 | loss: 0.3116
# Epoch: 1/30 | Batch 490/938 | loss: 0.2951
# Epoch: 1/30 | Batch 500/938 | loss: 0.1984
# Epoch: 1/30 | Batch 510/938 | loss: 0.2187
# Epoch: 1/30 | Batch 520/938 | loss: 0.4187
# Epoch: 1/30 | Batch 530/938 | loss: 0.3799
# Epoch: 1/30 | Batch 540/938 | loss: 0.3656
# Epoch: 1/30 | Batch 550/938 | loss: 0.3707
# Epoch: 1/30 | Batch 560/938 | loss: 0.1908
# Epoch: 1/30 | Batch 570/938 | loss: 0.3320
# Epoch: 1/30 | Batch 580/938 | loss: 0.4253
# Epoch: 1/30 | Batch 590/938 | loss: 0.5245
# Epoch: 1/30 | Batch 600/938 | loss: 0.3294
# Epoch: 1/30 | Batch 610/938 | loss: 0.4144
# Epoch: 1/30 | Batch 620/938 | loss: 0.2967
# Epoch: 1/30 | Batch 630/938 | loss: 0.2129
# Epoch: 1/30 | Batch 640/938 | loss: 0.2062
# Epoch: 1/30 | Batch 650/938 | loss: 0.3524
# Epoch: 1/30 | Batch 660/938 | loss: 0.4129
# Epoch: 1/30 | Batch 670/938 | loss: 0.3861
# Epoch: 1/30 | Batch 680/938 | loss: 0.3513
# Epoch: 1/30 | Batch 690/938 | loss: 0.2681
# Epoch: 1/30 | Batch 700/938 | loss: 0.3649
# Epoch: 1/30 | Batch 710/938 | loss: 0.5253
# Epoch: 1/30 | Batch 720/938 | loss: 0.2445
# Epoch: 1/30 | Batch 730/938 | loss: 0.2502
# Epoch: 1/30 | Batch 740/938 | loss: 0.2283
# Epoch: 1/30 | Batch 750/938 | loss: 0.3652
# Epoch: 1/30 | Batch 760/938 | loss: 0.3069
# Epoch: 1/30 | Batch 770/938 | loss: 0.3220
# Epoch: 1/30 | Batch 780/938 | loss: 0.3186
# Epoch: 1/30 | Batch 790/938 | loss: 0.2639
# Epoch: 1/30 | Batch 800/938 | loss: 0.2457
# Epoch: 1/30 | Batch 810/938 | loss: 0.2891
# Epoch: 1/30 | Batch 820/938 | loss: 0.5617
# Epoch: 1/30 | Batch 830/938 | loss: 0.3376
# Epoch: 1/30 | Batch 840/938 | loss: 0.2791
# Epoch: 1/30 | Batch 850/938 | loss: 0.4080
# Epoch: 1/30 | Batch 860/938 | loss: 0.2822
# Epoch: 1/30 | Batch 870/938 | loss: 0.3625
# Epoch: 1/30 | Batch 880/938 | loss: 0.2718
# Epoch: 1/30 | Batch 890/938 | loss: 0.4134
# Epoch: 1/30 | Batch 900/938 | loss: 0.5684
# Epoch: 1/30 | Batch 910/938 | loss: 0.3339
# Epoch: 1/30 | Batch 920/938 | loss: 0.3146
# Epoch: 1/30 | Batch 930/938 | loss: 0.1626
# Epoch 1/30, training loss: 0.44787712104475574, validation loss: 0.323728970518917
# 	     precision: 0.8849
# 	        recall: 0.8814
# 	            F1: 0.8693
# 	      accuracy: 0.8820
# Epoch: 2/30 | Batch 0/938 | loss: 0.2578
# Epoch: 2/30 | Batch 10/938 | loss: 0.4696
# Epoch: 2/30 | Batch 20/938 | loss: 0.2452
# Epoch: 2/30 | Batch 30/938 | loss: 0.4046
# Epoch: 2/30 | Batch 40/938 | loss: 0.4866
# Epoch: 2/30 | Batch 50/938 | loss: 0.1813
# Epoch: 2/30 | Batch 60/938 | loss: 0.2563
# Epoch: 2/30 | Batch 70/938 | loss: 0.4552
# Epoch: 2/30 | Batch 80/938 | loss: 0.1678
# Epoch: 2/30 | Batch 90/938 | loss: 0.2752
# Epoch: 2/30 | Batch 100/938 | loss: 0.3269
# Epoch: 2/30 | Batch 110/938 | loss: 0.3224
# Epoch: 2/30 | Batch 120/938 | loss: 0.4198
# Epoch: 2/30 | Batch 130/938 | loss: 0.3253
# Epoch: 2/30 | Batch 140/938 | loss: 0.4750
# Epoch: 2/30 | Batch 150/938 | loss: 0.2914
# Epoch: 2/30 | Batch 160/938 | loss: 0.0828
# Epoch: 2/30 | Batch 170/938 | loss: 0.5229
# Epoch: 2/30 | Batch 180/938 | loss: 0.3390
# Epoch: 2/30 | Batch 190/938 | loss: 0.3509
# Epoch: 2/30 | Batch 200/938 | loss: 0.3089
# Epoch: 2/30 | Batch 210/938 | loss: 0.5182
# Epoch: 2/30 | Batch 220/938 | loss: 0.2456
# Epoch: 2/30 | Batch 230/938 | loss: 0.2258
# Epoch: 2/30 | Batch 240/938 | loss: 0.2829
# Epoch: 2/30 | Batch 250/938 | loss: 0.3320
# Epoch: 2/30 | Batch 260/938 | loss: 0.2803
# Epoch: 2/30 | Batch 270/938 | loss: 0.1990
# Epoch: 2/30 | Batch 280/938 | loss: 0.2988
# Epoch: 2/30 | Batch 290/938 | loss: 0.1770
# Epoch: 2/30 | Batch 300/938 | loss: 0.3194
# Epoch: 2/30 | Batch 310/938 | loss: 0.2689
# Epoch: 2/30 | Batch 320/938 | loss: 0.2837
# Epoch: 2/30 | Batch 330/938 | loss: 0.3075
# Epoch: 2/30 | Batch 340/938 | loss: 0.2497
# Epoch: 2/30 | Batch 350/938 | loss: 0.3272
# Epoch: 2/30 | Batch 360/938 | loss: 0.2727
# Epoch: 2/30 | Batch 370/938 | loss: 0.2948
# Epoch: 2/30 | Batch 380/938 | loss: 0.3010
# Epoch: 2/30 | Batch 390/938 | loss: 0.3342
# Epoch: 2/30 | Batch 400/938 | loss: 0.2751
# Epoch: 2/30 | Batch 410/938 | loss: 0.2704
# Epoch: 2/30 | Batch 420/938 | loss: 0.2791
# Epoch: 2/30 | Batch 430/938 | loss: 0.1586
# Epoch: 2/30 | Batch 440/938 | loss: 0.3173
# Epoch: 2/30 | Batch 450/938 | loss: 0.4038
# Epoch: 2/30 | Batch 460/938 | loss: 0.3592
# Epoch: 2/30 | Batch 470/938 | loss: 0.3853
# Epoch: 2/30 | Batch 480/938 | loss: 0.1997
# Epoch: 2/30 | Batch 490/938 | loss: 0.3346
# Epoch: 2/30 | Batch 500/938 | loss: 0.2435
# Epoch: 2/30 | Batch 510/938 | loss: 0.3780
# Epoch: 2/30 | Batch 520/938 | loss: 0.2871
# Epoch: 2/30 | Batch 530/938 | loss: 0.4341
# Epoch: 2/30 | Batch 540/938 | loss: 0.1748
# Epoch: 2/30 | Batch 550/938 | loss: 0.3634
# Epoch: 2/30 | Batch 560/938 | loss: 0.4728
# Epoch: 2/30 | Batch 570/938 | loss: 0.4217
# Epoch: 2/30 | Batch 580/938 | loss: 0.2117
# Epoch: 2/30 | Batch 590/938 | loss: 0.3342
# Epoch: 2/30 | Batch 600/938 | loss: 0.3744
# Epoch: 2/30 | Batch 610/938 | loss: 0.2947
# Epoch: 2/30 | Batch 620/938 | loss: 0.3525
# Epoch: 2/30 | Batch 630/938 | loss: 0.4270
# Epoch: 2/30 | Batch 640/938 | loss: 0.1655
# Epoch: 2/30 | Batch 650/938 | loss: 0.3727
# Epoch: 2/30 | Batch 660/938 | loss: 0.4082
# Epoch: 2/30 | Batch 670/938 | loss: 0.3160
# Epoch: 2/30 | Batch 680/938 | loss: 0.2708
# Epoch: 2/30 | Batch 690/938 | loss: 0.2624
# Epoch: 2/30 | Batch 700/938 | loss: 0.2009
# Epoch: 2/30 | Batch 710/938 | loss: 0.2898
# Epoch: 2/30 | Batch 720/938 | loss: 0.2118
# Epoch: 2/30 | Batch 730/938 | loss: 0.2145
# Epoch: 2/30 | Batch 740/938 | loss: 0.4954
# Epoch: 2/30 | Batch 750/938 | loss: 0.2420
# Epoch: 2/30 | Batch 760/938 | loss: 0.2352
# Epoch: 2/30 | Batch 770/938 | loss: 0.2064
# Epoch: 2/30 | Batch 780/938 | loss: 0.1839
# Epoch: 2/30 | Batch 790/938 | loss: 0.3335
# Epoch: 2/30 | Batch 800/938 | loss: 0.1485
# Epoch: 2/30 | Batch 810/938 | loss: 0.1406
# Epoch: 2/30 | Batch 820/938 | loss: 0.1534
# Epoch: 2/30 | Batch 830/938 | loss: 0.2148
# Epoch: 2/30 | Batch 840/938 | loss: 0.4773
# Epoch: 2/30 | Batch 850/938 | loss: 0.2724
# Epoch: 2/30 | Batch 860/938 | loss: 0.2354
# Epoch: 2/30 | Batch 870/938 | loss: 0.1741
# Epoch: 2/30 | Batch 880/938 | loss: 0.1647
# Epoch: 2/30 | Batch 890/938 | loss: 0.1685
# Epoch: 2/30 | Batch 900/938 | loss: 0.2272
# Epoch: 2/30 | Batch 910/938 | loss: 0.2235
# Epoch: 2/30 | Batch 920/938 | loss: 0.2952
# Epoch: 2/30 | Batch 930/938 | loss: 0.1528
# Epoch 2/30, training loss: 0.29756981056572784, validation loss: 0.26392184959570314
# 	     precision: 0.9049
# 	        recall: 0.9072
# 	            F1: 0.8975
# 	      accuracy: 0.9058
# Epoch: 3/30 | Batch 0/938 | loss: 0.1739
# Epoch: 3/30 | Batch 10/938 | loss: 0.2746
# Epoch: 3/30 | Batch 20/938 | loss: 0.3790
# Epoch: 3/30 | Batch 30/938 | loss: 0.2850
# Epoch: 3/30 | Batch 40/938 | loss: 0.2519
# Epoch: 3/30 | Batch 50/938 | loss: 0.1222
# Epoch: 3/30 | Batch 60/938 | loss: 0.2364
# Epoch: 3/30 | Batch 70/938 | loss: 0.2531
# Epoch: 3/30 | Batch 80/938 | loss: 0.4581
# Epoch: 3/30 | Batch 90/938 | loss: 0.4715
# Epoch: 3/30 | Batch 100/938 | loss: 0.1523
# Epoch: 3/30 | Batch 110/938 | loss: 0.2897
# Epoch: 3/30 | Batch 120/938 | loss: 0.2595
# Epoch: 3/30 | Batch 130/938 | loss: 0.2910
# Epoch: 3/30 | Batch 140/938 | loss: 0.2978
# Epoch: 3/30 | Batch 150/938 | loss: 0.3377
# Epoch: 3/30 | Batch 160/938 | loss: 0.1818
# Epoch: 3/30 | Batch 170/938 | loss: 0.1963
# Epoch: 3/30 | Batch 180/938 | loss: 0.2834
# Epoch: 3/30 | Batch 190/938 | loss: 0.2420
# Epoch: 3/30 | Batch 200/938 | loss: 0.3175
# Epoch: 3/30 | Batch 210/938 | loss: 0.2502
# Epoch: 3/30 | Batch 220/938 | loss: 0.4645
# Epoch: 3/30 | Batch 230/938 | loss: 0.2636
# Epoch: 3/30 | Batch 240/938 | loss: 0.2159
# Epoch: 3/30 | Batch 250/938 | loss: 0.1564
# Epoch: 3/30 | Batch 260/938 | loss: 0.1554
# Epoch: 3/30 | Batch 270/938 | loss: 0.2046
# Epoch: 3/30 | Batch 280/938 | loss: 0.2138
# Epoch: 3/30 | Batch 290/938 | loss: 0.3191
# Epoch: 3/30 | Batch 300/938 | loss: 0.3817
# Epoch: 3/30 | Batch 310/938 | loss: 0.3835
# Epoch: 3/30 | Batch 320/938 | loss: 0.1102
# Epoch: 3/30 | Batch 330/938 | loss: 0.2476
# Epoch: 3/30 | Batch 340/938 | loss: 0.3574
# Epoch: 3/30 | Batch 350/938 | loss: 0.3340
# Epoch: 3/30 | Batch 360/938 | loss: 0.2633
# Epoch: 3/30 | Batch 370/938 | loss: 0.2027
# Epoch: 3/30 | Batch 380/938 | loss: 0.2661
# Epoch: 3/30 | Batch 390/938 | loss: 0.2296
# Epoch: 3/30 | Batch 400/938 | loss: 0.1666
# Epoch: 3/30 | Batch 410/938 | loss: 0.2838
# Epoch: 3/30 | Batch 420/938 | loss: 0.3456
# Epoch: 3/30 | Batch 430/938 | loss: 0.3038
# Epoch: 3/30 | Batch 440/938 | loss: 0.1879
# Epoch: 3/30 | Batch 450/938 | loss: 0.3721
# Epoch: 3/30 | Batch 460/938 | loss: 0.3915
# Epoch: 3/30 | Batch 470/938 | loss: 0.1427
# Epoch: 3/30 | Batch 480/938 | loss: 0.1956
# Epoch: 3/30 | Batch 490/938 | loss: 0.3141
# Epoch: 3/30 | Batch 500/938 | loss: 0.2762
# Epoch: 3/30 | Batch 510/938 | loss: 0.1996
# Epoch: 3/30 | Batch 520/938 | loss: 0.2108
# Epoch: 3/30 | Batch 530/938 | loss: 0.1930
# Epoch: 3/30 | Batch 540/938 | loss: 0.2115
# Epoch: 3/30 | Batch 550/938 | loss: 0.2591
# Epoch: 3/30 | Batch 560/938 | loss: 0.1628
# Epoch: 3/30 | Batch 570/938 | loss: 0.2884
# Epoch: 3/30 | Batch 580/938 | loss: 0.2388
# Epoch: 3/30 | Batch 590/938 | loss: 0.2567
# Epoch: 3/30 | Batch 600/938 | loss: 0.2414
# Epoch: 3/30 | Batch 610/938 | loss: 0.1698
# Epoch: 3/30 | Batch 620/938 | loss: 0.3617
# Epoch: 3/30 | Batch 630/938 | loss: 0.1430
# Epoch: 3/30 | Batch 640/938 | loss: 0.2385
# Epoch: 3/30 | Batch 650/938 | loss: 0.1656
# Epoch: 3/30 | Batch 660/938 | loss: 0.4604
# Epoch: 3/30 | Batch 670/938 | loss: 0.2479
# Epoch: 3/30 | Batch 680/938 | loss: 0.3891
# Epoch: 3/30 | Batch 690/938 | loss: 0.4228
# Epoch: 3/30 | Batch 700/938 | loss: 0.2264
# Epoch: 3/30 | Batch 710/938 | loss: 0.2406
# Epoch: 3/30 | Batch 720/938 | loss: 0.2176
# Epoch: 3/30 | Batch 730/938 | loss: 0.2424
# Epoch: 3/30 | Batch 740/938 | loss: 0.1658
# Epoch: 3/30 | Batch 750/938 | loss: 0.2011
# Epoch: 3/30 | Batch 760/938 | loss: 0.1375
# Epoch: 3/30 | Batch 770/938 | loss: 0.1300
# Epoch: 3/30 | Batch 780/938 | loss: 0.3276
# Epoch: 3/30 | Batch 790/938 | loss: 0.3056
# Epoch: 3/30 | Batch 800/938 | loss: 0.1312
# Epoch: 3/30 | Batch 810/938 | loss: 0.2114
# Epoch: 3/30 | Batch 820/938 | loss: 0.1631
# Epoch: 3/30 | Batch 830/938 | loss: 0.1381
# Epoch: 3/30 | Batch 840/938 | loss: 0.1824
# Epoch: 3/30 | Batch 850/938 | loss: 0.3142
# Epoch: 3/30 | Batch 860/938 | loss: 0.1871
# Epoch: 3/30 | Batch 870/938 | loss: 0.3372
# Epoch: 3/30 | Batch 880/938 | loss: 0.3460
# Epoch: 3/30 | Batch 890/938 | loss: 0.3454
# Epoch: 3/30 | Batch 900/938 | loss: 0.1451
# Epoch: 3/30 | Batch 910/938 | loss: 0.1711
# Epoch: 3/30 | Batch 920/938 | loss: 0.1073
# Epoch: 3/30 | Batch 930/938 | loss: 0.2309
# Epoch 3/30, training loss: 0.2612678431498725, validation loss: 0.2572624075469697
# 	     precision: 0.9066
# 	        recall: 0.9041
# 	            F1: 0.8975
# 	      accuracy: 0.9060
# Epoch: 4/30 | Batch 0/938 | loss: 0.1308
# Epoch: 4/30 | Batch 10/938 | loss: 0.2662
# Epoch: 4/30 | Batch 20/938 | loss: 0.2346
# Epoch: 4/30 | Batch 30/938 | loss: 0.1757
# Epoch: 4/30 | Batch 40/938 | loss: 0.1746
# Epoch: 4/30 | Batch 50/938 | loss: 0.2253
# Epoch: 4/30 | Batch 60/938 | loss: 0.3087
# Epoch: 4/30 | Batch 70/938 | loss: 0.1895
# Epoch: 4/30 | Batch 80/938 | loss: 0.3570
# Epoch: 4/30 | Batch 90/938 | loss: 0.1686
# Epoch: 4/30 | Batch 100/938 | loss: 0.1857
# Epoch: 4/30 | Batch 110/938 | loss: 0.2592
# Epoch: 4/30 | Batch 120/938 | loss: 0.2479
# Epoch: 4/30 | Batch 130/938 | loss: 0.1077
# Epoch: 4/30 | Batch 140/938 | loss: 0.3017
# Epoch: 4/30 | Batch 150/938 | loss: 0.3507
# Epoch: 4/30 | Batch 160/938 | loss: 0.2037
# Epoch: 4/30 | Batch 170/938 | loss: 0.2303
# Epoch: 4/30 | Batch 180/938 | loss: 0.2157
# Epoch: 4/30 | Batch 190/938 | loss: 0.2163
# Epoch: 4/30 | Batch 200/938 | loss: 0.2045
# Epoch: 4/30 | Batch 210/938 | loss: 0.2455
# Epoch: 4/30 | Batch 220/938 | loss: 0.3204
# Epoch: 4/30 | Batch 230/938 | loss: 0.1870
# Epoch: 4/30 | Batch 240/938 | loss: 0.1611
# Epoch: 4/30 | Batch 250/938 | loss: 0.3285
# Epoch: 4/30 | Batch 260/938 | loss: 0.3561
# Epoch: 4/30 | Batch 270/938 | loss: 0.1795
# Epoch: 4/30 | Batch 280/938 | loss: 0.2856
# Epoch: 4/30 | Batch 290/938 | loss: 0.1933
# Epoch: 4/30 | Batch 300/938 | loss: 0.1396
# Epoch: 4/30 | Batch 310/938 | loss: 0.1403
# Epoch: 4/30 | Batch 320/938 | loss: 0.1933
# Epoch: 4/30 | Batch 330/938 | loss: 0.2506
# Epoch: 4/30 | Batch 340/938 | loss: 0.1433
# Epoch: 4/30 | Batch 350/938 | loss: 0.0907
# Epoch: 4/30 | Batch 360/938 | loss: 0.1653
# Epoch: 4/30 | Batch 370/938 | loss: 0.1785
# Epoch: 4/30 | Batch 380/938 | loss: 0.3218
# Epoch: 4/30 | Batch 390/938 | loss: 0.2952
# Epoch: 4/30 | Batch 400/938 | loss: 0.1771
# Epoch: 4/30 | Batch 410/938 | loss: 0.3043
# Epoch: 4/30 | Batch 420/938 | loss: 0.1759
# Epoch: 4/30 | Batch 430/938 | loss: 0.2794
# Epoch: 4/30 | Batch 440/938 | loss: 0.2075
# Epoch: 4/30 | Batch 450/938 | loss: 0.2192
# Epoch: 4/30 | Batch 460/938 | loss: 0.2672
# Epoch: 4/30 | Batch 470/938 | loss: 0.4997
# Epoch: 4/30 | Batch 480/938 | loss: 0.2707
# Epoch: 4/30 | Batch 490/938 | loss: 0.2265
# Epoch: 4/30 | Batch 500/938 | loss: 0.2986
# Epoch: 4/30 | Batch 510/938 | loss: 0.4276
# Epoch: 4/30 | Batch 520/938 | loss: 0.1442
# Epoch: 4/30 | Batch 530/938 | loss: 0.2256
# Epoch: 4/30 | Batch 540/938 | loss: 0.1500
# Epoch: 4/30 | Batch 550/938 | loss: 0.2946
# Epoch: 4/30 | Batch 560/938 | loss: 0.1314
# Epoch: 4/30 | Batch 570/938 | loss: 0.2065
# Epoch: 4/30 | Batch 580/938 | loss: 0.2504
# Epoch: 4/30 | Batch 590/938 | loss: 0.2720
# Epoch: 4/30 | Batch 600/938 | loss: 0.2645
# Epoch: 4/30 | Batch 610/938 | loss: 0.1746
# Epoch: 4/30 | Batch 620/938 | loss: 0.2165
# Epoch: 4/30 | Batch 630/938 | loss: 0.1783
# Epoch: 4/30 | Batch 640/938 | loss: 0.2749
# Epoch: 4/30 | Batch 650/938 | loss: 0.2357
# Epoch: 4/30 | Batch 660/938 | loss: 0.1546
# Epoch: 4/30 | Batch 670/938 | loss: 0.2204
# Epoch: 4/30 | Batch 680/938 | loss: 0.1769
# Epoch: 4/30 | Batch 690/938 | loss: 0.2403
# Epoch: 4/30 | Batch 700/938 | loss: 0.2700
# Epoch: 4/30 | Batch 710/938 | loss: 0.1588
# Epoch: 4/30 | Batch 720/938 | loss: 0.2394
# Epoch: 4/30 | Batch 730/938 | loss: 0.1685
# Epoch: 4/30 | Batch 740/938 | loss: 0.2807
# Epoch: 4/30 | Batch 750/938 | loss: 0.1496
# Epoch: 4/30 | Batch 760/938 | loss: 0.2748
# Epoch: 4/30 | Batch 770/938 | loss: 0.2878
# Epoch: 4/30 | Batch 780/938 | loss: 0.2022
# Epoch: 4/30 | Batch 790/938 | loss: 0.1844
# Epoch: 4/30 | Batch 800/938 | loss: 0.1961
# Epoch: 4/30 | Batch 810/938 | loss: 0.2559
# Epoch: 4/30 | Batch 820/938 | loss: 0.1909
# Epoch: 4/30 | Batch 830/938 | loss: 0.2830
# Epoch: 4/30 | Batch 840/938 | loss: 0.1988
# Epoch: 4/30 | Batch 850/938 | loss: 0.2277
# Epoch: 4/30 | Batch 860/938 | loss: 0.1636
# Epoch: 4/30 | Batch 870/938 | loss: 0.1163
# Epoch: 4/30 | Batch 880/938 | loss: 0.2752
# Epoch: 4/30 | Batch 890/938 | loss: 0.0898
# Epoch: 4/30 | Batch 900/938 | loss: 0.2163
# Epoch: 4/30 | Batch 910/938 | loss: 0.2422
# Epoch: 4/30 | Batch 920/938 | loss: 0.2842
# Epoch: 4/30 | Batch 930/938 | loss: 0.2458
# Epoch 4/30, training loss: 0.23388892899094615, validation loss: 0.2366256641734178
# 	     precision: 0.9128
# 	        recall: 0.9130
# 	            F1: 0.9057
# 	      accuracy: 0.9131
# Epoch: 5/30 | Batch 0/938 | loss: 0.0893
# Epoch: 5/30 | Batch 10/938 | loss: 0.0596
# Epoch: 5/30 | Batch 20/938 | loss: 0.1534
# Epoch: 5/30 | Batch 30/938 | loss: 0.1762
# Epoch: 5/30 | Batch 40/938 | loss: 0.1744
# Epoch: 5/30 | Batch 50/938 | loss: 0.2212
# Epoch: 5/30 | Batch 60/938 | loss: 0.2164
# Epoch: 5/30 | Batch 70/938 | loss: 0.1782
# Epoch: 5/30 | Batch 80/938 | loss: 0.2342
# Epoch: 5/30 | Batch 90/938 | loss: 0.2374
# Epoch: 5/30 | Batch 100/938 | loss: 0.2371
# Epoch: 5/30 | Batch 110/938 | loss: 0.1474
# Epoch: 5/30 | Batch 120/938 | loss: 0.0589
# Epoch: 5/30 | Batch 130/938 | loss: 0.2422
# Epoch: 5/30 | Batch 140/938 | loss: 0.2579
# Epoch: 5/30 | Batch 150/938 | loss: 0.3696
# Epoch: 5/30 | Batch 160/938 | loss: 0.2340
# Epoch: 5/30 | Batch 170/938 | loss: 0.1375
# Epoch: 5/30 | Batch 180/938 | loss: 0.3296
# Epoch: 5/30 | Batch 190/938 | loss: 0.1845
# Epoch: 5/30 | Batch 200/938 | loss: 0.1727
# Epoch: 5/30 | Batch 210/938 | loss: 0.1361
# Epoch: 5/30 | Batch 220/938 | loss: 0.1832
# Epoch: 5/30 | Batch 230/938 | loss: 0.1831
# Epoch: 5/30 | Batch 240/938 | loss: 0.2821
# Epoch: 5/30 | Batch 250/938 | loss: 0.2031
# Epoch: 5/30 | Batch 260/938 | loss: 0.0931
# Epoch: 5/30 | Batch 270/938 | loss: 0.2733
# Epoch: 5/30 | Batch 280/938 | loss: 0.2594
# Epoch: 5/30 | Batch 290/938 | loss: 0.1905
# Epoch: 5/30 | Batch 300/938 | loss: 0.2562
# Epoch: 5/30 | Batch 310/938 | loss: 0.1414
# Epoch: 5/30 | Batch 320/938 | loss: 0.1778
# Epoch: 5/30 | Batch 330/938 | loss: 0.1271
# Epoch: 5/30 | Batch 340/938 | loss: 0.2696
# Epoch: 5/30 | Batch 350/938 | loss: 0.1810
# Epoch: 5/30 | Batch 360/938 | loss: 0.2039
# Epoch: 5/30 | Batch 370/938 | loss: 0.1078
# Epoch: 5/30 | Batch 380/938 | loss: 0.1963
# Epoch: 5/30 | Batch 390/938 | loss: 0.0856
# Epoch: 5/30 | Batch 400/938 | loss: 0.1892
# Epoch: 5/30 | Batch 410/938 | loss: 0.2496
# Epoch: 5/30 | Batch 420/938 | loss: 0.2361
# Epoch: 5/30 | Batch 430/938 | loss: 0.3460
# Epoch: 5/30 | Batch 440/938 | loss: 0.2021
# Epoch: 5/30 | Batch 450/938 | loss: 0.3479
# Epoch: 5/30 | Batch 460/938 | loss: 0.3219
# Epoch: 5/30 | Batch 470/938 | loss: 0.2619
# Epoch: 5/30 | Batch 480/938 | loss: 0.1867
# Epoch: 5/30 | Batch 490/938 | loss: 0.1664
# Epoch: 5/30 | Batch 500/938 | loss: 0.1781
# Epoch: 5/30 | Batch 510/938 | loss: 0.2138
# Epoch: 5/30 | Batch 520/938 | loss: 0.1437
# Epoch: 5/30 | Batch 530/938 | loss: 0.1441
# Epoch: 5/30 | Batch 540/938 | loss: 0.0991
# Epoch: 5/30 | Batch 550/938 | loss: 0.1113
# Epoch: 5/30 | Batch 560/938 | loss: 0.2498
# Epoch: 5/30 | Batch 570/938 | loss: 0.1390
# Epoch: 5/30 | Batch 580/938 | loss: 0.2039
# Epoch: 5/30 | Batch 590/938 | loss: 0.1534
# Epoch: 5/30 | Batch 600/938 | loss: 0.2051
# Epoch: 5/30 | Batch 610/938 | loss: 0.4309
# Epoch: 5/30 | Batch 620/938 | loss: 0.1247
# Epoch: 5/30 | Batch 630/938 | loss: 0.1564
# Epoch: 5/30 | Batch 640/938 | loss: 0.4851
# Epoch: 5/30 | Batch 650/938 | loss: 0.0936
# Epoch: 5/30 | Batch 660/938 | loss: 0.2000
# Epoch: 5/30 | Batch 670/938 | loss: 0.1468
# Epoch: 5/30 | Batch 680/938 | loss: 0.3021
# Epoch: 5/30 | Batch 690/938 | loss: 0.1317
# Epoch: 5/30 | Batch 700/938 | loss: 0.0933
# Epoch: 5/30 | Batch 710/938 | loss: 0.2169
# Epoch: 5/30 | Batch 720/938 | loss: 0.1673
# Epoch: 5/30 | Batch 730/938 | loss: 0.2704
# Epoch: 5/30 | Batch 740/938 | loss: 0.1744
# Epoch: 5/30 | Batch 750/938 | loss: 0.2500
# Epoch: 5/30 | Batch 760/938 | loss: 0.2718
# Epoch: 5/30 | Batch 770/938 | loss: 0.2017
# Epoch: 5/30 | Batch 780/938 | loss: 0.2735
# Epoch: 5/30 | Batch 790/938 | loss: 0.2382
# Epoch: 5/30 | Batch 800/938 | loss: 0.2497
# Epoch: 5/30 | Batch 810/938 | loss: 0.1236
# Epoch: 5/30 | Batch 820/938 | loss: 0.3512
# Epoch: 5/30 | Batch 830/938 | loss: 0.2366
# Epoch: 5/30 | Batch 840/938 | loss: 0.3353
# Epoch: 5/30 | Batch 850/938 | loss: 0.3814
# Epoch: 5/30 | Batch 860/938 | loss: 0.0744
# Epoch: 5/30 | Batch 870/938 | loss: 0.1881
# Epoch: 5/30 | Batch 880/938 | loss: 0.2296
# Epoch: 5/30 | Batch 890/938 | loss: 0.2250
# Epoch: 5/30 | Batch 900/938 | loss: 0.3033
# Epoch: 5/30 | Batch 910/938 | loss: 0.1673
# Epoch: 5/30 | Batch 920/938 | loss: 0.2866
# Epoch: 5/30 | Batch 930/938 | loss: 0.1731
# Epoch 5/30, training loss: 0.21480921262315214, validation loss: 0.23303998646083152
# 	     precision: 0.9125
# 	        recall: 0.9115
# 	            F1: 0.9035
# 	      accuracy: 0.9113
# Epoch: 6/30 | Batch 0/938 | loss: 0.3546
# Epoch: 6/30 | Batch 10/938 | loss: 0.0940
# Epoch: 6/30 | Batch 20/938 | loss: 0.2010
# Epoch: 6/30 | Batch 30/938 | loss: 0.1683
# Epoch: 6/30 | Batch 40/938 | loss: 0.1530
# Epoch: 6/30 | Batch 50/938 | loss: 0.1096
# Epoch: 6/30 | Batch 60/938 | loss: 0.2354
# Epoch: 6/30 | Batch 70/938 | loss: 0.1598
# Epoch: 6/30 | Batch 80/938 | loss: 0.2513
# Epoch: 6/30 | Batch 90/938 | loss: 0.2643
# Epoch: 6/30 | Batch 100/938 | loss: 0.1145
# Epoch: 6/30 | Batch 110/938 | loss: 0.1916
# Epoch: 6/30 | Batch 120/938 | loss: 0.2198
# Epoch: 6/30 | Batch 130/938 | loss: 0.1330
# Epoch: 6/30 | Batch 140/938 | loss: 0.1863
# Epoch: 6/30 | Batch 150/938 | loss: 0.1597
# Epoch: 6/30 | Batch 160/938 | loss: 0.1125
# Epoch: 6/30 | Batch 170/938 | loss: 0.2063
# Epoch: 6/30 | Batch 180/938 | loss: 0.2135
# Epoch: 6/30 | Batch 190/938 | loss: 0.2906
# Epoch: 6/30 | Batch 200/938 | loss: 0.1028
# Epoch: 6/30 | Batch 210/938 | loss: 0.1660
# Epoch: 6/30 | Batch 220/938 | loss: 0.2116
# Epoch: 6/30 | Batch 230/938 | loss: 0.1086
# Epoch: 6/30 | Batch 240/938 | loss: 0.2175
# Epoch: 6/30 | Batch 250/938 | loss: 0.2968
# Epoch: 6/30 | Batch 260/938 | loss: 0.2396
# Epoch: 6/30 | Batch 270/938 | loss: 0.2290
# Epoch: 6/30 | Batch 280/938 | loss: 0.2145
# Epoch: 6/30 | Batch 290/938 | loss: 0.3814
# Epoch: 6/30 | Batch 300/938 | loss: 0.1322
# Epoch: 6/30 | Batch 310/938 | loss: 0.1156
# Epoch: 6/30 | Batch 320/938 | loss: 0.1560
# Epoch: 6/30 | Batch 330/938 | loss: 0.1281
# Epoch: 6/30 | Batch 340/938 | loss: 0.0943
# Epoch: 6/30 | Batch 350/938 | loss: 0.1334
# Epoch: 6/30 | Batch 360/938 | loss: 0.0938
# Epoch: 6/30 | Batch 370/938 | loss: 0.1546
# Epoch: 6/30 | Batch 380/938 | loss: 0.1832
# Epoch: 6/30 | Batch 390/938 | loss: 0.1273
# Epoch: 6/30 | Batch 400/938 | loss: 0.1291
# Epoch: 6/30 | Batch 410/938 | loss: 0.1908
# Epoch: 6/30 | Batch 420/938 | loss: 0.1476
# Epoch: 6/30 | Batch 430/938 | loss: 0.3020
# Epoch: 6/30 | Batch 440/938 | loss: 0.1586
# Epoch: 6/30 | Batch 450/938 | loss: 0.2652
# Epoch: 6/30 | Batch 460/938 | loss: 0.2145
# Epoch: 6/30 | Batch 470/938 | loss: 0.1973
# Epoch: 6/30 | Batch 480/938 | loss: 0.1637
# Epoch: 6/30 | Batch 490/938 | loss: 0.2386
# Epoch: 6/30 | Batch 500/938 | loss: 0.2706
# Epoch: 6/30 | Batch 510/938 | loss: 0.1616
# Epoch: 6/30 | Batch 520/938 | loss: 0.3131
# Epoch: 6/30 | Batch 530/938 | loss: 0.2625
# Epoch: 6/30 | Batch 540/938 | loss: 0.1094
# Epoch: 6/30 | Batch 550/938 | loss: 0.1471
# Epoch: 6/30 | Batch 560/938 | loss: 0.2079
# Epoch: 6/30 | Batch 570/938 | loss: 0.1219
# Epoch: 6/30 | Batch 580/938 | loss: 0.2046
# Epoch: 6/30 | Batch 590/938 | loss: 0.1663
# Epoch: 6/30 | Batch 600/938 | loss: 0.1391
# Epoch: 6/30 | Batch 610/938 | loss: 0.1622
# Epoch: 6/30 | Batch 620/938 | loss: 0.1692
# Epoch: 6/30 | Batch 630/938 | loss: 0.1131
# Epoch: 6/30 | Batch 640/938 | loss: 0.1833
# Epoch: 6/30 | Batch 650/938 | loss: 0.0798
# Epoch: 6/30 | Batch 660/938 | loss: 0.2008
# Epoch: 6/30 | Batch 670/938 | loss: 0.1500
# Epoch: 6/30 | Batch 680/938 | loss: 0.0741
# Epoch: 6/30 | Batch 690/938 | loss: 0.2678
# Epoch: 6/30 | Batch 700/938 | loss: 0.3041
# Epoch: 6/30 | Batch 710/938 | loss: 0.2291
# Epoch: 6/30 | Batch 720/938 | loss: 0.2360
# Epoch: 6/30 | Batch 730/938 | loss: 0.1218
# Epoch: 6/30 | Batch 740/938 | loss: 0.2296
# Epoch: 6/30 | Batch 750/938 | loss: 0.3087
# Epoch: 6/30 | Batch 760/938 | loss: 0.2658
# Epoch: 6/30 | Batch 770/938 | loss: 0.2873
# Epoch: 6/30 | Batch 780/938 | loss: 0.1295
# Epoch: 6/30 | Batch 790/938 | loss: 0.1143
# Epoch: 6/30 | Batch 800/938 | loss: 0.2613
# Epoch: 6/30 | Batch 810/938 | loss: 0.3388
# Epoch: 6/30 | Batch 820/938 | loss: 0.1918
# Epoch: 6/30 | Batch 830/938 | loss: 0.1622
# Epoch: 6/30 | Batch 840/938 | loss: 0.2727
# Epoch: 6/30 | Batch 850/938 | loss: 0.2795
# Epoch: 6/30 | Batch 860/938 | loss: 0.1348
# Epoch: 6/30 | Batch 870/938 | loss: 0.1514
# Epoch: 6/30 | Batch 880/938 | loss: 0.1308
# Epoch: 6/30 | Batch 890/938 | loss: 0.0965
# Epoch: 6/30 | Batch 900/938 | loss: 0.2026
# Epoch: 6/30 | Batch 910/938 | loss: 0.2620
# Epoch: 6/30 | Batch 920/938 | loss: 0.1871
# Epoch: 6/30 | Batch 930/938 | loss: 0.0770
# Epoch 6/30, training loss: 0.19432843889572474, validation loss: 0.22252934551827466
# 	     precision: 0.9190
# 	        recall: 0.9209
# 	            F1: 0.9132
# 	      accuracy: 0.9201
# Epoch: 7/30 | Batch 0/938 | loss: 0.1863
# Epoch: 7/30 | Batch 10/938 | loss: 0.0854
# Epoch: 7/30 | Batch 20/938 | loss: 0.2297
# Epoch: 7/30 | Batch 30/938 | loss: 0.0729
# Epoch: 7/30 | Batch 40/938 | loss: 0.0978
# Epoch: 7/30 | Batch 50/938 | loss: 0.1358
# Epoch: 7/30 | Batch 60/938 | loss: 0.1193
# Epoch: 7/30 | Batch 70/938 | loss: 0.2370
# Epoch: 7/30 | Batch 80/938 | loss: 0.2000
# Epoch: 7/30 | Batch 90/938 | loss: 0.3200
# Epoch: 7/30 | Batch 100/938 | loss: 0.2529
# Epoch: 7/30 | Batch 110/938 | loss: 0.1016
# Epoch: 7/30 | Batch 120/938 | loss: 0.1187
# Epoch: 7/30 | Batch 130/938 | loss: 0.0685
# Epoch: 7/30 | Batch 140/938 | loss: 0.2382
# Epoch: 7/30 | Batch 150/938 | loss: 0.1367
# Epoch: 7/30 | Batch 160/938 | loss: 0.1226
# Epoch: 7/30 | Batch 170/938 | loss: 0.1684
# Epoch: 7/30 | Batch 180/938 | loss: 0.3393
# Epoch: 7/30 | Batch 190/938 | loss: 0.2308
# Epoch: 7/30 | Batch 200/938 | loss: 0.2028
# Epoch: 7/30 | Batch 210/938 | loss: 0.1290
# Epoch: 7/30 | Batch 220/938 | loss: 0.1487
# Epoch: 7/30 | Batch 230/938 | loss: 0.1438
# Epoch: 7/30 | Batch 240/938 | loss: 0.1787
# Epoch: 7/30 | Batch 250/938 | loss: 0.0970
# Epoch: 7/30 | Batch 260/938 | loss: 0.0516
# Epoch: 7/30 | Batch 270/938 | loss: 0.2452
# Epoch: 7/30 | Batch 280/938 | loss: 0.1760
# Epoch: 7/30 | Batch 290/938 | loss: 0.0969
# Epoch: 7/30 | Batch 300/938 | loss: 0.1524
# Epoch: 7/30 | Batch 310/938 | loss: 0.0457
# Epoch: 7/30 | Batch 320/938 | loss: 0.1316
# Epoch: 7/30 | Batch 330/938 | loss: 0.2362
# Epoch: 7/30 | Batch 340/938 | loss: 0.1697
# Epoch: 7/30 | Batch 350/938 | loss: 0.2702
# Epoch: 7/30 | Batch 360/938 | loss: 0.2736
# Epoch: 7/30 | Batch 370/938 | loss: 0.1110
# Epoch: 7/30 | Batch 380/938 | loss: 0.1835
# Epoch: 7/30 | Batch 390/938 | loss: 0.1086
# Epoch: 7/30 | Batch 400/938 | loss: 0.1014
# Epoch: 7/30 | Batch 410/938 | loss: 0.1759
# Epoch: 7/30 | Batch 420/938 | loss: 0.1638
# Epoch: 7/30 | Batch 430/938 | loss: 0.1874
# Epoch: 7/30 | Batch 440/938 | loss: 0.1514
# Epoch: 7/30 | Batch 450/938 | loss: 0.1615
# Epoch: 7/30 | Batch 460/938 | loss: 0.1535
# Epoch: 7/30 | Batch 470/938 | loss: 0.1544
# Epoch: 7/30 | Batch 480/938 | loss: 0.1488
# Epoch: 7/30 | Batch 490/938 | loss: 0.2627
# Epoch: 7/30 | Batch 500/938 | loss: 0.1849
# Epoch: 7/30 | Batch 510/938 | loss: 0.2186
# Epoch: 7/30 | Batch 520/938 | loss: 0.1136
# Epoch: 7/30 | Batch 530/938 | loss: 0.3929
# Epoch: 7/30 | Batch 540/938 | loss: 0.1730
# Epoch: 7/30 | Batch 550/938 | loss: 0.1909
# Epoch: 7/30 | Batch 560/938 | loss: 0.1933
# Epoch: 7/30 | Batch 570/938 | loss: 0.2728
# Epoch: 7/30 | Batch 580/938 | loss: 0.3349
# Epoch: 7/30 | Batch 590/938 | loss: 0.1295
# Epoch: 7/30 | Batch 600/938 | loss: 0.3581
# Epoch: 7/30 | Batch 610/938 | loss: 0.1792
# Epoch: 7/30 | Batch 620/938 | loss: 0.1690
# Epoch: 7/30 | Batch 630/938 | loss: 0.2542
# Epoch: 7/30 | Batch 640/938 | loss: 0.2038
# Epoch: 7/30 | Batch 650/938 | loss: 0.1958
# Epoch: 7/30 | Batch 660/938 | loss: 0.1685
# Epoch: 7/30 | Batch 670/938 | loss: 0.1301
# Epoch: 7/30 | Batch 680/938 | loss: 0.2667
# Epoch: 7/30 | Batch 690/938 | loss: 0.1721
# Epoch: 7/30 | Batch 700/938 | loss: 0.1303
# Epoch: 7/30 | Batch 710/938 | loss: 0.1499
# Epoch: 7/30 | Batch 720/938 | loss: 0.2048
# Epoch: 7/30 | Batch 730/938 | loss: 0.1281
# Epoch: 7/30 | Batch 740/938 | loss: 0.1775
# Epoch: 7/30 | Batch 750/938 | loss: 0.2103
# Epoch: 7/30 | Batch 760/938 | loss: 0.2767
# Epoch: 7/30 | Batch 770/938 | loss: 0.1474
# Epoch: 7/30 | Batch 780/938 | loss: 0.2061
# Epoch: 7/30 | Batch 790/938 | loss: 0.2022
# Epoch: 7/30 | Batch 800/938 | loss: 0.1699
# Epoch: 7/30 | Batch 810/938 | loss: 0.2083
# Epoch: 7/30 | Batch 820/938 | loss: 0.1691
# Epoch: 7/30 | Batch 830/938 | loss: 0.0984
# Epoch: 7/30 | Batch 840/938 | loss: 0.1351
# Epoch: 7/30 | Batch 850/938 | loss: 0.1321
# Epoch: 7/30 | Batch 860/938 | loss: 0.1914
# Epoch: 7/30 | Batch 870/938 | loss: 0.1957
# Epoch: 7/30 | Batch 880/938 | loss: 0.2636
# Epoch: 7/30 | Batch 890/938 | loss: 0.1603
# Epoch: 7/30 | Batch 900/938 | loss: 0.1409
# Epoch: 7/30 | Batch 910/938 | loss: 0.0735
# Epoch: 7/30 | Batch 920/938 | loss: 0.1122
# Epoch: 7/30 | Batch 930/938 | loss: 0.1992
# Epoch 7/30, training loss: 0.17874413142914075, validation loss: 0.2269872771042168
# 	     precision: 0.9190
# 	        recall: 0.9187
# 	            F1: 0.9122
# 	      accuracy: 0.9212
# Epoch: 8/30 | Batch 0/938 | loss: 0.2468
# Epoch: 8/30 | Batch 10/938 | loss: 0.1836
# Epoch: 8/30 | Batch 20/938 | loss: 0.1303
# Epoch: 8/30 | Batch 30/938 | loss: 0.1414
# Epoch: 8/30 | Batch 40/938 | loss: 0.0946
# Epoch: 8/30 | Batch 50/938 | loss: 0.0490
# Epoch: 8/30 | Batch 60/938 | loss: 0.0712
# Epoch: 8/30 | Batch 70/938 | loss: 0.1209
# Epoch: 8/30 | Batch 80/938 | loss: 0.1167
# Epoch: 8/30 | Batch 90/938 | loss: 0.0549
# Epoch: 8/30 | Batch 100/938 | loss: 0.0503
# Epoch: 8/30 | Batch 110/938 | loss: 0.1741
# Epoch: 8/30 | Batch 120/938 | loss: 0.0441
# Epoch: 8/30 | Batch 130/938 | loss: 0.0689
# Epoch: 8/30 | Batch 140/938 | loss: 0.1945
# Epoch: 8/30 | Batch 150/938 | loss: 0.0963
# Epoch: 8/30 | Batch 160/938 | loss: 0.1881
# Epoch: 8/30 | Batch 170/938 | loss: 0.0748
# Epoch: 8/30 | Batch 180/938 | loss: 0.2059
# Epoch: 8/30 | Batch 190/938 | loss: 0.1708
# Epoch: 8/30 | Batch 200/938 | loss: 0.1417
# Epoch: 8/30 | Batch 210/938 | loss: 0.1748
# Epoch: 8/30 | Batch 220/938 | loss: 0.0938
# Epoch: 8/30 | Batch 230/938 | loss: 0.3373
# Epoch: 8/30 | Batch 240/938 | loss: 0.1402
# Epoch: 8/30 | Batch 250/938 | loss: 0.0909
# Epoch: 8/30 | Batch 260/938 | loss: 0.1706
# Epoch: 8/30 | Batch 270/938 | loss: 0.2780
# Epoch: 8/30 | Batch 280/938 | loss: 0.1433
# Epoch: 8/30 | Batch 290/938 | loss: 0.0780
# Epoch: 8/30 | Batch 300/938 | loss: 0.1282
# Epoch: 8/30 | Batch 310/938 | loss: 0.1378
# Epoch: 8/30 | Batch 320/938 | loss: 0.1378
# Epoch: 8/30 | Batch 330/938 | loss: 0.0778
# Epoch: 8/30 | Batch 340/938 | loss: 0.1592
# Epoch: 8/30 | Batch 350/938 | loss: 0.1550
# Epoch: 8/30 | Batch 360/938 | loss: 0.1216
# Epoch: 8/30 | Batch 370/938 | loss: 0.1114
# Epoch: 8/30 | Batch 380/938 | loss: 0.0840
# Epoch: 8/30 | Batch 390/938 | loss: 0.1765
# Epoch: 8/30 | Batch 400/938 | loss: 0.0959
# Epoch: 8/30 | Batch 410/938 | loss: 0.3130
# Epoch: 8/30 | Batch 420/938 | loss: 0.2413
# Epoch: 8/30 | Batch 430/938 | loss: 0.1324
# Epoch: 8/30 | Batch 440/938 | loss: 0.1498
# Epoch: 8/30 | Batch 450/938 | loss: 0.1976
# Epoch: 8/30 | Batch 460/938 | loss: 0.0461
# Epoch: 8/30 | Batch 470/938 | loss: 0.1980
# Epoch: 8/30 | Batch 480/938 | loss: 0.1198
# Epoch: 8/30 | Batch 490/938 | loss: 0.2643
# Epoch: 8/30 | Batch 500/938 | loss: 0.2047
# Epoch: 8/30 | Batch 510/938 | loss: 0.1860
# Epoch: 8/30 | Batch 520/938 | loss: 0.2984
# Epoch: 8/30 | Batch 530/938 | loss: 0.0605
# Epoch: 8/30 | Batch 540/938 | loss: 0.1176
# Epoch: 8/30 | Batch 550/938 | loss: 0.2734
# Epoch: 8/30 | Batch 560/938 | loss: 0.2349
# Epoch: 8/30 | Batch 570/938 | loss: 0.1706
# Epoch: 8/30 | Batch 580/938 | loss: 0.2457
# Epoch: 8/30 | Batch 590/938 | loss: 0.1886
# Epoch: 8/30 | Batch 600/938 | loss: 0.2286
# Epoch: 8/30 | Batch 610/938 | loss: 0.2429
# Epoch: 8/30 | Batch 620/938 | loss: 0.1373
# Epoch: 8/30 | Batch 630/938 | loss: 0.1845
# Epoch: 8/30 | Batch 640/938 | loss: 0.2134
# Epoch: 8/30 | Batch 650/938 | loss: 0.1325
# Epoch: 8/30 | Batch 660/938 | loss: 0.2636
# Epoch: 8/30 | Batch 670/938 | loss: 0.1106
# Epoch: 8/30 | Batch 680/938 | loss: 0.1703
# Epoch: 8/30 | Batch 690/938 | loss: 0.1343
# Epoch: 8/30 | Batch 700/938 | loss: 0.0753
# Epoch: 8/30 | Batch 710/938 | loss: 0.1236
# Epoch: 8/30 | Batch 720/938 | loss: 0.3077
# Epoch: 8/30 | Batch 730/938 | loss: 0.1160
# Epoch: 8/30 | Batch 740/938 | loss: 0.2077
# Epoch: 8/30 | Batch 750/938 | loss: 0.1323
# Epoch: 8/30 | Batch 760/938 | loss: 0.3111
# Epoch: 8/30 | Batch 770/938 | loss: 0.1281
# Epoch: 8/30 | Batch 780/938 | loss: 0.0907
# Epoch: 8/30 | Batch 790/938 | loss: 0.1245
# Epoch: 8/30 | Batch 800/938 | loss: 0.2171
# Epoch: 8/30 | Batch 810/938 | loss: 0.0587
# Epoch: 8/30 | Batch 820/938 | loss: 0.0689
# Epoch: 8/30 | Batch 830/938 | loss: 0.0883
# Epoch: 8/30 | Batch 840/938 | loss: 0.2520
# Epoch: 8/30 | Batch 850/938 | loss: 0.2108
# Epoch: 8/30 | Batch 860/938 | loss: 0.1186
# Epoch: 8/30 | Batch 870/938 | loss: 0.1397
# Epoch: 8/30 | Batch 880/938 | loss: 0.0928
# Epoch: 8/30 | Batch 890/938 | loss: 0.2529
# Epoch: 8/30 | Batch 900/938 | loss: 0.1372
# Epoch: 8/30 | Batch 910/938 | loss: 0.1314
# Epoch: 8/30 | Batch 920/938 | loss: 0.1818
# Epoch: 8/30 | Batch 930/938 | loss: 0.0679
# Epoch 8/30, training loss: 0.16373074424665557, validation loss: 0.22180477216555056
# 	     precision: 0.9250
# 	        recall: 0.9231
# 	            F1: 0.9174
# 	      accuracy: 0.9234
# Epoch: 9/30 | Batch 0/938 | loss: 0.1032
# Epoch: 9/30 | Batch 10/938 | loss: 0.0599
# Epoch: 9/30 | Batch 20/938 | loss: 0.1363
# Epoch: 9/30 | Batch 30/938 | loss: 0.1290
# Epoch: 9/30 | Batch 40/938 | loss: 0.0729
# Epoch: 9/30 | Batch 50/938 | loss: 0.1543
# Epoch: 9/30 | Batch 60/938 | loss: 0.1887
# Epoch: 9/30 | Batch 70/938 | loss: 0.0894
# Epoch: 9/30 | Batch 80/938 | loss: 0.2072
# Epoch: 9/30 | Batch 90/938 | loss: 0.0934
# Epoch: 9/30 | Batch 100/938 | loss: 0.2002
# Epoch: 9/30 | Batch 110/938 | loss: 0.2151
# Epoch: 9/30 | Batch 120/938 | loss: 0.1085
# Epoch: 9/30 | Batch 130/938 | loss: 0.2370
# Epoch: 9/30 | Batch 140/938 | loss: 0.1866
# Epoch: 9/30 | Batch 150/938 | loss: 0.1121
# Epoch: 9/30 | Batch 160/938 | loss: 0.2284
# Epoch: 9/30 | Batch 170/938 | loss: 0.0522
# Epoch: 9/30 | Batch 180/938 | loss: 0.1291
# Epoch: 9/30 | Batch 190/938 | loss: 0.0737
# Epoch: 9/30 | Batch 200/938 | loss: 0.2168
# Epoch: 9/30 | Batch 210/938 | loss: 0.1250
# Epoch: 9/30 | Batch 220/938 | loss: 0.1340
# Epoch: 9/30 | Batch 230/938 | loss: 0.1121
# Epoch: 9/30 | Batch 240/938 | loss: 0.0978
# Epoch: 9/30 | Batch 250/938 | loss: 0.2417
# Epoch: 9/30 | Batch 260/938 | loss: 0.0907
# Epoch: 9/30 | Batch 270/938 | loss: 0.2174
# Epoch: 9/30 | Batch 280/938 | loss: 0.3103
# Epoch: 9/30 | Batch 290/938 | loss: 0.1286
# Epoch: 9/30 | Batch 300/938 | loss: 0.1014
# Epoch: 9/30 | Batch 310/938 | loss: 0.1361
# Epoch: 9/30 | Batch 320/938 | loss: 0.1401
# Epoch: 9/30 | Batch 330/938 | loss: 0.1231
# Epoch: 9/30 | Batch 340/938 | loss: 0.2130
# Epoch: 9/30 | Batch 350/938 | loss: 0.2126
# Epoch: 9/30 | Batch 360/938 | loss: 0.1214
# Epoch: 9/30 | Batch 370/938 | loss: 0.0714
# Epoch: 9/30 | Batch 380/938 | loss: 0.1041
# Epoch: 9/30 | Batch 390/938 | loss: 0.1467
# Epoch: 9/30 | Batch 400/938 | loss: 0.1211
# Epoch: 9/30 | Batch 410/938 | loss: 0.2437
# Epoch: 9/30 | Batch 420/938 | loss: 0.0823
# Epoch: 9/30 | Batch 430/938 | loss: 0.1216
# Epoch: 9/30 | Batch 440/938 | loss: 0.2697
# Epoch: 9/30 | Batch 450/938 | loss: 0.1684
# Epoch: 9/30 | Batch 460/938 | loss: 0.1996
# Epoch: 9/30 | Batch 470/938 | loss: 0.1794
# Epoch: 9/30 | Batch 480/938 | loss: 0.1005
# Epoch: 9/30 | Batch 490/938 | loss: 0.1433
# Epoch: 9/30 | Batch 500/938 | loss: 0.1302
# Epoch: 9/30 | Batch 510/938 | loss: 0.1975
# Epoch: 9/30 | Batch 520/938 | loss: 0.1707
# Epoch: 9/30 | Batch 530/938 | loss: 0.1493
# Epoch: 9/30 | Batch 540/938 | loss: 0.1848
# Epoch: 9/30 | Batch 550/938 | loss: 0.1476
# Epoch: 9/30 | Batch 560/938 | loss: 0.2314
# Epoch: 9/30 | Batch 570/938 | loss: 0.1827
# Epoch: 9/30 | Batch 580/938 | loss: 0.1232
# Epoch: 9/30 | Batch 590/938 | loss: 0.2177
# Epoch: 9/30 | Batch 600/938 | loss: 0.1810
# Epoch: 9/30 | Batch 610/938 | loss: 0.0833
# Epoch: 9/30 | Batch 620/938 | loss: 0.0901
# Epoch: 9/30 | Batch 630/938 | loss: 0.1463
# Epoch: 9/30 | Batch 640/938 | loss: 0.1296
# Epoch: 9/30 | Batch 650/938 | loss: 0.1433
# Epoch: 9/30 | Batch 660/938 | loss: 0.0932
# Epoch: 9/30 | Batch 670/938 | loss: 0.1099
# Epoch: 9/30 | Batch 680/938 | loss: 0.1153
# Epoch: 9/30 | Batch 690/938 | loss: 0.1755
# Epoch: 9/30 | Batch 700/938 | loss: 0.1282
# Epoch: 9/30 | Batch 710/938 | loss: 0.1503
# Epoch: 9/30 | Batch 720/938 | loss: 0.1620
# Epoch: 9/30 | Batch 730/938 | loss: 0.0666
# Epoch: 9/30 | Batch 740/938 | loss: 0.1289
# Epoch: 9/30 | Batch 750/938 | loss: 0.1057
# Epoch: 9/30 | Batch 760/938 | loss: 0.1419
# Epoch: 9/30 | Batch 770/938 | loss: 0.2338
# Epoch: 9/30 | Batch 780/938 | loss: 0.2205
# Epoch: 9/30 | Batch 790/938 | loss: 0.1185
# Epoch: 9/30 | Batch 800/938 | loss: 0.2591
# Epoch: 9/30 | Batch 810/938 | loss: 0.2751
# Epoch: 9/30 | Batch 820/938 | loss: 0.3361
# Epoch: 9/30 | Batch 830/938 | loss: 0.0904
# Epoch: 9/30 | Batch 840/938 | loss: 0.1909
# Epoch: 9/30 | Batch 850/938 | loss: 0.1572
# Epoch: 9/30 | Batch 860/938 | loss: 0.1973
# Epoch: 9/30 | Batch 870/938 | loss: 0.0972
# Epoch: 9/30 | Batch 880/938 | loss: 0.2783
# Epoch: 9/30 | Batch 890/938 | loss: 0.1534
# Epoch: 9/30 | Batch 900/938 | loss: 0.1751
# Epoch: 9/30 | Batch 910/938 | loss: 0.1314
# Epoch: 9/30 | Batch 920/938 | loss: 0.2594
# Epoch: 9/30 | Batch 930/938 | loss: 0.0846
# Epoch 9/30, training loss: 0.1479153034370591, validation loss: 0.21927969252607624
# 	     precision: 0.9265
# 	        recall: 0.9279
# 	            F1: 0.9206
# 	      accuracy: 0.9272
# Epoch: 10/30 | Batch 0/938 | loss: 0.1567
# Epoch: 10/30 | Batch 10/938 | loss: 0.0953
# Epoch: 10/30 | Batch 20/938 | loss: 0.1027
# Epoch: 10/30 | Batch 30/938 | loss: 0.1667
# Epoch: 10/30 | Batch 40/938 | loss: 0.1216
# Epoch: 10/30 | Batch 50/938 | loss: 0.0732
# Epoch: 10/30 | Batch 60/938 | loss: 0.1229
# Epoch: 10/30 | Batch 70/938 | loss: 0.2238
# Epoch: 10/30 | Batch 80/938 | loss: 0.0633
# Epoch: 10/30 | Batch 90/938 | loss: 0.1062
# Epoch: 10/30 | Batch 100/938 | loss: 0.1842
# Epoch: 10/30 | Batch 110/938 | loss: 0.0750
# Epoch: 10/30 | Batch 120/938 | loss: 0.1335
# Epoch: 10/30 | Batch 130/938 | loss: 0.1323
# Epoch: 10/30 | Batch 140/938 | loss: 0.1180
# Epoch: 10/30 | Batch 150/938 | loss: 0.1617
# Epoch: 10/30 | Batch 160/938 | loss: 0.0720
# Epoch: 10/30 | Batch 170/938 | loss: 0.0207
# Epoch: 10/30 | Batch 180/938 | loss: 0.0836
# Epoch: 10/30 | Batch 190/938 | loss: 0.1157
# Epoch: 10/30 | Batch 200/938 | loss: 0.2086
# Epoch: 10/30 | Batch 210/938 | loss: 0.1902
# Epoch: 10/30 | Batch 220/938 | loss: 0.1682
# Epoch: 10/30 | Batch 230/938 | loss: 0.0929
# Epoch: 10/30 | Batch 240/938 | loss: 0.1150
# Epoch: 10/30 | Batch 250/938 | loss: 0.2031
# Epoch: 10/30 | Batch 260/938 | loss: 0.0693
# Epoch: 10/30 | Batch 270/938 | loss: 0.1435
# Epoch: 10/30 | Batch 280/938 | loss: 0.1804
# Epoch: 10/30 | Batch 290/938 | loss: 0.0891
# Epoch: 10/30 | Batch 300/938 | loss: 0.2484
# Epoch: 10/30 | Batch 310/938 | loss: 0.0923
# Epoch: 10/30 | Batch 320/938 | loss: 0.1645
# Epoch: 10/30 | Batch 330/938 | loss: 0.0852
# Epoch: 10/30 | Batch 340/938 | loss: 0.1357
# Epoch: 10/30 | Batch 350/938 | loss: 0.1784
# Epoch: 10/30 | Batch 360/938 | loss: 0.0962
# Epoch: 10/30 | Batch 370/938 | loss: 0.1635
# Epoch: 10/30 | Batch 380/938 | loss: 0.3430
# Epoch: 10/30 | Batch 390/938 | loss: 0.2113
# Epoch: 10/30 | Batch 400/938 | loss: 0.2739
# Epoch: 10/30 | Batch 410/938 | loss: 0.1000
# Epoch: 10/30 | Batch 420/938 | loss: 0.0877
# Epoch: 10/30 | Batch 430/938 | loss: 0.1800
# Epoch: 10/30 | Batch 440/938 | loss: 0.1776
# Epoch: 10/30 | Batch 450/938 | loss: 0.0830
# Epoch: 10/30 | Batch 460/938 | loss: 0.1290
# Epoch: 10/30 | Batch 470/938 | loss: 0.1000
# Epoch: 10/30 | Batch 480/938 | loss: 0.1451
# Epoch: 10/30 | Batch 490/938 | loss: 0.1138
# Epoch: 10/30 | Batch 500/938 | loss: 0.0456
# Epoch: 10/30 | Batch 510/938 | loss: 0.1441
# Epoch: 10/30 | Batch 520/938 | loss: 0.0559
# Epoch: 10/30 | Batch 530/938 | loss: 0.0854
# Epoch: 10/30 | Batch 540/938 | loss: 0.0791
# Epoch: 10/30 | Batch 550/938 | loss: 0.0357
# Epoch: 10/30 | Batch 560/938 | loss: 0.2519
# Epoch: 10/30 | Batch 570/938 | loss: 0.0606
# Epoch: 10/30 | Batch 580/938 | loss: 0.1034
# Epoch: 10/30 | Batch 590/938 | loss: 0.1166
# Epoch: 10/30 | Batch 600/938 | loss: 0.1131
# Epoch: 10/30 | Batch 610/938 | loss: 0.1217
# Epoch: 10/30 | Batch 620/938 | loss: 0.1393
# Epoch: 10/30 | Batch 630/938 | loss: 0.2382
# Epoch: 10/30 | Batch 640/938 | loss: 0.1059
# Epoch: 10/30 | Batch 650/938 | loss: 0.1507
# Epoch: 10/30 | Batch 660/938 | loss: 0.1738
# Epoch: 10/30 | Batch 670/938 | loss: 0.1817
# Epoch: 10/30 | Batch 680/938 | loss: 0.2915
# Epoch: 10/30 | Batch 690/938 | loss: 0.1235
# Epoch: 10/30 | Batch 700/938 | loss: 0.1311
# Epoch: 10/30 | Batch 710/938 | loss: 0.1427
# Epoch: 10/30 | Batch 720/938 | loss: 0.1720
# Epoch: 10/30 | Batch 730/938 | loss: 0.2428
# Epoch: 10/30 | Batch 740/938 | loss: 0.1903
# Epoch: 10/30 | Batch 750/938 | loss: 0.0899
# Epoch: 10/30 | Batch 760/938 | loss: 0.0940
# Epoch: 10/30 | Batch 770/938 | loss: 0.2059
# Epoch: 10/30 | Batch 780/938 | loss: 0.0629
# Epoch: 10/30 | Batch 790/938 | loss: 0.1940
# Epoch: 10/30 | Batch 800/938 | loss: 0.0693
# Epoch: 10/30 | Batch 810/938 | loss: 0.0751
# Epoch: 10/30 | Batch 820/938 | loss: 0.1875
# Epoch: 10/30 | Batch 830/938 | loss: 0.2502
# Epoch: 10/30 | Batch 840/938 | loss: 0.0658
# Epoch: 10/30 | Batch 850/938 | loss: 0.1227
# Epoch: 10/30 | Batch 860/938 | loss: 0.1726
# Epoch: 10/30 | Batch 870/938 | loss: 0.0987
# Epoch: 10/30 | Batch 880/938 | loss: 0.2575
# Epoch: 10/30 | Batch 890/938 | loss: 0.1051
# Epoch: 10/30 | Batch 900/938 | loss: 0.1255
# Epoch: 10/30 | Batch 910/938 | loss: 0.0757
# Epoch: 10/30 | Batch 920/938 | loss: 0.1998
# Epoch: 10/30 | Batch 930/938 | loss: 0.1009
# Epoch 10/30, training loss: 0.13395483705149627, validation loss: 0.24028271192293257
# 	     precision: 0.9203
# 	        recall: 0.9205
# 	            F1: 0.9137
# 	      accuracy: 0.9219
# Epoch: 11/30 | Batch 0/938 | loss: 0.1587
# Epoch: 11/30 | Batch 10/938 | loss: 0.0779
# Epoch: 11/30 | Batch 20/938 | loss: 0.0435
# Epoch: 11/30 | Batch 30/938 | loss: 0.1400
# Epoch: 11/30 | Batch 40/938 | loss: 0.1727
# Epoch: 11/30 | Batch 50/938 | loss: 0.2371
# Epoch: 11/30 | Batch 60/938 | loss: 0.1189
# Epoch: 11/30 | Batch 70/938 | loss: 0.0398
# Epoch: 11/30 | Batch 80/938 | loss: 0.0811
# Epoch: 11/30 | Batch 90/938 | loss: 0.1262
# Epoch: 11/30 | Batch 100/938 | loss: 0.0744
# Epoch: 11/30 | Batch 110/938 | loss: 0.1471
# Epoch: 11/30 | Batch 120/938 | loss: 0.1352
# Epoch: 11/30 | Batch 130/938 | loss: 0.1097
# Epoch: 11/30 | Batch 140/938 | loss: 0.1091
# Epoch: 11/30 | Batch 150/938 | loss: 0.1071
# Epoch: 11/30 | Batch 160/938 | loss: 0.1632
# Epoch: 11/30 | Batch 170/938 | loss: 0.1181
# Epoch: 11/30 | Batch 180/938 | loss: 0.0484
# Epoch: 11/30 | Batch 190/938 | loss: 0.1185
# Epoch: 11/30 | Batch 200/938 | loss: 0.1651
# Epoch: 11/30 | Batch 210/938 | loss: 0.3786
# Epoch: 11/30 | Batch 220/938 | loss: 0.1421
# Epoch: 11/30 | Batch 230/938 | loss: 0.0565
# Epoch: 11/30 | Batch 240/938 | loss: 0.1549
# Epoch: 11/30 | Batch 250/938 | loss: 0.1542
# Epoch: 11/30 | Batch 260/938 | loss: 0.0944
# Epoch: 11/30 | Batch 270/938 | loss: 0.0332
# Epoch: 11/30 | Batch 280/938 | loss: 0.0835
# Epoch: 11/30 | Batch 290/938 | loss: 0.1768
# Epoch: 11/30 | Batch 300/938 | loss: 0.1105
# Epoch: 11/30 | Batch 310/938 | loss: 0.1908
# Epoch: 11/30 | Batch 320/938 | loss: 0.1585
# Epoch: 11/30 | Batch 330/938 | loss: 0.0835
# Epoch: 11/30 | Batch 340/938 | loss: 0.0506
# Epoch: 11/30 | Batch 350/938 | loss: 0.1049
# Epoch: 11/30 | Batch 360/938 | loss: 0.0743
# Epoch: 11/30 | Batch 370/938 | loss: 0.1215
# Epoch: 11/30 | Batch 380/938 | loss: 0.0757
# Epoch: 11/30 | Batch 390/938 | loss: 0.1432
# Epoch: 11/30 | Batch 400/938 | loss: 0.0959
# Epoch: 11/30 | Batch 410/938 | loss: 0.0908
# Epoch: 11/30 | Batch 420/938 | loss: 0.1676
# Epoch: 11/30 | Batch 430/938 | loss: 0.0558
# Epoch: 11/30 | Batch 440/938 | loss: 0.1740
# Epoch: 11/30 | Batch 450/938 | loss: 0.0836
# Epoch: 11/30 | Batch 460/938 | loss: 0.2347
# Epoch: 11/30 | Batch 470/938 | loss: 0.1393
# Epoch: 11/30 | Batch 480/938 | loss: 0.0985
# Epoch: 11/30 | Batch 490/938 | loss: 0.1346
# Epoch: 11/30 | Batch 500/938 | loss: 0.1342
# Epoch: 11/30 | Batch 510/938 | loss: 0.0716
# Epoch: 11/30 | Batch 520/938 | loss: 0.1702
# Epoch: 11/30 | Batch 530/938 | loss: 0.0772
# Epoch: 11/30 | Batch 540/938 | loss: 0.2085
# Epoch: 11/30 | Batch 550/938 | loss: 0.1564
# Epoch: 11/30 | Batch 560/938 | loss: 0.1073
# Epoch: 11/30 | Batch 570/938 | loss: 0.1115
# Epoch: 11/30 | Batch 580/938 | loss: 0.1460
# Epoch: 11/30 | Batch 590/938 | loss: 0.0879
# Epoch: 11/30 | Batch 600/938 | loss: 0.1080
# Epoch: 11/30 | Batch 610/938 | loss: 0.0507
# Epoch: 11/30 | Batch 620/938 | loss: 0.0517
# Epoch: 11/30 | Batch 630/938 | loss: 0.0781
# Epoch: 11/30 | Batch 640/938 | loss: 0.0746
# Epoch: 11/30 | Batch 650/938 | loss: 0.0707
# Epoch: 11/30 | Batch 660/938 | loss: 0.0469
# Epoch: 11/30 | Batch 670/938 | loss: 0.0343
# Epoch: 11/30 | Batch 680/938 | loss: 0.0919
# Epoch: 11/30 | Batch 690/938 | loss: 0.1955
# Epoch: 11/30 | Batch 700/938 | loss: 0.0338
# Epoch: 11/30 | Batch 710/938 | loss: 0.0962
# Epoch: 11/30 | Batch 720/938 | loss: 0.1604
# Epoch: 11/30 | Batch 730/938 | loss: 0.2095
# Epoch: 11/30 | Batch 740/938 | loss: 0.0605
# Epoch: 11/30 | Batch 750/938 | loss: 0.2222
# Epoch: 11/30 | Batch 760/938 | loss: 0.0872
# Epoch: 11/30 | Batch 770/938 | loss: 0.1415
# Epoch: 11/30 | Batch 780/938 | loss: 0.1516
# Epoch: 11/30 | Batch 790/938 | loss: 0.2395
# Epoch: 11/30 | Batch 800/938 | loss: 0.1208
# Epoch: 11/30 | Batch 810/938 | loss: 0.1613
# Epoch: 11/30 | Batch 820/938 | loss: 0.1105
# Epoch: 11/30 | Batch 830/938 | loss: 0.0737
# Epoch: 11/30 | Batch 840/938 | loss: 0.0997
# Epoch: 11/30 | Batch 850/938 | loss: 0.0658
# Epoch: 11/30 | Batch 860/938 | loss: 0.0381
# Epoch: 11/30 | Batch 870/938 | loss: 0.0738
# Epoch: 11/30 | Batch 880/938 | loss: 0.1863
# Epoch: 11/30 | Batch 890/938 | loss: 0.1676
# Epoch: 11/30 | Batch 900/938 | loss: 0.0530
# Epoch: 11/30 | Batch 910/938 | loss: 0.0507
# Epoch: 11/30 | Batch 920/938 | loss: 0.1047
# Epoch: 11/30 | Batch 930/938 | loss: 0.0614
# Epoch 11/30, training loss: 0.12068272648510267, validation loss: 0.21639190244067247
# 	     precision: 0.9285
# 	        recall: 0.9274
# 	            F1: 0.9221
# 	      accuracy: 0.9289
# Epoch: 12/30 | Batch 0/938 | loss: 0.0548
# Epoch: 12/30 | Batch 10/938 | loss: 0.1321
# Epoch: 12/30 | Batch 20/938 | loss: 0.0584
# Epoch: 12/30 | Batch 30/938 | loss: 0.0538
# Epoch: 12/30 | Batch 40/938 | loss: 0.0454
# Epoch: 12/30 | Batch 50/938 | loss: 0.1923
# Epoch: 12/30 | Batch 60/938 | loss: 0.2360
# Epoch: 12/30 | Batch 70/938 | loss: 0.1056
# Epoch: 12/30 | Batch 80/938 | loss: 0.0692
# Epoch: 12/30 | Batch 90/938 | loss: 0.1036
# Epoch: 12/30 | Batch 100/938 | loss: 0.1664
# Epoch: 12/30 | Batch 110/938 | loss: 0.1320
# Epoch: 12/30 | Batch 120/938 | loss: 0.0471
# Epoch: 12/30 | Batch 130/938 | loss: 0.1588
# Epoch: 12/30 | Batch 140/938 | loss: 0.1198
# Epoch: 12/30 | Batch 150/938 | loss: 0.2747
# Epoch: 12/30 | Batch 160/938 | loss: 0.0612
# Epoch: 12/30 | Batch 170/938 | loss: 0.0874
# Epoch: 12/30 | Batch 180/938 | loss: 0.0869
# Epoch: 12/30 | Batch 190/938 | loss: 0.0407
# Epoch: 12/30 | Batch 200/938 | loss: 0.0431
# Epoch: 12/30 | Batch 210/938 | loss: 0.0433
# Epoch: 12/30 | Batch 220/938 | loss: 0.1132
# Epoch: 12/30 | Batch 230/938 | loss: 0.0391
# Epoch: 12/30 | Batch 240/938 | loss: 0.1289
# Epoch: 12/30 | Batch 250/938 | loss: 0.0348
# Epoch: 12/30 | Batch 260/938 | loss: 0.1047
# Epoch: 12/30 | Batch 270/938 | loss: 0.0814
# Epoch: 12/30 | Batch 280/938 | loss: 0.1111
# Epoch: 12/30 | Batch 290/938 | loss: 0.1257
# Epoch: 12/30 | Batch 300/938 | loss: 0.1873
# Epoch: 12/30 | Batch 310/938 | loss: 0.0501
# Epoch: 12/30 | Batch 320/938 | loss: 0.1467
# Epoch: 12/30 | Batch 330/938 | loss: 0.1754
# ...
# Epoch: 27/30 | Batch 290/938 | loss: 0.0181
# Epoch: 27/30 | Batch 300/938 | loss: 0.0023
# Epoch: 27/30 | Batch 310/938 | loss: 0.0079
# Epoch: 27/30 | Batch 320/938 | loss: 0.1152
# Epoch: 27/30 | Batch 330/938 | loss: 0.0099
# Epoch: 27/30 | Batch 340/938 | loss: 0.0136
# Epoch: 27/30 | Batch 350/938 | loss: 0.0228
# Epoch: 27/30 | Batch 360/938 | loss: 0.0179
# Epoch: 27/30 | Batch 370/938 | loss: 0.0312
# Epoch: 27/30 | Batch 380/938 | loss: 0.0040
# Epoch: 27/30 | Batch 390/938 | loss: 0.0057
# Epoch: 27/30 | Batch 400/938 | loss: 0.0137
# Epoch: 27/30 | Batch 410/938 | loss: 0.0159
# Epoch: 27/30 | Batch 420/938 | loss: 0.0167
# Epoch: 27/30 | Batch 430/938 | loss: 0.0034
# Epoch: 27/30 | Batch 440/938 | loss: 0.0922
# Epoch: 27/30 | Batch 450/938 | loss: 0.0168
# Epoch: 27/30 | Batch 460/938 | loss: 0.0135
# Epoch: 27/30 | Batch 470/938 | loss: 0.0102
# Epoch: 27/30 | Batch 480/938 | loss: 0.0333
# Epoch: 27/30 | Batch 490/938 | loss: 0.0409
# Epoch: 27/30 | Batch 500/938 | loss: 0.0175
# Epoch: 27/30 | Batch 510/938 | loss: 0.0336
# Epoch: 27/30 | Batch 520/938 | loss: 0.0165
# Epoch: 27/30 | Batch 530/938 | loss: 0.0045
# Epoch: 27/30 | Batch 540/938 | loss: 0.0205
# Epoch: 27/30 | Batch 550/938 | loss: 0.0357
# Epoch: 27/30 | Batch 560/938 | loss: 0.0305
# Epoch: 27/30 | Batch 570/938 | loss: 0.0224
# Epoch: 27/30 | Batch 580/938 | loss: 0.0256
# Epoch: 27/30 | Batch 590/938 | loss: 0.0336
# Epoch: 27/30 | Batch 600/938 | loss: 0.0189
# Epoch: 27/30 | Batch 610/938 | loss: 0.0132
# Epoch: 27/30 | Batch 620/938 | loss: 0.0755
# Epoch: 27/30 | Batch 630/938 | loss: 0.0344
# Epoch: 27/30 | Batch 640/938 | loss: 0.0042
# Epoch: 27/30 | Batch 650/938 | loss: 0.0417
# Epoch: 27/30 | Batch 660/938 | loss: 0.0273
# Epoch: 27/30 | Batch 670/938 | loss: 0.0058
# Epoch: 27/30 | Batch 680/938 | loss: 0.0444
# Epoch: 27/30 | Batch 690/938 | loss: 0.0317
# Epoch: 27/30 | Batch 700/938 | loss: 0.0128
# Epoch: 27/30 | Batch 710/938 | loss: 0.0082
# Epoch: 27/30 | Batch 720/938 | loss: 0.0144
# Epoch: 27/30 | Batch 730/938 | loss: 0.0148
# Epoch: 27/30 | Batch 740/938 | loss: 0.0172
# Epoch: 27/30 | Batch 750/938 | loss: 0.0287
# Epoch: 27/30 | Batch 760/938 | loss: 0.0059
# Epoch: 27/30 | Batch 770/938 | loss: 0.0214
# Epoch: 27/30 | Batch 780/938 | loss: 0.0471
# Epoch: 27/30 | Batch 790/938 | loss: 0.0245
# Epoch: 27/30 | Batch 800/938 | loss: 0.0677
# Epoch: 27/30 | Batch 810/938 | loss: 0.0389
# Epoch: 27/30 | Batch 820/938 | loss: 0.0391
# Epoch: 27/30 | Batch 830/938 | loss: 0.0235
# Epoch: 27/30 | Batch 840/938 | loss: 0.0082
# Epoch: 27/30 | Batch 850/938 | loss: 0.1583
# Epoch: 27/30 | Batch 860/938 | loss: 0.0099
# Epoch: 27/30 | Batch 870/938 | loss: 0.0153
# Epoch: 27/30 | Batch 880/938 | loss: 0.0505
# Epoch: 27/30 | Batch 890/938 | loss: 0.0826
# Epoch: 27/30 | Batch 900/938 | loss: 0.0610
# Epoch: 27/30 | Batch 910/938 | loss: 0.0039
# Epoch: 27/30 | Batch 920/938 | loss: 0.0237
# Epoch: 27/30 | Batch 930/938 | loss: 0.1294
# Epoch 27/30, training loss: 0.034941915023570774, validation loss: 0.3595704239004167
# 	     precision: 0.9299
# 	        recall: 0.9307
# 	            F1: 0.9242
# 	      accuracy: 0.9321
# Epoch: 28/30 | Batch 0/938 | loss: 0.0214
# Epoch: 28/30 | Batch 10/938 | loss: 0.0293
# Epoch: 28/30 | Batch 20/938 | loss: 0.0200
# Epoch: 28/30 | Batch 30/938 | loss: 0.0169
# Epoch: 28/30 | Batch 40/938 | loss: 0.0028
# Epoch: 28/30 | Batch 50/938 | loss: 0.0040
# Epoch: 28/30 | Batch 60/938 | loss: 0.0561
# Epoch: 28/30 | Batch 70/938 | loss: 0.0028
# Epoch: 28/30 | Batch 80/938 | loss: 0.0169
# Epoch: 28/30 | Batch 90/938 | loss: 0.0007
# Epoch: 28/30 | Batch 100/938 | loss: 0.0253
# Epoch: 28/30 | Batch 110/938 | loss: 0.0014
# Epoch: 28/30 | Batch 120/938 | loss: 0.1535
# Epoch: 28/30 | Batch 130/938 | loss: 0.0150
# Epoch: 28/30 | Batch 140/938 | loss: 0.0003
# Epoch: 28/30 | Batch 150/938 | loss: 0.0170
# Epoch: 28/30 | Batch 160/938 | loss: 0.0067
# Epoch: 28/30 | Batch 170/938 | loss: 0.0247
# Epoch: 28/30 | Batch 180/938 | loss: 0.0627
# Epoch: 28/30 | Batch 190/938 | loss: 0.0115
# Epoch: 28/30 | Batch 200/938 | loss: 0.0324
# Epoch: 28/30 | Batch 210/938 | loss: 0.0601
# Epoch: 28/30 | Batch 220/938 | loss: 0.0355
# Epoch: 28/30 | Batch 230/938 | loss: 0.0181
# Epoch: 28/30 | Batch 240/938 | loss: 0.0029
# Epoch: 28/30 | Batch 250/938 | loss: 0.0111
# Epoch: 28/30 | Batch 260/938 | loss: 0.0945
# Epoch: 28/30 | Batch 270/938 | loss: 0.0052
# Epoch: 28/30 | Batch 280/938 | loss: 0.0298
# Epoch: 28/30 | Batch 290/938 | loss: 0.0131
# Epoch: 28/30 | Batch 300/938 | loss: 0.0232
# Epoch: 28/30 | Batch 310/938 | loss: 0.0097
# Epoch: 28/30 | Batch 320/938 | loss: 0.0138
# Epoch: 28/30 | Batch 330/938 | loss: 0.0534
# Epoch: 28/30 | Batch 340/938 | loss: 0.0041
# Epoch: 28/30 | Batch 350/938 | loss: 0.0137
# Epoch: 28/30 | Batch 360/938 | loss: 0.0434
# Epoch: 28/30 | Batch 370/938 | loss: 0.0043
# Epoch: 28/30 | Batch 380/938 | loss: 0.0445
# Epoch: 28/30 | Batch 390/938 | loss: 0.0207
# Epoch: 28/30 | Batch 400/938 | loss: 0.0045
# Epoch: 28/30 | Batch 410/938 | loss: 0.0302
# Epoch: 28/30 | Batch 420/938 | loss: 0.0514
# Epoch: 28/30 | Batch 430/938 | loss: 0.0657
# Epoch: 28/30 | Batch 440/938 | loss: 0.0552
# Epoch: 28/30 | Batch 450/938 | loss: 0.0576
# Epoch: 28/30 | Batch 460/938 | loss: 0.0480
# Epoch: 28/30 | Batch 470/938 | loss: 0.0218
# Epoch: 28/30 | Batch 480/938 | loss: 0.0009
# Epoch: 28/30 | Batch 490/938 | loss: 0.0400
# Epoch: 28/30 | Batch 500/938 | loss: 0.0040
# Epoch: 28/30 | Batch 510/938 | loss: 0.0110
# Epoch: 28/30 | Batch 520/938 | loss: 0.0556
# Epoch: 28/30 | Batch 530/938 | loss: 0.0168
# Epoch: 28/30 | Batch 540/938 | loss: 0.0948
# Epoch: 28/30 | Batch 550/938 | loss: 0.0085
# Epoch: 28/30 | Batch 560/938 | loss: 0.0228
# Epoch: 28/30 | Batch 570/938 | loss: 0.0908
# Epoch: 28/30 | Batch 580/938 | loss: 0.0189
# Epoch: 28/30 | Batch 590/938 | loss: 0.0005
# Epoch: 28/30 | Batch 600/938 | loss: 0.0564
# Epoch: 28/30 | Batch 610/938 | loss: 0.1363
# Epoch: 28/30 | Batch 620/938 | loss: 0.0048
# Epoch: 28/30 | Batch 630/938 | loss: 0.0357
# Epoch: 28/30 | Batch 640/938 | loss: 0.0207
# Epoch: 28/30 | Batch 650/938 | loss: 0.0086
# Epoch: 28/30 | Batch 660/938 | loss: 0.0153
# Epoch: 28/30 | Batch 670/938 | loss: 0.1336
# Epoch: 28/30 | Batch 680/938 | loss: 0.0261
# Epoch: 28/30 | Batch 690/938 | loss: 0.0577
# Epoch: 28/30 | Batch 700/938 | loss: 0.0386
# Epoch: 28/30 | Batch 710/938 | loss: 0.0729
# Epoch: 28/30 | Batch 720/938 | loss: 0.0252
# Epoch: 28/30 | Batch 730/938 | loss: 0.0501
# Epoch: 28/30 | Batch 740/938 | loss: 0.0300
# Epoch: 28/30 | Batch 750/938 | loss: 0.0908
# Epoch: 28/30 | Batch 760/938 | loss: 0.0454
# Epoch: 28/30 | Batch 770/938 | loss: 0.0387
# Epoch: 28/30 | Batch 780/938 | loss: 0.0399
# Epoch: 28/30 | Batch 790/938 | loss: 0.0183
# Epoch: 28/30 | Batch 800/938 | loss: 0.0056
# Epoch: 28/30 | Batch 810/938 | loss: 0.0094
# Epoch: 28/30 | Batch 820/938 | loss: 0.0061
# Epoch: 28/30 | Batch 830/938 | loss: 0.0145
# Epoch: 28/30 | Batch 840/938 | loss: 0.0280
# Epoch: 28/30 | Batch 850/938 | loss: 0.1329
# Epoch: 28/30 | Batch 860/938 | loss: 0.0279
# Epoch: 28/30 | Batch 870/938 | loss: 0.0275
# Epoch: 28/30 | Batch 880/938 | loss: 0.0099
# Epoch: 28/30 | Batch 890/938 | loss: 0.0329
# Epoch: 28/30 | Batch 900/938 | loss: 0.0215
# Epoch: 28/30 | Batch 910/938 | loss: 0.0176
# Epoch: 28/30 | Batch 920/938 | loss: 0.0220
# Epoch: 28/30 | Batch 930/938 | loss: 0.0460
# Epoch 28/30, training loss: 0.033558133613332604, validation loss: 0.35297661222321736
# 	     precision: 0.9268
# 	        recall: 0.9297
# 	            F1: 0.9215
# 	      accuracy: 0.9299
# Epoch: 29/30 | Batch 0/938 | loss: 0.0138
# Epoch: 29/30 | Batch 10/938 | loss: 0.0154
# Epoch: 29/30 | Batch 20/938 | loss: 0.0135
# Epoch: 29/30 | Batch 30/938 | loss: 0.1911
# Epoch: 29/30 | Batch 40/938 | loss: 0.0417
# Epoch: 29/30 | Batch 50/938 | loss: 0.0004
# Epoch: 29/30 | Batch 60/938 | loss: 0.0619
# Epoch: 29/30 | Batch 70/938 | loss: 0.0041
# Epoch: 29/30 | Batch 80/938 | loss: 0.0448
# Epoch: 29/30 | Batch 90/938 | loss: 0.0409
# Epoch: 29/30 | Batch 100/938 | loss: 0.0025
# Epoch: 29/30 | Batch 110/938 | loss: 0.0069
# Epoch: 29/30 | Batch 120/938 | loss: 0.0423
# Epoch: 29/30 | Batch 130/938 | loss: 0.0139
# Epoch: 29/30 | Batch 140/938 | loss: 0.0053
# Epoch: 29/30 | Batch 150/938 | loss: 0.0950
# Epoch: 29/30 | Batch 160/938 | loss: 0.0088
# Epoch: 29/30 | Batch 170/938 | loss: 0.0428
# Epoch: 29/30 | Batch 180/938 | loss: 0.0053
# Epoch: 29/30 | Batch 190/938 | loss: 0.0217
# Epoch: 29/30 | Batch 200/938 | loss: 0.0112
# Epoch: 29/30 | Batch 210/938 | loss: 0.0337
# Epoch: 29/30 | Batch 220/938 | loss: 0.1006
# Epoch: 29/30 | Batch 230/938 | loss: 0.0219
# Epoch: 29/30 | Batch 240/938 | loss: 0.0361
# Epoch: 29/30 | Batch 250/938 | loss: 0.0281
# Epoch: 29/30 | Batch 260/938 | loss: 0.0160
# Epoch: 29/30 | Batch 270/938 | loss: 0.0179
# Epoch: 29/30 | Batch 280/938 | loss: 0.1198
# Epoch: 29/30 | Batch 290/938 | loss: 0.0564
# Epoch: 29/30 | Batch 300/938 | loss: 0.0520
# Epoch: 29/30 | Batch 310/938 | loss: 0.0554
# Epoch: 29/30 | Batch 320/938 | loss: 0.0402
# Epoch: 29/30 | Batch 330/938 | loss: 0.1077
# Epoch: 29/30 | Batch 340/938 | loss: 0.0148
# Epoch: 29/30 | Batch 350/938 | loss: 0.0731
# Epoch: 29/30 | Batch 360/938 | loss: 0.2205
# Epoch: 29/30 | Batch 370/938 | loss: 0.0192
# Epoch: 29/30 | Batch 380/938 | loss: 0.0163
# Epoch: 29/30 | Batch 390/938 | loss: 0.0111
# Epoch: 29/30 | Batch 400/938 | loss: 0.0901
# Epoch: 29/30 | Batch 410/938 | loss: 0.0473
# Epoch: 29/30 | Batch 420/938 | loss: 0.0389
# Epoch: 29/30 | Batch 430/938 | loss: 0.0255
# Epoch: 29/30 | Batch 440/938 | loss: 0.0466
# Epoch: 29/30 | Batch 450/938 | loss: 0.0141
# Epoch: 29/30 | Batch 460/938 | loss: 0.0097
# Epoch: 29/30 | Batch 470/938 | loss: 0.0009
# Epoch: 29/30 | Batch 480/938 | loss: 0.0025
# Epoch: 29/30 | Batch 490/938 | loss: 0.0497
# Epoch: 29/30 | Batch 500/938 | loss: 0.0428
# Epoch: 29/30 | Batch 510/938 | loss: 0.0087
# Epoch: 29/30 | Batch 520/938 | loss: 0.0193
# Epoch: 29/30 | Batch 530/938 | loss: 0.0106
# Epoch: 29/30 | Batch 540/938 | loss: 0.0344
# Epoch: 29/30 | Batch 550/938 | loss: 0.0253
# Epoch: 29/30 | Batch 560/938 | loss: 0.0048
# Epoch: 29/30 | Batch 570/938 | loss: 0.0098
# Epoch: 29/30 | Batch 580/938 | loss: 0.0197
# Epoch: 29/30 | Batch 590/938 | loss: 0.0032
# Epoch: 29/30 | Batch 600/938 | loss: 0.0039
# Epoch: 29/30 | Batch 610/938 | loss: 0.0531
# Epoch: 29/30 | Batch 620/938 | loss: 0.0083
# Epoch: 29/30 | Batch 630/938 | loss: 0.0269
# Epoch: 29/30 | Batch 640/938 | loss: 0.0029
# Epoch: 29/30 | Batch 650/938 | loss: 0.0462
# Epoch: 29/30 | Batch 660/938 | loss: 0.0222
# Epoch: 29/30 | Batch 670/938 | loss: 0.0046
# Epoch: 29/30 | Batch 680/938 | loss: 0.0287
# Epoch: 29/30 | Batch 690/938 | loss: 0.0791
# Epoch: 29/30 | Batch 700/938 | loss: 0.0245
# Epoch: 29/30 | Batch 710/938 | loss: 0.0312
# Epoch: 29/30 | Batch 720/938 | loss: 0.0274
# Epoch: 29/30 | Batch 730/938 | loss: 0.0088
# Epoch: 29/30 | Batch 740/938 | loss: 0.0396
# Epoch: 29/30 | Batch 750/938 | loss: 0.0886
# Epoch: 29/30 | Batch 760/938 | loss: 0.0057
# Epoch: 29/30 | Batch 770/938 | loss: 0.0302
# Epoch: 29/30 | Batch 780/938 | loss: 0.0853
# Epoch: 29/30 | Batch 790/938 | loss: 0.0063
# Epoch: 29/30 | Batch 800/938 | loss: 0.0765
# Epoch: 29/30 | Batch 810/938 | loss: 0.0332
# Epoch: 29/30 | Batch 820/938 | loss: 0.0296
# Epoch: 29/30 | Batch 830/938 | loss: 0.0052
# Epoch: 29/30 | Batch 840/938 | loss: 0.0035
# Epoch: 29/30 | Batch 850/938 | loss: 0.0424
# Epoch: 29/30 | Batch 860/938 | loss: 0.1386
# Epoch: 29/30 | Batch 870/938 | loss: 0.0875
# Epoch: 29/30 | Batch 880/938 | loss: 0.0597
# Epoch: 29/30 | Batch 890/938 | loss: 0.0717
# Epoch: 29/30 | Batch 900/938 | loss: 0.0426
# Epoch: 29/30 | Batch 910/938 | loss: 0.0313
# Epoch: 29/30 | Batch 920/938 | loss: 0.0091
# Epoch: 29/30 | Batch 930/938 | loss: 0.0065
# Epoch 29/30, training loss: 0.03220386067149056, validation loss: 0.3622795285621456
# 	     precision: 0.9303
# 	        recall: 0.9271
# 	            F1: 0.9228
# 	      accuracy: 0.9295
# Epoch: 30/30 | Batch 0/938 | loss: 0.0331
# Epoch: 30/30 | Batch 10/938 | loss: 0.0775
# Epoch: 30/30 | Batch 20/938 | loss: 0.0388
# Epoch: 30/30 | Batch 30/938 | loss: 0.0053
# Epoch: 30/30 | Batch 40/938 | loss: 0.0022
# Epoch: 30/30 | Batch 50/938 | loss: 0.0198
# Epoch: 30/30 | Batch 60/938 | loss: 0.0075
# Epoch: 30/30 | Batch 70/938 | loss: 0.0023
# Epoch: 30/30 | Batch 80/938 | loss: 0.0128
# Epoch: 30/30 | Batch 90/938 | loss: 0.0033
# Epoch: 30/30 | Batch 100/938 | loss: 0.0298
# Epoch: 30/30 | Batch 110/938 | loss: 0.0383
# Epoch: 30/30 | Batch 120/938 | loss: 0.0005
# Epoch: 30/30 | Batch 130/938 | loss: 0.0061
# Epoch: 30/30 | Batch 140/938 | loss: 0.0581
# Epoch: 30/30 | Batch 150/938 | loss: 0.0069
# Epoch: 30/30 | Batch 160/938 | loss: 0.0250
# Epoch: 30/30 | Batch 170/938 | loss: 0.0060
# Epoch: 30/30 | Batch 180/938 | loss: 0.0259
# Epoch: 30/30 | Batch 190/938 | loss: 0.0456
# Epoch: 30/30 | Batch 200/938 | loss: 0.0114
# Epoch: 30/30 | Batch 210/938 | loss: 0.0249
# Epoch: 30/30 | Batch 220/938 | loss: 0.0034
# Epoch: 30/30 | Batch 230/938 | loss: 0.0022
# Epoch: 30/30 | Batch 240/938 | loss: 0.0172
# Epoch: 30/30 | Batch 250/938 | loss: 0.0021
# Epoch: 30/30 | Batch 260/938 | loss: 0.0161
# Epoch: 30/30 | Batch 270/938 | loss: 0.0360
# Epoch: 30/30 | Batch 280/938 | loss: 0.0058
# Epoch: 30/30 | Batch 290/938 | loss: 0.0018
# Epoch: 30/30 | Batch 300/938 | loss: 0.0058
# Epoch: 30/30 | Batch 310/938 | loss: 0.0765
# Epoch: 30/30 | Batch 320/938 | loss: 0.1041
# Epoch: 30/30 | Batch 330/938 | loss: 0.0044
# Epoch: 30/30 | Batch 340/938 | loss: 0.0109
# Epoch: 30/30 | Batch 350/938 | loss: 0.0002
# Epoch: 30/30 | Batch 360/938 | loss: 0.0202
# Epoch: 30/30 | Batch 370/938 | loss: 0.0078
# Epoch: 30/30 | Batch 380/938 | loss: 0.0168
# Epoch: 30/30 | Batch 390/938 | loss: 0.0288
# Epoch: 30/30 | Batch 400/938 | loss: 0.0172
# Epoch: 30/30 | Batch 410/938 | loss: 0.0297
# Epoch: 30/30 | Batch 420/938 | loss: 0.0016
# Epoch: 30/30 | Batch 430/938 | loss: 0.0104
# Epoch: 30/30 | Batch 440/938 | loss: 0.0132
# Epoch: 30/30 | Batch 450/938 | loss: 0.0051
# Epoch: 30/30 | Batch 460/938 | loss: 0.0024
# Epoch: 30/30 | Batch 470/938 | loss: 0.0339
# Epoch: 30/30 | Batch 480/938 | loss: 0.0514
# Epoch: 30/30 | Batch 490/938 | loss: 0.0132
# Epoch: 30/30 | Batch 500/938 | loss: 0.0265
# Epoch: 30/30 | Batch 510/938 | loss: 0.0187
# Epoch: 30/30 | Batch 520/938 | loss: 0.0242
# Epoch: 30/30 | Batch 530/938 | loss: 0.0651
# Epoch: 30/30 | Batch 540/938 | loss: 0.0578
# Epoch: 30/30 | Batch 550/938 | loss: 0.0371
# Epoch: 30/30 | Batch 560/938 | loss: 0.0185
# Epoch: 30/30 | Batch 570/938 | loss: 0.0032
# Epoch: 30/30 | Batch 580/938 | loss: 0.0138
# Epoch: 30/30 | Batch 590/938 | loss: 0.0132
# Epoch: 30/30 | Batch 600/938 | loss: 0.0544
# Epoch: 30/30 | Batch 610/938 | loss: 0.0230
# Epoch: 30/30 | Batch 620/938 | loss: 0.0125
# Epoch: 30/30 | Batch 630/938 | loss: 0.0121
# Epoch: 30/30 | Batch 640/938 | loss: 0.0154
# Epoch: 30/30 | Batch 650/938 | loss: 0.0011
# Epoch: 30/30 | Batch 660/938 | loss: 0.0856
# Epoch: 30/30 | Batch 670/938 | loss: 0.0311
# Epoch: 30/30 | Batch 680/938 | loss: 0.0112
# Epoch: 30/30 | Batch 690/938 | loss: 0.0287
# Epoch: 30/30 | Batch 700/938 | loss: 0.0028
# Epoch: 30/30 | Batch 710/938 | loss: 0.0083
# Epoch: 30/30 | Batch 720/938 | loss: 0.0999
# Epoch: 30/30 | Batch 730/938 | loss: 0.0235
# Epoch: 30/30 | Batch 740/938 | loss: 0.0110
# Epoch: 30/30 | Batch 750/938 | loss: 0.0182
# Epoch: 30/30 | Batch 760/938 | loss: 0.0926
# Epoch: 30/30 | Batch 770/938 | loss: 0.0538
# Epoch: 30/30 | Batch 780/938 | loss: 0.0291
# Epoch: 30/30 | Batch 790/938 | loss: 0.1168
# Epoch: 30/30 | Batch 800/938 | loss: 0.0134
# Epoch: 30/30 | Batch 810/938 | loss: 0.0436
# Epoch: 30/30 | Batch 820/938 | loss: 0.0039
# Epoch: 30/30 | Batch 830/938 | loss: 0.0657
# Epoch: 30/30 | Batch 840/938 | loss: 0.0121
# Epoch: 30/30 | Batch 850/938 | loss: 0.1326
# Epoch: 30/30 | Batch 860/938 | loss: 0.0125
# Epoch: 30/30 | Batch 870/938 | loss: 0.0580
# Epoch: 30/30 | Batch 880/938 | loss: 0.0952
# Epoch: 30/30 | Batch 890/938 | loss: 0.1280
# Epoch: 30/30 | Batch 900/938 | loss: 0.0087
# Epoch: 30/30 | Batch 910/938 | loss: 0.0358
# Epoch: 30/30 | Batch 920/938 | loss: 0.0032
# Epoch: 30/30 | Batch 930/938 | loss: 0.0073
# Epoch 30/30, training loss: 0.031739403358779165, validation loss: 0.3497278252023326
# 	     precision: 0.9323
# 	        recall: 0.9323
# 	            F1: 0.9266
# 	      accuracy: 0.9311
# Total Training Time: 23.88 min

# %% [markdown]
# **At *epoch 13*, the model reaches the maximum accuracy 0.9335, which pass the goal accuracy 0.93!** <br>
# Resnet18 without modifications shows a best accuracy around 0.91 in epoch 5.
# After model changes, the model shows the accuracy with 0.9113 in epoch 5 and increase further. However, after few epochs, validation loss tends to increase by overfitting. It means that the model accuracy is highest at epoch 13, but there might be some critical large loss(error) on a few data.
